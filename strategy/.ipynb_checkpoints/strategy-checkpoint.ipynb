# %%
# set up
import pandas as pd
import numpy as np
import pickle
import time 
import os
import matplotlib.pyplot as plt
from datetime import datetime
from operator import itemgetter
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
data_folder_path = 'C:\\Users\\goodluck\\Desktop\\DB'
raw_data_path =  "C:\\Users\\goodluck\\Desktop\\DB\\raw_data"
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
DTBS_path = os.path.join(storage_path, "DTBS.pkl")

# re-open
with open(DTBS_path, 'rb') as f:  
    DTBS = pickle.load(f)

# %%
# helper

def select_industry(DTBS, iid):
    TS = dict()

    for one_iid in iid:
        count = 0
        for code in list(DTBS['A'].keys()):
            if DTBS['B'][code]['cat1'] == one_iid:
                TS[code] = DTBS['A'][code]
                count += 1
        print(one_iid, count)
    
    return TS

def takeSecond(elem):
    return elem[1]


def retrieve_low_nodes(TS, codes, days, index, sel_num):
    dl_rank = []
    for code in codes:
        dl_rank.append((code, TS[code][days[index]]['dl']))
        
        dl_rank.sort(key=takeSecond)    
    low = dl_rank[0:sel_num]
    return [j[0] for j in low]

def win_rt(res):
    print("For each transaction:")
    print("Max profit", max(res))
    print("Max loss", min(res))
    wins = []
    win = 0
    for i in res:
        if i >= 0:
            win += 1
            wins.append(True)
        else:
            wins.append(False)
        
    win_rate = win/len(res)
    print("Rate of wins", win_rate)
    print("Info for each transaction", wins)
    
def select_existing(PTS, dt):
    exist = []
    for code in list(PTS.keys()):
        if not np.isnan(PTS[code][dt]['dp']):
            exist.append(code)
    return exist

def select_condition(PTS, codes, dt, name, low, high):
    satisfy = []
    for code in codes:
        if PTS[code][dt][name] <= high:
            if PTS[code][dt][name] >= low:
                satisfy.append(code)
    return satisfy


def sel_dts(DD, st, ed, tp):
    dts = []
    stdt = datetime.strptime(st, '%Y-%m-%d').date()
    eddt = datetime.strptime(ed, '%Y-%m-%d').date()
    for time in DD[tp]:
        dt = datetime.strptime(time, '%Y-%m-%d').date()
        if dt >= stdt:
            if dt <= eddt:
                dts.append(time)
    return dts

def all_profit(DTBS, days, ct, sel_ct, sel_dl, sel_num, sel_cd1, sel_nm1, sel_low1, sel_high1):
    profit = []
    sum_dl = 0
    all_codes = []
    res = []
    if sel_ct == 1:
        TS = select_industry(DTBS, ct)
    else:
        TS = DTBS['A']
    for i in range(len(days)):  
#         if sel_dl == 1:
#             curr_dl_codes = retrieve_low_nodes(TS, days, i, sel_num)
#         else:
#             curr_dl_codes = select_existing(TS, days[i])

#         curr_dl_codes = select_existing(TS, days[i])

        if i+1 == len(days):
            curr_dl_codes = select_existing(TS, days[i])

            if sel_cd1 == 1:
                curr_dl_codes = select_condition(TS, curr_dl_codes, days[i], sel_nm1, sel_low1, sel_high1)
            if sel_dl == 1:
                curr_dl_codes = retrieve_low_nodes(TS, curr_dl_codes, days, i, sel_num)                
            
        else: 
            ctw = select_existing(TS, days[i])
            cnw = select_existing(TS, days[i+1])
            curr_dl_codes = list(set(ctw).intersection(set(cnw)))
            
                
            if sel_cd1 == 1:
                curr_dl_codes = select_condition(TS, curr_dl_codes, days[i], sel_nm1, sel_low1, sel_high1)
                if len(curr_dl_codes) == 0:
                    print("Nothing Satisfies!", sel_nm1)
                    
#             if sel_cd2 == 1:
#                 curr_dl_codes = select_condition(TS, curr_dl_codes, days[i], sel_nm2, sel_low2, sel_high2)
#                 if len(curr_dl_codes) == 0:
#                     print("Nothing Satisfies!", sel_nm2)
                    
#             if sel_cd3 == 1:
#                 curr_dl_codes = select_condition(TS, curr_dl_codes, days[i], sel_nm3, sel_low3, sel_high3)
#                 if len(curr_dl_codes) == 0:
#                     print("Nothing Satisfies!", sel_nm3)
                    
            if sel_dl == 1:
                curr_dl_codes = retrieve_low_nodes(TS, curr_dl_codes, days, i, sel_num)
#         print(len(curr_dl_codes))
        all_codes.append(curr_dl_codes)
        if i >= 1:
        
            tw = 0
            lw = 0
            for cd in all_codes[i-1]:
                tw += TS[cd][days[i]]['dp']
        
        
            for cd in all_codes[i-1]:
                lw += TS[cd][days[i-1]]['dp']
        
            re = ((tw - lw)/ lw)
            res.append(re)
            sum_dl += re
        
            profit.append(sum_dl)
    return profit, res
    

def plot_str(days, profit,tick_spacing = 4.5, market = DTBS['C']):
    plt.figure(dpi = 1000)

    fig, ax = plt.subplots(1,1)
    plt.plot(days[1:], profit)
    # ewi
    i_x = [days[1], days[-1]]
#     print(market['zi'][days[-1]], market['zi'][days[0]])

    market_gain = (market['zi'][days[-1]]-market['zi'][days[0]])/(market['zi'][days[0]])
    i_y = [0, market_gain]
    plt.plot(i_x, i_y)

    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
    plt.ylabel('Increase per year/%')
    plt.show()

    print("Final gain", profit[-1])
    print("Market index", market_gain)

def start(DTBS, days, ct, sel_ct, sel_dl, sel_num, sel_cd1, sel_nm1, sel_low1, sel_high1):
    profit, res = all_profit(DTBS, days, ct, sel_ct, sel_dl, sel_num, sel_cd1, sel_nm1, sel_low1, sel_high1)
    ap.append(profit)
    aw.append(profit)
    plot_str(days, profit)
    win_rt(res)

f2020 = sel_dts(DTBS['D'],'2020-01-01','2020-06-30','mon')
s2020 = sel_dts(DTBS['D'],'2020-07-01','2020-12-31','mon')
f2021 = sel_dts(DTBS['D'],'2021-01-01','2021-06-30','mon')
s2021 = sel_dts(DTBS['D'],'2021-07-01','2021-12-31','mon')
f2022 = sel_dts(DTBS['D'],'2022-01-01','2022-06-30','mon')
s2022 = sel_dts(DTBS['D'],'2022-07-01','2022-12-31','mon')
a2023 = sel_dts(DTBS['D'],'2023-01-01','2023-3-22','mon')
a2020 = sel_dts(DTBS['D'],'2020-01-01','2020-12-31','mon')
a2022 = sel_dts(DTBS['D'],'2022-01-01','2022-12-31','mon')
a2021 = sel_dts(DTBS['D'],'2021-01-01','2021-12-31','mon')

def leap(ori, gap):
    new = []
    for i in range(len(ori)):
        if i % gap == 0:
            new.append(ori[i])
    return new

leap(f2020,1)
# Out:
# ['2020-01-06',
#  '2020-01-13',
#  '2020-01-20',
#  '2020-02-03',
#  '2020-02-10',
#  '2020-02-17',
#  '2020-02-24',
#  '2020-03-02',
#  '2020-03-09',
#  '2020-03-16',
#  '2020-03-23',
#  '2020-03-30',
#  '2020-04-13',
#  '2020-04-20',
#  '2020-04-27',
#  '2020-05-11',
#  '2020-05-18',
#  '2020-05-25',
#  '2020-06-01',
#  '2020-06-08',
#  '2020-06-15',
#  '2020-06-22',
#  '2020-06-29']

# %%
# helper

def select_industry(DTBS, exists, iid):
    TS = dict()

    for one_iid in iid:
        count = 0
        for code in exists:
            if DTBS['B'][code]['cat1'] == one_iid:
                TS[code] = DTBS['A'][code]
                count += 1
#         print(one_iid, count)
    
    return TS


def select_price(DTBS, exists, dt, lwp, hgp):
    TS = dict()


    for code in exists:
#         print(code)

        if DTBS['A'][code][dt]['dp'] >= lwp:
            if DTBS['A'][code][dt]['dp'] <= hgp:
                TS[code] = DTBS['A'][code]
#         print(one_iid, count)
    
    return TS

def takeSecond(elem):
    return elem[1]


def retrieve_low_nodes(TS, codes, days, index, sel_num):
    dl_rank = []
    for code in codes:
        if TS[code][days[index]]['dl'] != 999:
            dl_rank.append((code, TS[code][days[index]]['dl']))
        
        dl_rank.sort(key=takeSecond)    
    low = dl_rank[0:sel_num]
    return [j[0] for j in low]

def win_rt(res):
    print("For each transaction:")
    print("Max profit", max(res))
    print("Max loss", min(res))
    wins = []
    win = 0
    for i in res:
        if i >= 0:
            win += 1
            wins.append(True)
        else:
            wins.append(False)
        
    win_rate = win/len(res)
    print("Rate of wins", win_rate)
    print("Info for each transaction", wins)
    
def select_existing(PTS, dt):
    exist = []
    for code in list(PTS.keys()):
        if not np.isnan(PTS[code][dt]['dp']):
            exist.append(code)
    return exist

def select_condition(PTS, codes, dt, name, low, high):
    satisfy = []
    for code in codes:
        if PTS[code][dt][name] <= high:
            if PTS[code][dt][name] >= low:
                satisfy.append(code)
    return satisfy


def sel_dts(DD, st, ed, tp):
    dts = []
    stdt = datetime.strptime(st, '%Y-%m-%d').date()
    eddt = datetime.strptime(ed, '%Y-%m-%d').date()
    for time in DD[tp]:
        dt = datetime.strptime(time, '%Y-%m-%d').date()
        if dt >= stdt:
            if dt <= eddt:
                dts.append(time)
    return dts

def all_profit(DTBS, days, ct, sel_ct, sel_prc, prclst, sel_dl, sel_num, sel_cd1, sel_nm1, sel_low1, sel_high1, sel_cd2, sel_nm2, sel_low2, sel_high2):
    profit = []
    sum_dl = 0
    all_codes = []
    res = []
 
    TS = DTBS['A']
    for i in range(len(days)):  
#         if sel_dl == 1:
#             curr_dl_codes = retrieve_low_nodes(TS, days, i, sel_num)
#         else:
#             curr_dl_codes = select_existing(TS, days[i])

#         curr_dl_codes = select_existing(TS, days[i])

        if i+1 == len(days):
            curr_dl_codes = select_existing(TS, days[i])

           
            
        else: 
            ctw = select_existing(TS, days[i])
            cnw = select_existing(TS, days[i+1])
            curr_dl_codes = list(set(ctw).intersection(set(cnw)))
#             if days[i] == '2020-02-03':
# #                 print("HAASHSFHFJAFJKASSAJKASFHASJFASFj")
# #                 print(TS['128068.SZ'][days[i]])
# #                 print(TS['128068.SZ'][days[i+1]])
#             if '128068.SZ' in curr_dl_codes:
#                 print(days[i], days[i],'????')
            
        if sel_ct == 1:
            ct_result = []
#             print(days[i])
            for idt in ct:
                
                ITS = select_industry(DTBS, curr_dl_codes, [idt])
                ct_codes = list(ITS.keys())
                if sel_cd1 == 1:
                    ct_codes = select_condition(ITS, ct_codes, days[i], sel_nm1, sel_low1, sel_high1)
                    if len(curr_dl_codes) == 0:
                        print("Nothing Satisfies!", sel_nm1)
                        
                if sel_cd2 == 1:
                    ct_codes = select_condition(ITS, ct_codes, days[i], sel_nm2, sel_low2, sel_high2)
                    if len(ct_codes) == 0:
                        print("Nothing Satisfies!", sel_nm2)

                        

                if sel_dl == 1:
                    ct_codes = retrieve_low_nodes(ITS, ct_codes, days, i, sel_num)
                
#                 print(idt, ct_codes)
                for ocd in ct_codes:
                    ct_result.append(ocd)
                    
#             print(ct_result)
            all_codes.append(ct_result)
                    
                
        elif sel_prc == 1:
            ct_result = []
            for lwp, hgp in prclst:
                ITS = select_price(DTBS, curr_dl_codes, days[i], lwp, hgp)
                
                ct_codes = list(ITS.keys())
                if sel_cd1 == 1:
                    ct_codes = select_condition(ITS, ct_codes, days[i], sel_nm1, sel_low1, sel_high1)
                    if len(ct_codes) == 0:
                        print("Nothing Satisfies!", sel_nm1)
                    

                if sel_cd2 == 1:
                    ct_codes = select_condition(ITS, ct_codes, days[i], sel_nm2, sel_low2, sel_high2)
                    if len(ct_codes) == 0:
                        print("Nothing Satisfies!", sel_nm2)
                        
                if sel_dl == 1:
                    ct_codes = retrieve_low_nodes(ITS, ct_codes, days, i, sel_num)
                
#                 print(idt, ct_codes)
                for ocd in ct_codes:
                    ct_result.append(ocd)
                    
#             print(ct_result)
            all_codes.append(ct_result)
                
        else:
            if sel_cd1 == 1:
                
                curr_dl_codes = select_condition(TS, curr_dl_codes, days[i], sel_nm1, sel_low1, sel_high1)
                if len(curr_dl_codes) == 0:
                    print("Nothing Satisfies!", sel_nm1)
                    
            if sel_cd2 == 1:
                curr_dl_codes = select_condition(ITS, ct_codes, days[i], sel_nm2, sel_low2, sel_high2)
                if len(curr_dl_codes) == 0:
                    print("Nothing Satisfies!", sel_nm2)
                    
#             if sel_cd2 == 1:
#                 curr_dl_codes = select_condition(TS, curr_dl_codes, days[i], sel_nm2, sel_low2, sel_high2)
#                 if len(curr_dl_codes) == 0:
#                     print("Nothing Satisfies!", sel_nm2)
                    
#             if sel_cd3 == 1:
#                 curr_dl_codes = select_condition(TS, curr_dl_codes, days[i], sel_nm3, sel_low3, sel_high3)
#                 if len(curr_dl_codes) == 0:
#                     print("Nothing Satisfies!", sel_nm3)
                    
            if sel_dl == 1:
                curr_dl_codes = retrieve_low_nodes(TS, curr_dl_codes, days, i, sel_num)
        
#         print(len(curr_dl_codes))
            all_codes.append(curr_dl_codes)
        if i >= 1:
        
            tw = 0
            lw = 0
#             print(all_codes)
            for cd in all_codes[i-1]:
#                 if i==3:
#                     print(days[3])
#                     print(days[2])
#                     print(cd, TS[cd][days[i]]['dp'])
#                     print(cd, TS[cd][days[i-1]]['dl'])
                tw += TS[cd][days[i]]['dp']
#                 if np.isnan(TS[cd][days[i]]['dp']):
#                     print(cd, days[i], TS[cd][days[i]]['dp'])
#                 print(TS[cd][days[i]]['dp'])
#             print(days[i-1])
        
            for cd in all_codes[i-1]:
                lw += TS[cd][days[i-1]]['dp']

#                 print('ditryprice', TS[cd][days[i-1]]['dp'], 'doublelow', TS[cd][days[i-1]]['dl'])
#                 if np.isnan(TS[cd][days[i-1]]['dp']):
#                     print(cd, days[i], TS[cd][days[i]]['dp'])
#                 print(TS[cd][days[i-1]]['dp'])
        
            re = ((tw - lw)/ lw)
            res.append(re)

            sum_dl += re
            profit.append(sum_dl)

#     print(profit)
    return profit, res
    

def plot_str(days, profit,tick_spacing = 4.5, market = DTBS['C']):
    plt.figure(dpi = 1000)

    fig, ax = plt.subplots(1,1)
    plt.plot(days[1:], profit)
    # ewi
    i_x = [days[1], days[-1]]
#     print(market['zi'][days[-1]], market['zi'][days[0]])

    market_gain = (market['zi'][days[-1]]-market['zi'][days[0]])/(market['zi'][days[0]])
    i_y = [0, market_gain]
    plt.plot(i_x, i_y)

    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
    plt.ylabel('Increase per year/%')
    plt.show()

    print("Final gain", profit[-1])
    print("Market index", market_gain)

def start(DTBS, days, ct, sel_ct, sel_prc, prclst, sel_dl, sel_num, sel_cd1, sel_nm1, sel_low1, sel_high1, sel_cd2, sel_nm2, sel_low2, sel_high2):
    profit, res = all_profit(DTBS, days, ct, sel_ct, sel_prc, prclst, sel_dl, sel_num, sel_cd1, sel_nm1, sel_low1, sel_high1, sel_cd2, sel_nm2, sel_low2, sel_high2)
    ap.append(profit)
    aw.append(profit)
    plot_str(days, profit)
    win_rt(res)

def plot_str(days, profit,tick_spacing = 4.5, market = DTBS['C']):
    plt.figure(dpi = 1000)

    fig, ax = plt.subplots(1,1)
    plt.plot(days[1:], profit)
    # ewi
    i_x = [days[1], days[-1]]
#     print(market['zi'][days[-1]], market['zi'][days[0]])

    market_gain = (market['zi'][days[-1]]-market['zi'][days[0]])/(market['zi'][days[0]])
    i_y = [0, market_gain]
    plt.plot(i_x, i_y)

    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
    plt.ylabel('Increase per year/%')
    plt.show()

    print("Final gain", profit[-1])
    print("Market index", market_gain)
f2020 = sel_dts(DTBS['D'],'2020-01-01','2020-06-30','mon')
s2020 = sel_dts(DTBS['D'],'2020-07-01','2020-12-31','mon')
f2021 = sel_dts(DTBS['D'],'2021-01-01','2021-06-30','mon')
s2021 = sel_dts(DTBS['D'],'2021-07-01','2021-12-31','mon')
f2022 = sel_dts(DTBS['D'],'2022-01-01','2022-06-30','mon')
s2022 = sel_dts(DTBS['D'],'2022-07-01','2022-12-31','mon')
a2023 = sel_dts(DTBS['D'],'2023-01-01','2023-3-22','mon')
a2020 = sel_dts(DTBS['D'],'2020-01-01','2020-12-31','mon')
a2022 = sel_dts(DTBS['D'],'2022-01-01','2022-12-31','mon')
a2021 = sel_dts(DTBS['D'],'2021-01-01','2021-12-31','mon')

def leap(ori, gap):
    new = []
    for i in range(len(ori)):          
        if i % gap == 0:
            new.append(ori[i])
    return new
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-a29ed8fcc293> in <module>()
#     283     print("Final gain", profit[-1])
#     284     print("Market index", market_gain)
# --> 285 f2020 = sel_dts(DTBS['D'],'2020-01-01','2020-06-30','mon')
#     286 s2020 = sel_dts(DTBS['D'],'2020-07-01','2020-12-31','mon')
#     287 f2021 = sel_dts(DTBS['D'],'2021-01-01','2021-06-30','mon')
#
# <ipython-input-32-a29ed8fcc293> in sel_dts(DD, st, ed, tp)
#      78 def sel_dts(DD, st, ed, tp):
#      79     dts = []
# ---> 80     stdt = datetime.strptime(st, '%Y-%m-%d').date()
#      81     eddt = datetime.strptime(ed, '%Y-%m-%d').date()
#      82     for time in DD[tp]:
#
# AttributeError: module 'datetime' has no attribute 'strptime'

# %%
prclst = [[110,120], [120,130], [130,140]]
for lwp, hgp in prclst:
    print(hgp)
# Out:
# 120
# 130
# 140

# %%
ap = []
aw = []

# %%
times = f2020
tt = '2020上半年区间价格与双低策略'
# idts = ['农林牧渔(2021)', '基础化工(2021)', '美容护理(2021)', '通信(2021)', '非银金融(2021)', '电力设备(2021)', '汽车(2021)', '电子(2021)']
prclst = [[110,120], [120,130], [130,140]]
start(DTBS, leap(times, 1), [], 0, 1, prclst, 1, 2, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 1, prclst, 1, 2, 0, 'trt', 2, 10)
start(DTBS, leap(times, 1), [], 0, 1, prclst, 1, 3, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 1, prclst, 1, 3, 0, 'trt', 2, 10)
start(DTBS, leap(times, 1), [], 0, 1, prclst, 1, 4, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 1, prclst, 1, 4, 0, 'trt', 2, 10)
start(DTBS, leap(times, 1), [], 0, 0, prclst, 1, 5, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 0, prclst, 1, 5, 0, 'trt', 2, 10)
start(DTBS, leap(times, 1), [], 0, 0, prclst, 1, 10, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 0, prclst, 1, 10, 0, 'trt', 2, 10)
# Out:
# Final gain 0.5657382557586967
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.22080833877769182
# Max loss -0.0882520810828851
# Rate of wins 0.6363636363636364
# Info for each transaction [True, True, False, True, True, True, False, True, True, True, False, False, True, True, False, False, False, True, True, False, True, True]
# Final gain 0.3450111546654898
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.18026455147503118
# Max loss -0.056554529460527234
# Rate of wins 0.6363636363636364
# Info for each transaction [True, False, True, False, True, False, True, False, True, True, True]
# Final gain 0.4604158373111732
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.1868665943718091
# Max loss -0.0832070716268092
# Rate of wins 0.6818181818181818
# Info for each transaction [True, True, False, True, True, True, False, True, True, True, True, False, True, False, True, False, False, True, True, False, True, True]
# Final gain 0.21556842822050848
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.1438390480239835
# Max loss -0.03942993386822743
# Rate of wins 0.5454545454545454
# Info for each transaction [True, False, True, False, True, False, True, False, True, False, True]
# Final gain 0.36235551743853667
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.16112551492314459
# Max loss -0.07838988827150735
# Rate of wins 0.5909090909090909
# Info for each transaction [True, True, False, True, True, True, False, True, True, True, True, False, True, False, False, False, False, True, True, False, True, False]
# Final gain 0.19367501080713176
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.14446615672789884
# Max loss -0.042110203154151975
# Rate of wins 0.5454545454545454
# Info for each transaction [True, False, True, False, False, False, True, False, True, True, True]
# Final gain 0.18270669472301504
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.1241006244123023
# Max loss -0.06941161101437558
# Rate of wins 0.5
# Info for each transaction [True, False, False, True, True, True, False, True, True, False, True, False, True, True, False, False, False, True, False, False, True, False]
# Final gain 0.10054783095544144
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.07663433724689449
# Max loss -0.06845214488445313
# Rate of wins 0.45454545454545453
# Info for each transaction [False, False, True, False, True, False, True, False, True, False, True]
# Final gain 0.276337983658686
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.12129321117090948
# Max loss -0.07449392784548307
# Rate of wins 0.5
# Info for each transaction [True, False, False, True, True, True, False, True, True, True, False, False, True, True, False, False, False, True, False, False, True, False]
# Final gain 0.12410699676175249
# Market index -0.03668576901966513
# For each transaction:
# Max profit 0.08358957274488273
# Max loss -0.0498892843297163
# Rate of wins 0.45454545454545453
# Info for each transaction [True, False, True, False, True, False, True, False, True, False, False]

# %%
times = s2020
tt = '2020下半年行业+双低1策略'
idts = ['家用电器(2021)', '基础化工(2021)', '建筑材料(2021)', '建筑装饰(2021)', '机械设备(2021)', '商贸零售(2021)', '计算机(2021)', '国防军工(2021)', '钢铁(2021)', '传媒(2021)']
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
# Out:
# Final gain -0.03888218269633265
# Market index -0.018645967595745706
# For each transaction:
# Max profit 0.0716109117463902
# Max loss -0.07517463547892662
# Rate of wins 0.4166666666666667
# Info for each transaction [True, True, True, False, False, False, True, False, True, False, False, False]

# %%
times = f2021
tt = '2021上半年行业+双低1策略'
idts = ['汽车(2021)', '交通运输(2021)', '农林牧渔(2021)', '煤炭(2021)', '有色金属(2021)', '商贸零售(2021)', '机械设备(2021)', '钢铁(2021)', '电力设备(2021)', '基础化工(2021)']
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
# Out:
# Final gain 0.11561820576913755
# Market index 0.015012005248918965
# For each transaction:
# Max profit 0.05484111432488576
# Max loss -0.0378116281745977
# Rate of wins 0.7
# Info for each transaction [False, False, True, True, True, True, True, True, True, False]

# %%
times = s2021
tt = '2021下半年行业+双低1策略'
idts = ['电力设备(2021)', '有色金属(2021)', '交通运输(2021)', '钢铁(2021)', '通信(2021)', '汽车(2021)', '基础化工(2021)', '轻工制造(2021)', '国防军工(2021)', '医药生物(2021)']
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
# Out:
# Final gain 0.21161860176829264
# Market index 0.12542651022902263
# For each transaction:
# Max profit 0.05769468941709009
# Max loss -0.05148466245896373
# Rate of wins 0.7272727272727273
# Info for each transaction [True, True, True, True, True, False, False, True, True, True, False]

# %%
times = f2022
tt = '2022上半年行业+双低1策略'
idts = ['有色金属(2021)', '机械社保(2021)', '基础化工(2021)', '农林牧渔(2021)', '汽车(2021)', '交通运输(2021)', '国防军工(2021)', '医药生物(2021)', '通信(2021)', '电力设备(2021)']
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
# Out:
# Final gain -0.02771398620067742
# Market index -0.05531962600880805
# For each transaction:
# Max profit 0.05187580620427731
# Max loss -0.058410995010825285
# Rate of wins 0.5
# Info for each transaction [False, False, True, False, False, True, False, True, True, True]

# %%
times = s2022
tt = '2022下半年行业+双低1策略'
idts = ['有色金属(2021)', '农林牧渔(2021)', '汽车(2021)', '电力设备(2021)', '公用事业(2021)', '社会服务(2021)', '食品饮料(2021)', '医药生物(2021)', '轻工制造(2021)', '建筑材料(2021)']
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
# Out:
# Final gain -0.06480076205907043
# Market index -0.0663953989832808
# For each transaction:
# Max profit 0.04432527393593588
# Max loss -0.04797967650083925
# Rate of wins 0.45454545454545453
# Info for each transaction [False, True, True, False, False, False, True, True, False, True, False]

# %%
times = a2023
tt = '2023上半年行业+双低1策略'
idts = ['建筑材料(2021)', '建筑装饰(2021)', '国防军工(2021)', '计算机(2021)', '通信(2021)', '食品饮料(2021)', '社会服务(2021)', '纺织服饰(2021)', '交通运输(2021)', '轻工制造(2021)']
start(DTBS, leap(times,2), idts, 1, 1, 1, 0, 'trt', 2, 10)
# Out:
# Final gain 0.06335634927377419
# Market index 0.004831515304733499
# For each transaction:
# Max profit 0.036988518346078095
# Max loss -0.025506789612667242
# Rate of wins 0.75
# Info for each transaction [True, True, False, True]

# %%
times = a2020
tt = '2020全年区间价格[110,120],[120,130],[130,140]与双低策略'
ap = []
aw = []
prclst = [[110,120], [120,130], [130,140]]
start(DTBS, leap(times, 1), [], 0, 1, prclst, 1, 2, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 1, prclst, 1, 2, 0, 'trt', 2, 10)
start(DTBS, leap(times, 1), [], 0, 1, prclst, 1, 3, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 1, prclst, 1, 3, 0, 'trt', 2, 10)
start(DTBS, leap(times, 1), [], 0, 1, prclst, 1, 4, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 1, prclst, 1, 4, 0, 'trt', 2, 10)
start(DTBS, leap(times, 1), [], 0, 0, prclst, 1, 5, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 0, prclst, 1, 5, 0, 'trt', 2, 10)
start(DTBS, leap(times, 1), [], 0, 0, prclst, 1, 10, 0, 'trt', 2, 10)
start(DTBS, leap(times, 2), [], 0, 0, prclst, 1, 10, 0, 'trt', 2, 10)
# Out:
# Final gain 0.9431847973386268
# Market index 0.02455815349311315
# For each transaction:
# Max profit 0.22080833877769182
# Max loss -0.0882520810828851
# Rate of wins 0.6170212765957447
# Info for each transaction [True, True, False, True, True, True, False, True, True, True, False, False, True, True, False, False, False, True, True, False, True, True, True, True, False, True, True, False, True, True, False, False, False, False, False, True, True, True, True, True, True, True, False, True, False, True, False]
# Final gain 0.6039397702877239
# Market index 0.033045622827152045
# For each transaction:
# Max profit 0.18026455147503118
# Max loss -0.056554529460527234
# Rate of wins 0.6086956521739131
# Info for each transaction [True, False, True, False, True, False, True, False, True, True, True, True, False, True, True, True, False, False, True, True, False, True, False]
# Final gain 0.8806601040512592
# Market index 0.02455815349311315
# For each transaction:
# Max profit 0.1868665943718091
# Max loss -0.0832070716268092
# Rate of wins 0.6382978723404256
# Info for each transaction [True, True, False, True, True, True, False, True, True, True, True, False, True, False, True, False, False, True, True, False, True, True, True, True, False, False, True, False, True, False, True, False, False, False, False, True, True, True, True, True, True, True, True, True, False, True, False]
# Final gain 0.6018646371864219
# Market index 0.033045622827152045
# For each transaction:
# Max profit 0.21563486225470407
# Max loss -0.03942993386822743
# Rate of wins 0.5217391304347826
# Info for each transaction [True, False, True, False, True, False, True, False, True, False, True, True, False, True, True, True, False, False, True, True, False, False, False]
# Final gain 0.8058798993394153
# Market index 0.02455815349311315
# For each transaction:
# Max profit 0.16112551492314459
# Max loss -0.07838988827150735
# Rate of wins 0.5957446808510638
# Info for each transaction [True, True, False, True, True, True, False, True, True, True, True, False, True, False, False, False, False, True, True, False, True, False, True, True, False, False, True, False, True, False, True, False, False, False, False, True, True, True, True, True, True, True, True, True, False, True, False]
# Final gain 0.6358370313935642
# Market index 0.033045622827152045
# For each transaction:
# Max profit 0.1939576086088132
# Max loss -0.042110203154151975
# Rate of wins 0.6086956521739131
# Info for each transaction [True, False, True, False, False, False, True, False, True, True, True, True, False, True, True, True, False, False, True, True, True, False, True]
# Final gain 0.1781694817532214
# Market index 0.02455815349311315
# For each transaction:
# Max profit 0.1241006244123023
# Max loss -0.06941161101437558
# Rate of wins 0.5319148936170213
# Info for each transaction [True, False, False, True, True, True, False, True, True, False, True, False, True, True, False, False, False, True, False, False, True, False, True, True, False, False, True, False, True, False, True, True, False, True, False, True, False, True, True, True, True, True, False, True, False, False, False]
# Final gain 0.13620443204500812
# Market index 0.033045622827152045
# For each transaction:
# Max profit 0.10597320498545319
# Max loss -0.06845214488445313
# Rate of wins 0.4782608695652174
# Info for each transaction [False, False, True, False, True, False, True, False, True, False, True, True, False, True, True, True, False, False, False, True, True, False, False]
# Final gain 0.38624493146642147
# Market index 0.02455815349311315
# For each transaction:
# Max profit 0.12129321117090948
# Max loss -0.07449392784548307
# Rate of wins 0.5319148936170213
# Info for each transaction [True, False, False, True, True, True, False, True, True, True, False, False, True, True, False, False, False, True, False, False, True, False, True, True, False, False, True, False, False, True, False, True, False, True, False, True, True, True, False, True, True, True, True, True, False, False, False]
# Final gain 0.3094532217920432
# Market index 0.033045622827152045
# For each transaction:
# Max profit 0.11288621346592533
# Max loss -0.0498892843297163
# Rate of wins 0.4782608695652174
# Info for each transaction [True, False, True, False, True, False, True, False, True, False, False, True, False, True, False, True, True, False, True, True, False, False, False]

# %%
# plot together


from pylab import *
from matplotlib.font_manager import FontProperties  
import matplotlib.pyplot as plt 

font = FontProperties(fname=r"simsun.ttf", size=14)  
matplotlib.rcParams['axes.unicode_minus'] =False
mpl.rcParams['font.sans-serif'] = ['SimHei']

# times = a2023

tick_spacing = 4
plt.figure(figsize=(80,60))

fig, ax = plt.subplots(1,1)
plt.plot(leap(times, 1)[1:], ap[0],linestyle='dashed', label='区间双低2单周')

plt.plot(leap(times, 2)[1:], ap[1],linestyle='dashed', label='区间双低2双周')
plt.plot(leap(times, 1)[1:], ap[2],linestyle='dashed', label='区间双低3单周')
plt.plot(leap(times, 2)[1:], ap[3],linestyle='dashed', label='区间双低3双周')
plt.plot(leap(times, 1)[1:], ap[4],linestyle='dashed', label='区间双低4单周')
plt.plot(leap(times, 2)[1:], ap[5],linestyle='dashed', label='区间双低4双周')
plt.plot(leap(times, 1)[1:], ap[6],linestyle='dotted', label='双低5单周')
plt.plot(leap(times, 2)[1:], ap[7],linestyle='dotted', label='双低5双周')
plt.plot(leap(times, 1)[1:], ap[8],linestyle='dotted', label='双低10单周')
plt.plot(leap(times, 2)[1:], ap[9],linestyle='dotted', label='双低10双周')
# plt.plot(leap(times, 4)[1:], ap[2],linestyle='dashdot',label='每月换仓')
# plt.plot(leap(times, 4)[1:], ap[2],linestyle='solid',label='每月换仓')
i_x = [leap(times, 1)[1], leap(times, 1)[-1]]
#     print(market['zi'][days[-1]], market['zi'][days[0]])

market_gain = (DTBS['C']['zi'][leap(times, 1)[-1]]-DTBS['C']['zi'][leap(times, 1)[0]])/(DTBS['C']['zi'][leap(times, 1)[0]])
i_y = [0, market_gain]
plt.plot(i_x, i_y, linestyle='dashdot', label='市场')

plt.legend(fontsize = 'x-small')

ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
plt.ylabel('收益率/%')

plt.title(tt)
plt.savefig(tt, dpi=300)
plt.show()

with open('log.txt','a') as f:
    print(tt, file=f)
    print("市场收益：", market_gain, file=f)
#     print("每周换仓收益：", ap[0][-1], file=f)
#     print("每两周换仓收益：", ap[1][-1], file=f)
#     print("每月换仓收益：", ap[2][-1], file=f)
    print(ap[0][-1], file=f)
    print(ap[1][-1], file=f)
    print(ap[2][-1], file=f)
    print(ap[3][-1], file=f)
    print(ap[4][-1], file=f)
    print(ap[5][-1], file=f)
    print(ap[6][-1], file=f)
    print(ap[7][-1], file=f)
    print(ap[8][-1], file=f)
    print(ap[9][-1], file=f)
#     print(ap[2][-1], file=f)
#     print(ap[0][-1], ap[1][-1], file=f)
    print("\n", file=f)

# %%
ap
# Out:
# [[0.03803676274088006,
#   0.08885253294736886,
#   0.0006004518644837642,
#   0.22140879064217558,
#   0.2905692589163197,
#   0.3333168021220127,
#   0.300218425576984,
#   0.32379638970425756,
#   0.4743391222505493,
#   0.47931053125677975,
#   0.477415439093637,
#   0.44694782022188495,
#   0.5550229251215392,
#   0.5621153036862608,
#   0.5475753763588516,
#   0.5255115030786227,
#   0.5134072468008835,
#   0.5489321687040353,
#   0.5540697947674051,
#   0.5499194729278264,
#   0.5606605926392727,
#   0.5657382557586967],
#  [0.059523148037900445,
#   0.04622274333181295,
#   0.22648729480684412,
#   0.19117044977833333,
#   0.24402460399232023,
#   0.2435004483804714,
#   0.35880061860523327,
#   0.302246089144706,
#   0.34144010644589096,
#   0.34240585605507246,
#   0.3450111546654898],
#  [0.022223146883296924,
#   0.05248977116878789,
#   -0.030717300458021304,
#   0.1561492939137878,
#   0.24691993987558986,
#   0.2950394159214584,
#   0.2675040019289035,
#   0.28275963184413117,
#   0.357335475994132,
#   0.372642085342027,
#   0.3833215979417761,
#   0.3653169693361304,
#   0.4504109359096824,
#   0.45021502954755616,
#   0.45154521983042173,
#   0.44098257914320543,
#   0.4225868122708679,
#   0.45502741873431135,
#   0.4597227851891347,
#   0.4500352871593284,
#   0.4593457116524781,
#   0.4604158373111732],
#  [0.034056251067909826,
#   0.006266535083906229,
#   0.15010558310788974,
#   0.11715459212138948,
#   0.13827164858624913,
#   0.13520239709962234,
#   0.2226691348927392,
#   0.18323920102451177,
#   0.20990455780123657,
#   0.20487092397521733,
#   0.21556842822050848],
#  [0.030485736820029592,
#   0.05182936066042444,
#   -0.026560527611082907,
#   0.13456498731206168,
#   0.21575483244110286,
#   0.2589865815277417,
#   0.2332869915941989,
#   0.24328872951564515,
#   0.29360464145708276,
#   0.31113844593845746,
#   0.3221457745968,
#   0.30739103351714325,
#   0.39068020367016976,
#   0.3826014137367619,
#   0.3820822172910324,
#   0.36303054545948976,
#   0.33168127704486783,
#   0.3588523713801414,
#   0.36929388694861454,
#   0.3588377018309563,
#   0.3676066551171633,
#   0.36235551743853667],
#  [0.03374088461618229,
#   0.020408714553311044,
#   0.16487487128120987,
#   0.13995241803960168,
#   0.13865240427395994,
#   0.1272657615505326,
#   0.21357333036576898,
#   0.171463127211617,
#   0.18567889350316252,
#   0.18735245122369595,
#   0.19367501080713176],
#  [0.009578013950158842,
#   -0.0016957719362340907,
#   -0.07110738295060967,
#   0.052993241461692625,
#   0.09758912371454281,
#   0.15321719169967452,
#   0.12054716900702647,
#   0.18280210307117054,
#   0.2337277309155743,
#   0.2173886350825886,
#   0.22787145034992087,
#   0.19320940820726218,
#   0.22649738094148264,
#   0.2380084291328411,
#   0.2076431142198676,
#   0.17643580790689442,
#   0.15708680248193954,
#   0.2026097935205764,
#   0.19657501926847204,
#   0.1961757372566663,
#   0.20582272343114916,
#   0.18270669472301504],
#  [-0.00020887747104719346,
#   -0.015645610309627172,
#   0.06098872693726731,
#   0.04535078805456538,
#   0.10942990869375302,
#   0.08452223870194862,
#   0.12790073848397066,
#   0.05944859359951753,
#   0.09516287931380324,
#   0.09109639179800895,
#   0.10054783095544144],
#  [0.020804632674441582,
#   0.013134215356989182,
#   -0.061359712488493895,
#   0.03388204411252839,
#   0.06640784999453853,
#   0.11183958203046535,
#   0.08807032772399057,
#   0.1261930582399921,
#   0.24748626941090157,
#   0.25329329442987575,
#   0.2520414109257124,
#   0.2217038886261393,
#   0.27976975490332084,
#   0.2853667269317257,
#   0.2718346176410392,
#   0.24976140545321626,
#   0.22903679045979025,
#   0.2741725287884892,
#   0.2734274700076923,
#   0.2715845250927606,
#   0.27887218054762714,
#   0.276337983658686],
#  [0.007821363846439765,
#   -0.01955534803165101,
#   0.06403422471323172,
#   0.05812805761897192,
#   0.11791724596028794,
#   0.0994445378372942,
#   0.15767539109787115,
#   0.10778610676815485,
#   0.1326623409201993,
#   0.12819287415549074,
#   0.12410699676175249]]

# %%
DTBS['A']['123019.SZ'][]
# Out:
# {'2017-01-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-01-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-02-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-03-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-04-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-05-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-06-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-07-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-08-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-09-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-10-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-11-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2017-12-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-01-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-02-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-03-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-04-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-05-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-06-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-07-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-08-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-09-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999},
#  '2018-10-25': {'cpr': nan,
# ...
#   'dp': 126.68,
#   'bl': 14.9993,
#   'trt': 1.2952,
#   'ytm': -1.8445,
#   'yl': 5.1557,
#   'dl': 132.94580000000002},
#  '2020-08-19': {'cpr': 7.8036,
#   'dp': 125.96,
#   'bl': 14.9993,
#   'trt': 0.5307,
#   'ytm': -1.7348,
#   'yl': 5.153,
#   'dl': 133.7636},
#  '2020-08-20': {'cpr': 8.2394,
#   'dp': 124.95,
#   'bl': 14.9993,
#   'trt': 0.3547,
#   'ytm': -1.579,
#   'yl': 5.1503,
#   'dl': 133.1894},
#  '2020-08-21': {'cpr': 6.1848,
#   'dp': 125.0,
#   'bl': 14.9993,
#   'trt': 1.3589,
#   'ytm': -1.5877,
#   'yl': 5.1475,
#   'dl': 131.1848},
#  '2020-08-24': {'cpr': 6.5733,
#   'dp': 127.14,
#   'bl': 14.9993,
#   'trt': 1.3127,
#   'ytm': -1.921,
#   'yl': 5.1393,
#   'dl': 133.7133},
#  '2020-08-25': {'cpr': 7.9171,
#   'dp': 126.85,
#   'bl': 14.9993,
#   'trt': 1.7879,
#   'ytm': -1.8776,
#   'yl': 5.1366,
#   'dl': 134.7671},
#  '2020-08-26': {'cpr': 6.8514,
#   'dp': 124.66,
#   'bl': 14.9993,
#   'trt': 1.2949,
#   'ytm': -1.5387,
#   'yl': 5.1339,
#   'dl': 131.5114},
#  '2020-08-27': {'cpr': 8.3435,
#   'dp': 124.5,
#   'bl': 14.9993,
#   'trt': 1.0431,
#   'ytm': -1.5144,
#   'yl': 5.1311,
#   'dl': 132.8435},
#  '2020-08-28': {'cpr': 7.4981,
#   'dp': 124.0,
#   'bl': 14.9993,
#   'trt': 0.2161,
#   'ytm': -1.4364,
#   'yl': 5.1284,
#   'dl': 131.4981},
#  '2020-08-31': {'cpr': 4.5345,
#   'dp': 126.45,
#   'bl': 14.9993,
#   'trt': 5.0388,
#   'ytm': -1.822,
#   'yl': 5.1202,
#   'dl': 130.9845},
#  '2020-09-01': {'cpr': 6.4532,
#   'dp': 126.53,
#   'bl': 14.9993,
#   'trt': 0.8671,
#   'ytm': -1.8353,
#   'yl': 5.1175,
#   'dl': 132.9832},
#  '2020-09-02': {'cpr': 6.7294,
#   'dp': 127.42,
#   'bl': 14.9993,
#   'trt': 0.9966,
#   'ytm': -1.9734,
#   'yl': 5.1148,
#   'dl': 134.1494},
#  '2020-09-03': {'cpr': 4.4384,
#   'dp': 127.25,
#   'bl': 14.9993,
#   'trt': 0.859,
#   'ytm': -1.9483,
#   'yl': 5.112,
#   'dl': 131.6884},
#  '2020-09-04': {'cpr': 6.8381,
#   'dp': 126.8,
#   'bl': 14.9993,
#   'trt': 0.2451,
#   'ytm': -1.8801,
#   'yl': 5.1093,
#   'dl': 133.6381},
#  '2020-09-07': {'cpr': 9.338,
#   'dp': 124.3,
#   'bl': 14.9993,
#   'trt': 0.7554,
#   'ytm': -1.4918,
#   'yl': 5.1011,
#   'dl': 133.638},
#  '2020-09-08': {'cpr': 9.6064,
#   'dp': 121.24,
#   'bl': 14.9993,
#   'trt': 0.6111,
#   'ytm': -1.0003,
#   'yl': 5.0984,
#   'dl': 130.8464},
#  '2020-09-09': {'cpr': 12.8741,
#   'dp': 120.3,
#   'bl': 14.9993,
#   'trt': 0.434,
#   'ytm': -0.8464,
#   'yl': 5.0956,
#   'dl': 133.1741},
#  '2020-09-10': {'cpr': 12.9184,
#   'dp': 117.97,
#   'bl': 14.9993,
#   'trt': 0.3749,
#   'ytm': -0.4577,
#   'yl': 5.0929,
#   'dl': 130.8884},
#  '2020-09-11': {'cpr': 11.7914,
#   'dp': 118.95,
#   'bl': 14.9993,
#   'trt': 2.1444,
#   'ytm': -0.6228,
#   'yl': 5.0902,
#   'dl': 130.7414},
#  '2020-09-14': {'cpr': 12.2085,
#   'dp': 119.0,
#   'bl': 14.9993,
#   'trt': 0.7948,
#   'ytm': -0.6323,
#   'yl': 5.082,
#   'dl': 131.20850000000002},
#  '2020-09-15': {'cpr': 12.2055,
#   'dp': 118.8,
#   'bl': 14.9993,
#   'trt': 0.1615,
#   'ytm': -0.599,
#   'yl': 5.0792,
#   'dl': 131.00549999999998},
#  '2020-09-16': {'cpr': 13.4753,
#   'dp': 118.95,
#   'bl': 14.9993,
#   'trt': 0.1209,
#   'ytm': -0.6246,
#   'yl': 5.0765,
#   'dl': 132.4253},
#  '2020-09-17': {'cpr': 12.1157,
#   'dp': 119.0,
#   'bl': 14.9993,
#   'trt': 0.1559,
#   'ytm': -0.6333,
#   'yl': 5.0738,
#   'dl': 131.1157},
#  '2020-09-18': {'cpr': 10.4732,
#   'dp': 119.97,
#   'bl': 14.9993,
#   'trt': 0.7664,
#   'ytm': -0.7958,
#   'yl': 5.071,
#   'dl': 130.4432},
#  '2020-09-21': {'cpr': 10.1537,
#   'dp': 118.85,
#   'bl': 14.9993,
#   'trt': 0.1308,
#   'ytm': -0.6094,
#   'yl': 5.0628,
#   'dl': 129.00369999999998},
#  '2020-09-22': {'cpr': 10.2219,
#   'dp': 117.28,
#   'bl': 14.9993,
#   'trt': 0.7458,
#   'ytm': -0.3429,
#   'yl': 5.0601,
#   'dl': 127.5019},
#  '2020-09-23': {'cpr': 9.2277,
#   'dp': 118.33,
#   'bl': 14.9993,
#   'trt': 3.132,
#   'ytm': -0.5221,
#   'yl': 5.0574,
#   'dl': 127.5577},
#  '2020-09-24': {'cpr': 11.2587,
#   'dp': 117.7,
#   'bl': 14.9993,
#   'trt': 0.708,
#   'ytm': -0.4151,
#   'yl': 5.0546,
#   'dl': 128.9587},
#  '2020-09-25': {'cpr': 10.681,
#   'dp': 115.05,
#   'bl': 14.9993,
#   'trt': 0.4979,
#   'ytm': 0.0439,
#   'yl': 5.0519,
#   'dl': 125.731},
#  '2020-09-28': {'cpr': 12.4551,
#   'dp': 117.19,
#   'bl': 14.9993,
#   'trt': 1.43,
#   'ytm': -0.3285,
#   'yl': 5.0437,
#   'dl': 129.64509999999999},
#  '2020-09-29': {'cpr': 11.3685,
#   'dp': 118.5,
#   'bl': 14.9993,
#   'trt': 1.9716,
#   'ytm': -0.5528,
#   'yl': 5.041,
#   'dl': 129.8685},
#  '2020-09-30': {'cpr': 12.2045,
#   'dp': 118.11,
#   'bl': 14.9992,
#   'trt': 0.0353,
#   'ytm': -0.4866,
#   'yl': 5.0383,
#   'dl': 130.3145},
#  '2020-10-09': {'cpr': 11.761,
#   'dp': 119.8,
#   'bl': 14.9992,
#   'trt': 0.0745,
#   'ytm': -0.7765,
#   'yl': 5.0137,
#   'dl': 131.561},
#  '2020-10-12': {'cpr': 12.256,
#   'dp': 123.58,
#   'bl': 14.9987,
#   'trt': 0.7764,
#   'ytm': -1.4041,
#   'yl': 5.0055,
#   'dl': 135.836},
#  '2020-10-13': {'cpr': 11.9157,
#   'dp': 123.5,
#   'bl': 14.9986,
#   'trt': 0.6628,
#   'ytm': -1.3919,
#   'yl': 5.0027,
#   'dl': 135.4157},
#  '2020-10-14': {'cpr': 12.5394,
#   'dp': 122.51,
#   'bl': 14.9985,
#   'trt': 0.6284,
#   'ytm': -1.2962,
#   'yl': 5.0,
#   'dl': 135.0494},
#  '2020-10-15': {'cpr': 12.109,
#   'dp': 124.5,
#   'bl': 14.9984,
#   'trt': 0.948,
#   'ytm': -1.62,
#   'yl': 4.9973,
#   'dl': 136.609},
#  '2020-10-16': {'cpr': 10.5917,
#   'dp': 123.3,
#   'bl': 14.9984,
#   'trt': 0.1615,
#   'ytm': -1.4268,
#   'yl': 4.9945,
#   'dl': 133.8917},
#  '2020-10-19': {'cpr': 9.9679,
#   'dp': 120.0,
#   'bl': 14.9984,
#   'trt': 0.3121,
#   'ytm': -0.8822,
#   'yl': 4.9863,
#   'dl': 129.9679},
#  '2020-10-20': {'cpr': 11.1454,
#   'dp': 120.7,
#   'bl': 14.9983,
#   'trt': 0.1818,
#   'ytm': -1.0003,
#   'yl': 4.9836,
#   'dl': 131.8454},
#  '2020-10-21': {'cpr': 13.1625,
#   'dp': 121.6,
#   'bl': 14.9983,
#   'trt': 0.2674,
#   'ytm': -1.1509,
#   'yl': 4.9808,
#   'dl': 134.7625},
#  '2020-10-22': {'cpr': 14.2452,
#   'dp': 121.16,
#   'bl': 14.9983,
#   'trt': 0.5207,
#   'ytm': -1.0783,
#   'yl': 4.9781,
#   'dl': 135.4052},
#  '2020-10-23': {'cpr': 15.9223,
#   'dp': 121.21,
#   'bl': 14.9983,
#   'trt': 1.2897,
#   'ytm': -1.0872,
#   'yl': 4.9753,
#   'dl': 137.1323},
#  '2020-10-26': {'cpr': 13.8304,
#   'dp': 120.82,
#   'bl': 14.9983,
#   'trt': 0.233,
#   'ytm': -1.0238,
#   'yl': 4.9671,
#   'dl': 134.6504},
#  '2020-10-27': {'cpr': 13.5433,
#   'dp': 121.81,
#   'bl': 14.9983,
#   'trt': 0.3568,
#   'ytm': -1.1897,
#   'yl': 4.9644,
#   'dl': 135.3533},
#  '2020-10-28': {'cpr': 14.3172,
#   'dp': 122.54,
#   'bl': 14.9983,
#   'trt': 0.3763,
#   'ytm': -1.3113,
#   'yl': 4.9616,
#   'dl': 136.8572},
#  '2020-10-29': {'cpr': 15.819,
#   'dp': 121.61,
#   'bl': 14.9983,
#   'trt': 0.0846,
#   'ytm': -1.1577,
#   'yl': 4.9589,
#   'dl': 137.429},
#  '2020-10-30': {'cpr': 12.5058,
#   'dp': 121.98,
#   'bl': 14.9983,
#   'trt': 1.4627,
#   'ytm': -1.22,
#   'yl': 4.9562,
#   'dl': 134.4858},
#  '2020-11-02': {'cpr': 11.193,
#   'dp': 122.8,
#   'bl': 14.9983,
#   'trt': 0.515,
#   'ytm': -1.358,
#   'yl': 4.9479,
#   'dl': 133.993},
#  '2020-11-03': {'cpr': 11.9471,
#   'dp': 123.24,
#   'bl': 14.9983,
#   'trt': 0.1301,
#   'ytm': -1.4313,
#   'yl': 4.9452,
#   'dl': 135.1871},
#  '2020-11-04': {'cpr': 9.4109,
#   'dp': 127.55,
#   'bl': 14.9983,
#   'trt': 6.6761,
#   'ytm': -2.1267,
#   'yl': 4.9425,
#   'dl': 136.9609},
#  '2020-11-05': {'cpr': 8.6642,
#   'dp': 128.3,
#   'bl': 14.9982,
#   'trt': 2.041,
#   'ytm': -2.246,
#   'yl': 4.9397,
#   'dl': 136.9642},
#  '2020-11-06': {'cpr': 9.0707,
#   'dp': 128.78,
#   'bl': 14.9982,
#   'trt': 0.5774,
#   'ytm': -2.3224,
#   'yl': 4.937,
#   'dl': 137.8507},
#  '2020-11-09': {'cpr': 7.6722,
#   'dp': 129.49,
#   'bl': 14.9982,
#   'trt': 1.991,
#   'ytm': -2.437,
#   'yl': 4.9288,
#   'dl': 137.1622},
#  '2020-11-10': {'cpr': 6.4852,
#   'dp': 129.09,
#   'bl': 14.9982,
#   'trt': 1.0013,
#   'ytm': -2.376,
#   'yl': 4.926,
#   'dl': 135.5752},
#  '2020-11-11': {'cpr': 6.549,
#   'dp': 128.7,
#   'bl': 14.9982,
#   'trt': 0.858,
#   'ytm': -2.3163,
#   'yl': 4.9233,
#   'dl': 135.249},
#  '2020-11-12': {'cpr': 9.0168,
#   'dp': 127.76,
#   'bl': 14.9982,
#   'trt': 0.4539,
#   'ytm': -2.1695,
#   'yl': 4.9205,
#   'dl': 136.7768},
#  '2020-11-13': {'cpr': 6.0132,
#   'dp': 126.1,
#   'bl': 14.9982,
#   'trt': 2.3413,
#   'ytm': -1.9058,
#   'yl': 4.9178,
#   'dl': 132.1132},
#  '2020-11-16': {'cpr': 4.5161,
#   'dp': 129.82,
#   'bl': 14.9982,
#   'trt': 2.4723,
#   'ytm': -2.4979,
#   'yl': 4.9096,
#   'dl': 134.3361},
#  '2020-11-17': {'cpr': -0.797,
#   'dp': 132.24,
#   'bl': 14.6978,
#   'trt': 5.1396,
#   'ytm': -2.8717,
#   'yl': 4.9068,
#   'dl': 131.443},
#  '2020-11-18': {'cpr': -0.4501,
#   'dp': 132.61,
#   'bl': 14.659,
#   'trt': 2.1218,
#   'ytm': -2.9296,
#   'yl': 4.9041,
#   'dl': 132.15990000000002},
#  '2020-11-19': {'cpr': -0.1155,
#   'dp': 131.11,
#   'bl': 14.6433,
#   'trt': 2.1346,
#   'ytm': -2.7019,
#   'yl': 4.9014,
#   'dl': 130.99450000000002},
#  '2020-11-20': {'cpr': -0.6068,
#   'dp': 133.6,
#   'bl': 14.4803,
#   'trt': 3.4523,
#   'ytm': -3.0825,
#   'yl': 4.8986,
#   'dl': 132.9932},
#  '2020-11-23': {'cpr': -1.2425,
#   'dp': 139.25,
#   'bl': 13.6427,
#   'trt': 14.5417,
#   'ytm': -3.9184,
#   'yl': 4.8904,
#   'dl': 138.0075},
#  '2020-11-24': {'cpr': 0.0949,
#   'dp': 140.3,
#   'bl': 13.6426,
#   'trt': 5.4984,
#   'ytm': -4.0705,
#   'yl': 4.8877,
#   'dl': 140.3949},
#  '2020-11-25': {'cpr': -2.5646,
#   'dp': 150.13,
#   'bl': 12.2176,
#   'trt': 62.3461,
#   'ytm': -5.4141,
#   'yl': 4.8849,
#   'dl': 147.56539999999998},
#  '2020-11-26': {'cpr': -0.3899,
#   'dp': 149.6,
#   'bl': 11.7852,
#   'trt': 17.5992,
#   'ytm': -5.3475,
#   'yl': 4.8822,
#   'dl': 149.21009999999998},
#  '2020-11-27': {'cpr': -0.1845,
#   'dp': 151.39,
#   'bl': 11.6558,
#   'trt': 10.5991,
#   'ytm': -5.5845,
#   'yl': 4.8795,
#   'dl': 151.20549999999997},
#  '2020-11-30': {'cpr': -0.9328,
#   'dp': 145.66,
#   'bl': 11.2538,
#   'trt': 13.4328,
#   'ytm': -4.8313,
#   'yl': 4.8712,
#   'dl': 144.7272},
#  '2020-12-01': {'cpr': 0.2926,
#   'dp': 148.02,
#   'bl': 11.133,
#   'trt': 7.7425,
#   'ytm': -5.1525,
#   'yl': 4.8685,
#   'dl': 148.3126},
#  '2020-12-02': {'cpr': -0.0331,
#   'dp': 144.85,
#   'bl': 10.8748,
#   'trt': 8.0329,
#   'ytm': -4.7258,
#   'yl': 4.8658,
#   'dl': 144.8169},
#  '2020-12-03': {'cpr': -0.1981,
#   'dp': 137.76,
#   'bl': 10.8022,
#   'trt': 7.4562,
#   'ytm': -3.7241,
#   'yl': 4.863,
#   'dl': 137.56189999999998},
#  '2020-12-04': {'cpr': 0.0958,
#   'dp': 136.03,
#   'bl': 10.8014,
#   'trt': 4.6686,
#   'ytm': -3.4715,
#   'yl': 4.8603,
#   'dl': 136.1258},
#  '2020-12-07': {'cpr': -0.812,
#   'dp': 132.68,
#   'bl': 10.6421,
#   'trt': 7.5565,
#   'ytm': -2.9718,
#   'yl': 4.8521,
#   'dl': 131.868},
#  '2020-12-08': {'cpr': 0.4842,
#   'dp': 132.27,
#   'bl': 10.6421,
#   'trt': 3.7688,
#   'ytm': -2.9105,
#   'yl': 4.8493,
#   'dl': 132.7542},
#  '2020-12-09': {'cpr': -0.0373,
#   'dp': 135.2,
#   'bl': 10.6265,
#   'trt': 18.4859,
#   'ytm': -3.3573,
#   'yl': 4.8466,
#   'dl': 135.1627},
#  '2020-12-10': {'cpr': 1.1974,
#   'dp': 132.27,
#   'bl': 10.6264,
#   'trt': 6.9638,
#   'ytm': -2.9138,
#   'yl': 4.8438,
#   'dl': 133.4674},
#  '2020-12-11': {'cpr': 3.5811,
#   'dp': 133.56,
#   'bl': 10.6263,
#   'trt': 7.4213,
#   'ytm': -3.1131,
#   'yl': 4.8411,
#   'dl': 137.1411},
#  '2020-12-14': {'cpr': 2.2546,
#   'dp': 131.66,
#   'bl': 10.6263,
#   'trt': 2.828,
#   'ytm': -2.8259,
#   'yl': 4.8329,
#   'dl': 133.9146},
#  '2020-12-15': {'cpr': 1.4061,
#   'dp': 131.32,
#   'bl': 10.6263,
#   'trt': 2.2218,
#   'ytm': -2.7746,
#   'yl': 4.8301,
#   'dl': 132.7261},
#  '2020-12-16': {'cpr': 2.1757,
#   'dp': 130.8,
#   'bl': 10.6263,
#   'trt': 5.0113,
#   'ytm': -2.6949,
#   'yl': 4.8274,
#   'dl': 132.97570000000002},
#  '2020-12-17': {'cpr': 2.6238,
#   'dp': 136.8,
#   'bl': 10.6263,
#   'trt': 9.3547,
#   'ytm': -3.6118,
#   'yl': 4.8247,
#   'dl': 139.4238},
#  '2020-12-18': {'cpr': 3.507,
#   'dp': 142.01,
#   'bl': 10.6263,
#   'trt': 11.6114,
#   'ytm': -4.3702,
#   'yl': 4.8219,
#   'dl': 145.517},
#  '2020-12-21': {'cpr': 8.1175,
#   'dp': 149.84,
#   'bl': 10.6263,
#   'trt': 7.1546,
#   'ytm': -5.4547,
#   'yl': 4.8137,
#   'dl': 157.9575},
#  '2020-12-22': {'cpr': 7.8542,
#   'dp': 139.37,
#   'bl': 10.6263,
#   'trt': 5.7797,
#   'ytm': -4.0003,
#   'yl': 4.811,
#   'dl': 147.2242},
#  '2020-12-23': {'cpr': 3.7229,
#   'dp': 135.09,
#   'bl': 10.6262,
#   'trt': 2.5366,
#   'ytm': -3.3674,
#   'yl': 4.8082,
#   'dl': 138.8129},
#  '2020-12-24': {'cpr': 4.0467,
#   'dp': 132.23,
#   'bl': 10.6261,
#   'trt': 2.9,
#   'ytm': -2.9308,
#   'yl': 4.8055,
#   'dl': 136.27669999999998},
#  '2020-12-25': {'cpr': 1.6389,
#   'dp': 139.07,
#   'bl': 10.626,
#   'trt': 18.6533,
#   'ytm': -3.9633,
#   'yl': 4.8027,
#   'dl': 140.7089},
#  '2020-12-28': {'cpr': 1.6362,
#   'dp': 153.02,
#   'bl': 10.626,
#   'trt': 45.5903,
#   'ytm': -5.8958,
#   'yl': 4.7945,
#   'dl': 154.6562},
#  '2020-12-29': {'cpr': 1.0658,
#   'dp': 151.13,
#   'bl': 10.626,
#   'trt': 17.8913,
#   'ytm': -5.6509,
#   'yl': 4.7918,
#   'dl': 152.1958},
#  '2020-12-30': {'cpr': 0.4344,
#   'dp': 155.31,
#   'bl': 10.626,
#   'trt': 17.5108,
#   'ytm': -6.1984,
#   'yl': 4.789,
#   'dl': 155.7444},
#  '2020-12-31': {'cpr': 1.6419,
#   'dp': 154.16,
#   'bl': 10.5568,
#   'trt': 7.5673,
#   'ytm': -6.0539,
#   'yl': 4.7863,
#   'dl': 155.8019},
#  '2021-01-04': {'cpr': 5.0491,
#   'dp': 155.04,
#   'bl': 10.5568,
#   'trt': 4.3135,
#   'ytm': -6.1812,
#   'yl': 4.7753,
#   'dl': 160.0891},
#  '2021-01-05': {'cpr': 3.0173,
#   'dp': 149.27,
#   'bl': 10.5567,
#   'trt': 9.6872,
#   'ytm': -5.4243,
#   'yl': 4.7726,
#   'dl': 152.28730000000002},
#  '2021-01-06': {'cpr': 4.8187,
#   'dp': 150.13,
#   'bl': 10.5567,
#   'trt': 4.3852,
#   'ytm': -5.5431,
#   'yl': 4.7699,
#   'dl': 154.9487},
#  '2021-01-07': {'cpr': 7.3917,
#   'dp': 149.93,
#   'bl': 10.5567,
#   'trt': 5.1765,
#   'ytm': -5.5194,
#   'yl': 4.7671,
#   'dl': 157.32170000000002},
#  '2021-01-08': {'cpr': 6.7327,
#   'dp': 150.0,
#   'bl': 10.5567,
#   'trt': 7.5023,
#   'ytm': -5.5319,
#   'yl': 4.7644,
#   'dl': 156.7327},
#  '2021-01-11': {'cpr': 6.3471,
#   'dp': 150.05,
#   'bl': 10.5567,
#   'trt': 5.2432,
#   'ytm': -5.5481,
#   'yl': 4.7562,
#   'dl': 156.39710000000002},
#  '2021-01-12': {'cpr': 4.5254,
#   'dp': 151.94,
#   'bl': 10.5567,
#   'trt': 6.6124,
#   'ytm': -5.8035,
#   'yl': 4.7534,
#   'dl': 156.4654},
#  '2021-01-13': {'cpr': 6.269,
#   'dp': 152.01,
#   'bl': 10.5567,
#   'trt': 9.6854,
#   'ytm': -5.8161,
#   'yl': 4.7507,
#   'dl': 158.279},
#  '2021-01-14': {'cpr': 6.5306,
#   'dp': 155.25,
#   'bl': 10.5566,
#   'trt': 8.488,
#   'ytm': -6.2434,
#   'yl': 4.7479,
#   'dl': 161.7806},
#  '2021-01-15': {'cpr': 8.3626,
#   'dp': 156.01,
#   'bl': 10.5566,
#   'trt': 7.9303,
#   'ytm': -6.3449,
#   'yl': 4.7452,
#   'dl': 164.37259999999998},
#  '2021-01-18': {'cpr': 1.9774,
#   'dp': 161.48,
#   'bl': 10.5566,
#   'trt': 11.7522,
#   'ytm': -7.0449,
#   'yl': 4.737,
#   'dl': 163.45739999999998},
#  '2021-01-19': {'cpr': 0.6154,
#   'dp': 167.35,
#   'bl': 10.5565,
#   'trt': 28.9064,
#   'ytm': -7.7579,
#   'yl': 4.7342,
#   'dl': 167.9654},
#  '2021-01-20': {'cpr': 2.8288,
#   'dp': 173.13,
#   'bl': 10.5565,
#   'trt': 16.8789,
#   'ytm': -8.4316,
#   'yl': 4.7315,
#   'dl': 175.9588},
#  '2021-01-21': {'cpr': 0.5505,
#   'dp': 181.42,
#   'bl': 10.5565,
#   'trt': 20.7783,
#   'ytm': -9.3506,
#   'yl': 4.7288,
#   'dl': 181.9705},
#  '2021-01-22': {'cpr': 3.0443,
#   'dp': 184.39,
#   'bl': 10.5564,
#   'trt': 12.3263,
#   'ytm': -9.6712,
#   'yl': 4.726,
#   'dl': 187.43429999999998},
#  '2021-01-25': {'cpr': -0.1496,
#   'dp': 195.44,
#   'bl': 10.517,
#   'trt': 30.253,
#   'ytm': -10.8102,
#   'yl': 4.7178,
#   'dl': 195.2904},
#  '2021-01-26': {'cpr': -0.807,
#   'dp': 186.24,
#   'bl': 10.4489,
#   'trt': 18.3126,
#   'ytm': -9.8866,
#   'yl': 4.7151,
#   'dl': 185.43300000000002},
#  '2021-01-27': {'cpr': 2.1384,
#   'dp': 191.77,
#   'bl': 10.3629,
#   'trt': 23.1235,
#   'ytm': -10.4577,
#   'yl': 4.7123,
#   'dl': 193.9084},
#  '2021-01-28': {'cpr': 1.0646,
#   'dp': 179.16,
#   'bl': 10.3582,
#   'trt': 12.8464,
#   'ytm': -9.1424,
#   'yl': 4.7096,
#   'dl': 180.2246},
#  '2021-01-29': {'cpr': -0.5679,
#   'dp': 180.14,
#   'bl': 10.3441,
#   'trt': 29.6156,
#   'ytm': -9.2543,
#   'yl': 4.7068,
#   'dl': 179.57209999999998},
#  '2021-02-01': {'cpr': 2.1039,
#   'dp': 203.45,
#   'bl': 10.2681,
#   'trt': 30.2428,
#   'ytm': -11.6216,
#   'yl': 4.6986,
#   'dl': 205.5539},
#  '2021-02-02': {'cpr': -1.0634,
#   'dp': 203.38,
#   'bl': 10.2584,
#   'trt': 26.0803,
#   'ytm': -11.6215,
#   'yl': 4.6959,
#   'dl': 202.3166},
#  '2021-02-03': {'cpr': 1.4385,
#   'dp': 202.03,
#   'bl': 10.2584,
#   'trt': 14.4022,
#   'ytm': -11.5007,
#   'yl': 4.6932,
#   'dl': 203.4685},
#  '2021-02-04': {'cpr': 0.0167,
#   'dp': 198.92,
#   'bl': 10.2563,
#   'trt': 16.26,
#   'ytm': -11.21,
#   'yl': 4.6904,
#   'dl': 198.93669999999997},
#  '2021-02-05': {'cpr': 1.2364,
#   'dp': 190.64,
#   'bl': 10.2478,
#   'trt': 37.1803,
#   'ytm': -10.396,
#   'yl': 4.6877,
#   'dl': 191.8764},
#  '2021-02-08': {'cpr': 1.5129,
#   'dp': 198.6,
#   'bl': 10.2428,
#   'trt': 21.7701,
#   'ytm': -11.204,
#   'yl': 4.6795,
#   'dl': 200.1129},
#  ...}

# %%
2 in range(0,10)
# Out:
# True

# %%
DTBS['C']['zi']['2023-03-20'] = np.float64(DTBS['C']['zi']['2023-03-20'])
DTBS['C']['zi']['2023-03-21'] = np.float64(DTBS['C']['zi']['2023-03-21'])
DTBS['C']['zi']['2023-03-22'] = np.float64(DTBS['C']['zi']['2023-03-22'])

# %%
# save
f_save = open(DTBS_path, 'wb')
pickle.dump(DTBS, f_save)
f_save.close()

# %%
type(np.float64(411.2))
# Out:
# numpy.float64

# %%
DTBS['A']['123019.SZ']['2020-03-26']
# Out:
# {'cpr': nan,
#  'dp': nan,
#  'bl': nan,
#  'trt': nan,
#  'ytm': nan,
#  'yl': nan,
#  'ia': 0,
#  'dl': 999}

# %%
DTBS['B']['123035.SZ']
# Out:
# {'cn': '利德转债',
#  'ipo': '2019-12-09',
#  'sc': '300296.SZ',
#  'sn': '利亚德',
#  'cat1': '电子(2021)',
#  'cat2': '光学光电子(2021)',
#  'dld': '2046-01-01'}

# %%
DTBS['A']['123035.SZ']
# Out:
# {'2017-01-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-01-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-02-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-03-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-04-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-05-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-06-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-07-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-08-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-09-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-10-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-11-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2017-12-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-01-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-02-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-03-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-04-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-05-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-22': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-28': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-06-29': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-11': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-12': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-18': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-19': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-23': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-24': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-25': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-26': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-27': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-30': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-07-31': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-01': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-02': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-07': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-08': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-13': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-14': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-15': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-16': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-17': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-20': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
#  '2018-08-21': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0},
# ...
#   'dl': 140.1199,
#   'ia': 1},
#  '2020-08-31': {'cpr': 22.7578,
#   'dp': 120.999,
#   'bl': 7.9991,
#   'trt': 1.1337,
#   'ytm': -0.8923,
#   'yl': 5.2049,
#   'dl': 143.7568,
#   'ia': 1},
#  '2020-09-01': {'cpr': 18.8704,
#   'dp': 124.32,
#   'bl': 7.9991,
#   'trt': 2.0381,
#   'ytm': -1.4183,
#   'yl': 5.2022,
#   'dl': 143.19039999999998,
#   'ia': 1},
#  '2020-09-02': {'cpr': 9.5612,
#   'dp': 128.24,
#   'bl': 7.9991,
#   'trt': 61.6905,
#   'ytm': -2.0183,
#   'yl': 5.1995,
#   'dl': 137.8012,
#   'ia': 1},
#  '2020-09-03': {'cpr': 9.2295,
#   'dp': 125.348,
#   'bl': 7.9991,
#   'trt': 11.9916,
#   'ytm': -1.5792,
#   'yl': 5.1967,
#   'dl': 134.5775,
#   'ia': 1},
#  '2020-09-04': {'cpr': 8.6666,
#   'dp': 128.594,
#   'bl': 7.999,
#   'trt': 31.9782,
#   'ytm': -2.0735,
#   'yl': 5.194,
#   'dl': 137.26059999999998,
#   'ia': 1},
#  '2020-09-07': {'cpr': 9.9355,
#   'dp': 127.103,
#   'bl': 7.999,
#   'trt': 21.5848,
#   'ytm': -1.8517,
#   'yl': 5.1858,
#   'dl': 137.0385,
#   'ia': 1},
#  '2020-09-08': {'cpr': 6.558,
#   'dp': 126.404,
#   'bl': 7.999,
#   'trt': 11.9073,
#   'ytm': -1.746,
#   'yl': 5.1831,
#   'dl': 132.962,
#   'ia': 1},
#  '2020-09-09': {'cpr': 4.3327,
#   'dp': 127.8,
#   'bl': 7.9989,
#   'trt': 52.823,
#   'ytm': -1.9594,
#   'yl': 5.1803,
#   'dl': 132.1327,
#   'ia': 1},
#  '2020-09-10': {'cpr': 11.1547,
#   'dp': 124.85,
#   'bl': 7.9989,
#   'trt': 10.6995,
#   'ytm': -1.5078,
#   'yl': 5.1776,
#   'dl': 136.00469999999999,
#   'ia': 1},
#  '2020-09-11': {'cpr': 4.3772,
#   'dp': 129.35,
#   'bl': 7.9989,
#   'trt': 35.1032,
#   'ytm': -2.1944,
#   'yl': 5.1749,
#   'dl': 133.72719999999998,
#   'ia': 1},
#  '2020-09-14': {'cpr': 1.5866,
#   'dp': 132.15,
#   'bl': 7.9984,
#   'trt': 24.0539,
#   'ytm': -2.6109,
#   'yl': 5.1667,
#   'dl': 133.7366,
#   'ia': 1},
#  '2020-09-15': {'cpr': 4.0101,
#   'dp': 129.64,
#   'bl': 7.9984,
#   'trt': 9.6397,
#   'ytm': -2.2424,
#   'yl': 5.1639,
#   'dl': 133.65009999999998,
#   'ia': 1},
#  '2020-09-16': {'cpr': 4.0409,
#   'dp': 128.486,
#   'bl': 7.9983,
#   'trt': 8.9474,
#   'ytm': -2.0706,
#   'yl': 5.1612,
#   'dl': 132.52689999999998,
#   'ia': 1},
#  '2020-09-17': {'cpr': 4.4403,
#   'dp': 128.68,
#   'bl': 7.9983,
#   'trt': 7.0844,
#   'ytm': -2.1009,
#   'yl': 5.1585,
#   'dl': 133.12030000000001,
#   'ia': 1},
#  '2020-09-18': {'cpr': 4.5299,
#   'dp': 129.689,
#   'bl': 7.9983,
#   'trt': 7.862,
#   'ytm': -2.2534,
#   'yl': 5.1557,
#   'dl': 134.2189,
#   'ia': 1},
#  '2020-09-21': {'cpr': 3.3119,
#   'dp': 130.99,
#   'bl': 7.9983,
#   'trt': 8.8085,
#   'ytm': -2.4503,
#   'yl': 5.1475,
#   'dl': 134.30190000000002,
#   'ia': 1},
#  '2020-09-22': {'cpr': 7.0063,
#   'dp': 127.549,
#   'bl': 7.9983,
#   'trt': 3.6288,
#   'ytm': -1.9349,
#   'yl': 5.1448,
#   'dl': 134.55530000000002,
#   'ia': 1},
#  '2020-09-23': {'cpr': 7.7732,
#   'dp': 128.0,
#   'bl': 7.9983,
#   'trt': 1.0094,
#   'ytm': -2.0046,
#   'yl': 5.1421,
#   'dl': 135.7732,
#   'ia': 1},
#  '2020-09-24': {'cpr': 11.9795,
#   'dp': 125.616,
#   'bl': 7.9983,
#   'trt': 1.0333,
#   'ytm': -1.6389,
#   'yl': 5.1393,
#   'dl': 137.5955,
#   'ia': 1},
#  '2020-09-25': {'cpr': 11.0248,
#   'dp': 122.0,
#   'bl': 7.9983,
#   'trt': 1.7541,
#   'ytm': -1.0667,
#   'yl': 5.1366,
#   'dl': 133.0248,
#   'ia': 1},
#  '2020-09-28': {'cpr': 12.1588,
#   'dp': 121.8,
#   'bl': 7.9983,
#   'trt': 0.9815,
#   'ytm': -1.0361,
#   'yl': 5.1284,
#   'dl': 133.9588,
#   'ia': 1},
#  '2020-09-29': {'cpr': 10.3606,
#   'dp': 123.8,
#   'bl': 7.9983,
#   'trt': 2.6543,
#   'ytm': -1.3574,
#   'yl': 5.1257,
#   'dl': 134.1606,
#   'ia': 1},
#  '2020-09-30': {'cpr': 12.1075,
#   'dp': 123.511,
#   'bl': 7.9983,
#   'trt': 2.0351,
#   'ytm': -1.3122,
#   'yl': 5.123,
#   'dl': 135.61849999999998,
#   'ia': 1},
#  '2020-10-09': {'cpr': 11.8832,
#   'dp': 126.63,
#   'bl': 7.9983,
#   'trt': 1.4184,
#   'ytm': -1.8106,
#   'yl': 5.0984,
#   'dl': 138.51319999999998,
#   'ia': 1},
#  '2020-10-12': {'cpr': 9.0892,
#   'dp': 128.0,
#   'bl': 7.9983,
#   'trt': 1.8076,
#   'ytm': -2.0254,
#   'yl': 5.0902,
#   'dl': 137.0892,
#   'ia': 1},
#  '2020-10-13': {'cpr': 10.7247,
#   'dp': 128.65,
#   'bl': 7.9982,
#   'trt': 0.9167,
#   'ytm': -2.1261,
#   'yl': 5.0874,
#   'dl': 139.37470000000002,
#   'ia': 1},
#  '2020-10-14': {'cpr': 13.9926,
#   'dp': 127.221,
#   'bl': 7.9982,
#   'trt': 0.9503,
#   'ytm': -1.9073,
#   'yl': 5.0847,
#   'dl': 141.2136,
#   'ia': 1},
#  '2020-10-15': {'cpr': 15.4832,
#   'dp': 127.23,
#   'bl': 7.9982,
#   'trt': 0.5231,
#   'ytm': -1.9098,
#   'yl': 5.082,
#   'dl': 142.7132,
#   'ia': 1},
#  '2020-10-16': {'cpr': 14.1599,
#   'dp': 126.59,
#   'bl': 7.9982,
#   'trt': 0.928,
#   'ytm': -1.8113,
#   'yl': 5.0792,
#   'dl': 140.7499,
#   'ia': 1},
#  '2020-10-19': {'cpr': 13.2432,
#   'dp': 124.6,
#   'bl': 7.9982,
#   'trt': 0.939,
#   'ytm': -1.5003,
#   'yl': 5.071,
#   'dl': 137.8432,
#   'ia': 1},
#  '2020-10-20': {'cpr': 12.3146,
#   'dp': 125.67,
#   'bl': 7.9981,
#   'trt': 3.0362,
#   'ytm': -1.6708,
#   'yl': 5.0683,
#   'dl': 137.9846,
#   'ia': 1},
#  '2020-10-21': {'cpr': 15.2472,
#   'dp': 123.998,
#   'bl': 7.9981,
#   'trt': 1.6041,
#   'ytm': -1.4056,
#   'yl': 5.0656,
#   'dl': 139.2452,
#   'ia': 1},
#  '2020-10-22': {'cpr': 14.3513,
#   'dp': 125.0,
#   'bl': 7.9976,
#   'trt': 6.8979,
#   'ytm': -1.5664,
#   'yl': 5.0628,
#   'dl': 139.3513,
#   'ia': 1},
#  '2020-10-23': {'cpr': 13.162,
#   'dp': 123.7,
#   'bl': 7.9976,
#   'trt': 10.683,
#   'ytm': -1.3592,
#   'yl': 5.0601,
#   'dl': 136.862,
#   'ia': 1},
#  '2020-10-26': {'cpr': 13.4146,
#   'dp': 125.601,
#   'bl': 7.9976,
#   'trt': 3.5747,
#   'ytm': -1.6653,
#   'yl': 5.0519,
#   'dl': 139.0156,
#   'ia': 1},
#  '2020-10-27': {'cpr': 12.7835,
#   'dp': 125.71,
#   'bl': 7.9976,
#   'trt': 2.8799,
#   'ytm': -1.6835,
#   'yl': 5.0492,
#   'dl': 138.49349999999998,
#   'ia': 1},
#  '2020-10-28': {'cpr': 14.5477,
#   'dp': 127.02,
#   'bl': 7.9976,
#   'trt': 8.4389,
#   'ytm': -1.8906,
#   'yl': 5.0464,
#   'dl': 141.5677,
#   'ia': 1},
#  '2020-10-29': {'cpr': 16.3271,
#   'dp': 123.66,
#   'bl': 7.9976,
#   'trt': 6.548,
#   'ytm': -1.3573,
#   'yl': 5.0437,
#   'dl': 139.9871,
#   'ia': 1},
#  '2020-10-30': {'cpr': 19.825,
#   'dp': 122.4,
#   'bl': 7.9976,
#   'trt': 2.4433,
#   'ytm': -1.1529,
#   'yl': 5.041,
#   'dl': 142.225,
#   'ia': 1},
#  '2020-11-02': {'cpr': 21.22,
#   'dp': 121.22,
#   'bl': 7.9976,
#   'trt': 1.4632,
#   'ytm': -0.9601,
#   'yl': 5.0328,
#   'dl': 142.44,
#   'ia': 1},
#  '2020-11-03': {'cpr': 17.533,
#   'dp': 124.1,
#   'bl': 7.9976,
#   'trt': 6.4193,
#   'ytm': -1.4322,
#   'yl': 5.0301,
#   'dl': 141.63299999999998,
#   'ia': 1},
#  '2020-11-04': {'cpr': 18.833,
#   'dp': 123.6,
#   'bl': 7.9976,
#   'trt': 0.6627,
#   'ytm': -1.352,
#   'yl': 5.0273,
#   'dl': 142.433,
#   'ia': 1},
#  '2020-11-05': {'cpr': 17.2764,
#   'dp': 122.821,
#   'bl': 7.9976,
#   'trt': 1.2749,
#   'ytm': -1.2258,
#   'yl': 5.0246,
#   'dl': 140.0974,
#   'ia': 1},
#  '2020-11-06': {'cpr': 19.7837,
#   'dp': 122.701,
#   'bl': 7.9976,
#   'trt': 0.8423,
#   'ytm': -1.2068,
#   'yl': 5.0219,
#   'dl': 142.4847,
#   'ia': 1},
#  '2020-11-09': {'cpr': 15.9939,
#   'dp': 125.3,
#   'bl': 7.9976,
#   'trt': 5.6098,
#   'ytm': -1.6301,
#   'yl': 5.0137,
#   'dl': 141.2939,
#   'ia': 1},
#  '2020-11-10': {'cpr': 14.3251,
#   'dp': 124.48,
#   'bl': 7.9975,
#   'trt': 2.398,
#   'ytm': -1.4992,
#   'yl': 5.0109,
#   'dl': 138.8051,
#   'ia': 1},
#  '2020-11-11': {'cpr': 15.9621,
#   'dp': 123.272,
#   'bl': 7.9975,
#   'trt': 0.896,
#   'ytm': -1.3038,
#   'yl': 5.0082,
#   'dl': 139.2341,
#   'ia': 1},
#  '2020-11-12': {'cpr': 13.5511,
#   'dp': 123.8,
#   'bl': 7.9975,
#   'trt': 1.7758,
#   'ytm': -1.3906,
#   'yl': 5.0055,
#   'dl': 137.3511,
#   'ia': 1},
#  '2020-11-13': {'cpr': 15.6914,
#   'dp': 123.15,
#   'bl': 7.9975,
#   'trt': 1.2556,
#   'ytm': -1.2853,
#   'yl': 5.0027,
#   'dl': 138.8414,
#   'ia': 1},
#  '2020-11-16': {'cpr': 16.4912,
#   'dp': 123.0,
#   'bl': 7.9975,
#   'trt': 1.1504,
#   'ytm': -1.3447,
#   'yl': 4.9945,
#   'dl': 139.4912,
#   'ia': 1},
#  '2020-11-17': {'cpr': 14.5631,
#   'dp': 120.8,
#   'bl': 7.9975,
#   'trt': 1.2317,
#   'ytm': -0.9816,
#   'yl': 4.9918,
#   'dl': 135.3631,
#   'ia': 1},
#  '2020-11-18': {'cpr': 11.7992,
#   'dp': 123.812,
#   'bl': 7.9975,
#   'trt': 9.8543,
#   'ytm': -1.4786,
#   'yl': 4.989,
#   'dl': 135.6112,
#   'ia': 1},
#  '2020-11-19': {'cpr': 11.5807,
#   'dp': 123.57,
#   'bl': 7.9975,
#   'trt': 1.9535,
#   'ytm': -1.4401,
#   'yl': 4.9863,
#   'dl': 135.1507,
#   'ia': 1},
#  '2020-11-20': {'cpr': 11.3715,
#   'dp': 123.498,
#   'bl': 7.9975,
#   'trt': 1.0404,
#   'ytm': -1.4291,
#   'yl': 4.9836,
#   'dl': 134.86950000000002,
#   'ia': 1},
#  '2020-11-23': {'cpr': 12.3907,
#   'dp': 123.501,
#   'bl': 7.9975,
#   'trt': 1.0048,
#   'ytm': -1.432,
#   'yl': 4.9753,
#   'dl': 135.89170000000001,
#   'ia': 1},
#  '2020-11-24': {'cpr': 13.9753,
#   'dp': 124.589,
#   'bl': 7.9975,
#   'trt': 0.5057,
#   'ytm': -1.6097,
#   'yl': 4.9726,
#   'dl': 138.5643,
#   'ia': 1},
#  '2020-11-25': {'cpr': 13.3802,
#   'dp': 124.101,
#   'bl': 7.9975,
#   'trt': 0.7435,
#   'ytm': -1.5314,
#   'yl': 4.9699,
#   'dl': 137.4812,
#   'ia': 1},
#  '2020-11-26': {'cpr': 16.3481,
#   'dp': 123.349,
#   'bl': 7.9975,
#   'trt': 0.3445,
#   'ytm': -1.4095,
#   'yl': 4.9671,
#   'dl': 139.6971,
#   'ia': 1},
#  '2020-11-27': {'cpr': 16.2402,
#   'dp': 122.402,
#   'bl': 7.9975,
#   'trt': 0.8571,
#   'ytm': -1.2543,
#   'yl': 4.9644,
#   'dl': 138.6422,
#   'ia': 1},
#  '2020-11-30': {'cpr': 13.0997,
#   'dp': 123.956,
#   'bl': 7.9975,
#   'trt': 2.595,
#   'ytm': -1.5121,
#   'yl': 4.9562,
#   'dl': 137.0557,
#   'ia': 1},
#  '2020-12-01': {'cpr': 13.1551,
#   'dp': 125.8,
#   'bl': 7.9975,
#   'trt': 1.6343,
#   'ytm': -1.8114,
#   'yl': 4.9534,
#   'dl': 138.9551,
#   'ia': 1},
#  '2020-12-02': {'cpr': 10.9466,
#   'dp': 128.59,
#   'bl': 7.9975,
#   'trt': 5.8496,
#   'ytm': -2.2544,
#   'yl': 4.9507,
#   'dl': 139.5366,
#   'ia': 1},
#  '2020-12-03': {'cpr': 10.6911,
#   'dp': 128.611,
#   'bl': 7.9975,
#   'trt': 2.1335,
#   'ytm': -2.2589,
#   'yl': 4.9479,
#   'dl': 139.3021,
#   'ia': 1},
#  '2020-12-04': {'cpr': 16.2398,
#   'dp': 124.4,
#   'bl': 7.9974,
#   'trt': 3.7259,
#   'ytm': -1.5879,
#   'yl': 4.9452,
#   'dl': 140.6398,
#   'ia': 1},
#  '2020-12-07': {'cpr': 18.4206,
#   'dp': 123.68,
#   'bl': 7.9974,
#   'trt': 0.5785,
#   'ytm': -1.4727,
#   'yl': 4.937,
#   'dl': 142.10060000000001,
#   'ia': 1},
#  '2020-12-08': {'cpr': 16.0987,
#   'dp': 123.75,
#   'bl': 7.9974,
#   'trt': 1.4611,
#   'ytm': -1.485,
#   'yl': 4.9342,
#   'dl': 139.8487,
#   'ia': 1},
#  '2020-12-09': {'cpr': 19.4048,
#   'dp': 122.484,
#   'bl': 7.9974,
#   'trt': 0.3446,
#   'ytm': -1.2764,
#   'yl': 4.9315,
#   'dl': 141.8888,
#   'ia': 1},
#  '2020-12-10': {'cpr': 17.9842,
#   'dp': 122.21,
#   'bl': 7.9974,
#   'trt': 0.6549,
#   'ytm': -1.2314,
#   'yl': 4.9288,
#   'dl': 140.1942,
#   'ia': 1},
#  '2020-12-11': {'cpr': 22.7468,
#   'dp': 121.34,
#   'bl': 7.9974,
#   'trt': 0.7499,
#   'ytm': -1.0861,
#   'yl': 4.926,
#   'dl': 144.0868,
#   'ia': 1},
#  '2020-12-14': {'cpr': 21.9087,
#   'dp': 121.21,
#   'bl': 7.9974,
#   'trt': 0.6404,
#   'ytm': -1.066,
#   'yl': 4.9178,
#   'dl': 143.1187,
#   'ia': 1},
#  '2020-12-15': {'cpr': 21.2747,
#   'dp': 119.711,
#   'bl': 7.9974,
#   'trt': 1.3765,
#   'ytm': -0.8111,
#   'yl': 4.9151,
#   'dl': 140.9857,
#   'ia': 1},
#  '2020-12-16': {'cpr': 20.3774,
#   'dp': 115.721,
#   'bl': 7.9974,
#   'trt': 0.8783,
#   'ytm': -0.1116,
#   'yl': 4.9123,
#   'dl': 136.0984,
#   'ia': 1},
#  '2020-12-17': {'cpr': 19.5262,
#   'dp': 117.3,
#   'bl': 7.9974,
#   'trt': 1.0288,
#   'ytm': -0.3923,
#   'yl': 4.9096,
#   'dl': 136.8262,
#   'ia': 1},
#  '2020-12-18': {'cpr': 22.3566,
#   'dp': 118.5,
#   'bl': 7.9974,
#   'trt': 1.8411,
#   'ytm': -0.6028,
#   'yl': 4.9068,
#   'dl': 140.85660000000001,
#   'ia': 1},
#  '2020-12-21': {'cpr': 19.3128,
#   'dp': 118.8,
#   'bl': 7.9974,
#   'trt': 1.3101,
#   'ytm': -0.6561,
#   'yl': 4.8986,
#   'dl': 138.1128,
#   'ia': 1},
#  '2020-12-22': {'cpr': 20.8186,
#   'dp': 115.972,
#   'bl': 7.9974,
#   'trt': 2.1754,
#   'ytm': -0.157,
#   'yl': 4.8959,
#   'dl': 136.79059999999998,
#   'ia': 1},
#  '2020-12-23': {'cpr': 20.6319,
#   'dp': 115.62,
#   'bl': 7.9974,
#   'trt': 0.866,
#   'ytm': -0.0939,
#   'yl': 4.8932,
#   'dl': 136.2519,
#   'ia': 1},
#  '2020-12-24': {'cpr': 24.8368,
#   'dp': 115.0,
#   'bl': 7.9974,
#   'trt': 1.4121,
#   'ytm': 0.0181,
#   'yl': 4.8904,
#   'dl': 139.8368,
#   'ia': 1},
#  '2020-12-25': {'cpr': 26.0255,
#   'dp': 114.109,
#   'bl': 7.9974,
#   'trt': 1.3467,
#   'ytm': 0.1805,
#   'yl': 4.8877,
#   'dl': 140.1345,
#   'ia': 1},
#  '2020-12-28': {'cpr': 27.1637,
#   'dp': 113.5,
#   'bl': 7.9974,
#   'trt': 0.9607,
#   'ytm': 0.2929,
#   'yl': 4.8795,
#   'dl': 140.6637,
#   'ia': 1},
#  '2020-12-29': {'cpr': 25.2622,
#   'dp': 112.7,
#   'bl': 7.9974,
#   'trt': 0.2055,
#   'ytm': 0.4415,
#   'yl': 4.8767,
#   'dl': 137.9622,
#   'ia': 1},
#  '2020-12-30': {'cpr': 24.1396,
#   'dp': 112.935,
#   'bl': 7.9974,
#   'trt': 0.8826,
#   'ytm': 0.398,
#   'yl': 4.874,
#   'dl': 137.0746,
#   'ia': 1},
#  '2020-12-31': {'cpr': 25.4435,
#   'dp': 114.301,
#   'bl': 7.9974,
#   'trt': 1.178,
#   'ytm': 0.1459,
#   'yl': 4.8712,
#   'dl': 139.74450000000002,
#   'ia': 1},
#  '2021-01-04': {'cpr': 26.7721,
#   'dp': 116.238,
#   'bl': 7.9974,
#   'trt': 1.7735,
#   'ytm': -0.2061,
#   'yl': 4.8603,
#   'dl': 143.0101,
#   'ia': 1},
#  '2021-01-05': {'cpr': 29.8897,
#   'dp': 117.98,
#   'bl': 7.9974,
#   'trt': 1.3246,
#   'ytm': -0.5173,
#   'yl': 4.8575,
#   'dl': 147.8697,
#   'ia': 1},
#  '2021-01-06': {'cpr': 32.2389,
#   'dp': 115.567,
#   'bl': 7.9974,
#   'trt': 1.8459,
#   'ytm': -0.085,
#   'yl': 4.8548,
#   'dl': 147.8059,
#   'ia': 1},
#  '2021-01-07': {'cpr': 36.4111,
#   'dp': 115.5,
#   'bl': 7.9974,
#   'trt': 2.3862,
#   'ytm': -0.0729,
#   'yl': 4.8521,
#   'dl': 151.9111,
#   'ia': 1},
#  '2021-01-08': {'cpr': 30.9227,
#   'dp': 116.48,
#   'bl': 7.9974,
#   'trt': 1.2228,
#   'ytm': -0.2502,
#   'yl': 4.8493,
#   'dl': 147.4027,
#   'ia': 1},
#  '2021-01-11': {'cpr': 31.0006,
#   'dp': 117.3,
#   'bl': 7.9974,
#   'trt': 1.491,
#   'ytm': -0.3979,
#   'yl': 4.8411,
#   'dl': 148.3006,
#   'ia': 1},
#  '2021-01-12': {'cpr': 26.7057,
#   'dp': 118.9,
#   'bl': 7.9973,
#   'trt': 2.6945,
#   'ytm': -0.682,
#   'yl': 4.8384,
#   'dl': 145.6057,
#   'ia': 1},
#  '2021-01-13': {'cpr': 29.1778,
#   'dp': 118.999,
#   'bl': 7.9973,
#   'trt': 0.8652,
#   'ytm': -0.6998,
#   'yl': 4.8356,
#   'dl': 148.1768,
#   'ia': 1},
#  '2021-01-14': {'cpr': 31.2591,
#   'dp': 119.6,
#   'bl': 7.9973,
#   'trt': 0.772,
#   'ytm': -0.8057,
#   'yl': 4.8329,
#   'dl': 150.85909999999998,
#   'ia': 1},
#  '2021-01-15': {'cpr': 31.993,
#   'dp': 117.054,
#   'bl': 7.9973,
#   'trt': 0.859,
#   'ytm': -0.3547,
#   'yl': 4.8301,
#   'dl': 149.047,
#   'ia': 1},
#  '2021-01-18': {'cpr': 31.7153,
#   'dp': 117.94,
#   'bl': 7.9973,
#   'trt': 0.465,
#   'ytm': -0.514,
#   'yl': 4.8219,
#   'dl': 149.6553,
#   'ia': 1},
#  '2021-01-19': {'cpr': 32.5963,
#   'dp': 117.399,
#   'bl': 7.9973,
#   'trt': 0.8425,
#   'ytm': -0.4175,
#   'yl': 4.8192,
#   'dl': 149.9953,
#   'ia': 1},
#  '2021-01-20': {'cpr': 34.989,
#   'dp': 116.81,
#   'bl': 7.9973,
#   'trt': 0.6284,
#   'ytm': -0.3117,
#   'yl': 4.8164,
#   'dl': 151.799,
#   'ia': 1},
#  '2021-01-21': {'cpr': 32.3296,
#   'dp': 118.49,
#   'bl': 7.9973,
#   'trt': 2.5972,
#   'ytm': -0.6129,
#   'yl': 4.8137,
#   'dl': 150.81959999999998,
#   'ia': 1},
#  '2021-01-22': {'cpr': 34.3621,
#   'dp': 118.0,
#   'bl': 7.9973,
#   'trt': 0.1966,
#   'ytm': -0.5259,
#   'yl': 4.811,
#   'dl': 152.3621,
#   'ia': 1},
#  '2021-01-25': {'cpr': 32.4179,
#   'dp': 118.0,
#   'bl': 7.9973,
#   'trt': 0.6689,
#   'ytm': -0.5269,
#   'yl': 4.8027,
#   'dl': 150.4179,
#   'ia': 1},
#  '2021-01-26': {'cpr': 31.7016,
#   'dp': 114.72,
#   'bl': 7.9973,
#   'trt': 2.1647,
#   'ytm': 0.0703,
#   'yl': 4.8,
#   'dl': 146.4216,
#   'ia': 1},
#  '2021-01-27': {'cpr': 33.3732,
#   'dp': 113.501,
#   'bl': 7.9973,
#   'trt': 0.6351,
#   'ytm': 0.2978,
#   'yl': 4.7973,
#   'dl': 146.8742,
#   'ia': 1},
#  '2021-01-28': {'cpr': 26.1381,
#   'dp': 111.681,
#   'bl': 7.9973,
#   'trt': 0.6148,
#   'ytm': 0.6435,
#   'yl': 4.7945,
#   'dl': 137.8191,
#   'ia': 1},
#  '2021-01-29': {'cpr': 22.7861,
#   'dp': 111.0,
#   'bl': 7.9973,
#   'trt': 8.624,
#   'ytm': 0.7751,
#   'yl': 4.7918,
#   'dl': 133.7861,
#   'ia': 1},
#  '2021-02-01': {'cpr': 24.6513,
#   'dp': 108.936,
#   'bl': 7.9973,
#   'trt': 1.6493,
#   'ytm': 1.1807,
#   'yl': 4.7836,
#   'dl': 133.5873,
#   'ia': 1},
#  '2021-02-02': {'cpr': 25.1022,
#   'dp': 107.0,
#   'bl': 7.9973,
#   'trt': 2.3778,
#   'ytm': 1.5694,
#   'yl': 4.7808,
#   'dl': 132.1022,
#   'ia': 1},
#  '2021-02-03': {'cpr': 20.0559,
#   'dp': 107.5,
#   'bl': 7.9973,
#   'trt': 1.0696,
#   'ytm': 1.4693,
#   'yl': 4.7781,
#   'dl': 127.55590000000001,
#   'ia': 1},
#  '2021-02-04': {'cpr': 17.8503,
#   'dp': 106.538,
#   'bl': 7.9973,
#   'trt': 2.0097,
#   'ytm': 1.6653,
#   'yl': 4.7753,
#   'dl': 124.3883,
#   'ia': 1},
#  '2021-02-05': {'cpr': 19.6408,
#   'dp': 104.9,
#   'bl': 7.9973,
#   'trt': 3.6283,
#   'ytm': 2.0038,
#   'yl': 4.7726,
#   'dl': 124.5408,
#   'ia': 1},
#  '2021-02-08': {'cpr': 20.1663,
#   'dp': 104.5,
#   'bl': 7.9973,
#   'trt': 0.8528,
#   'ytm': 2.0909,
#   'yl': 4.7644,
#   'dl': 124.6663,
#   'ia': 1},
#  ...}
