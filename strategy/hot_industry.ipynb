# %%
# set up
import pandas as pd
import numpy as np
import pickle
import time 
import os
import matplotlib.pyplot as plt
import datetime
from operator import itemgetter
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from pylab import *
from matplotlib.font_manager import FontProperties
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use("ggplot")
data_folder_path = 'C:\\Users\\goodluck\\Desktop\\DB'
raw_data_path =  "C:\\Users\\goodluck\\Desktop\\DB\\raw_data"
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
DTBS_path = os.path.join(storage_path, "DTBS.pkl")
font = FontProperties(fname=r"simsun.ttf", size=14)  
matplotlib.rcParams['axes.unicode_minus'] =False
mpl.rcParams['font.sans-serif'] = ['SimHei']
tick_spacing = 4

# re-open
with open(DTBS_path, 'rb') as f:  
    DTBS = pickle.load(f)
    
# helper -- days
def select_days(s_d, e_d, wkd, gap):
    days = []
    flag = 0
    sdt = datetime.datetime.strptime(s_d, '%Y-%m-%d').date()
    edt = datetime.datetime.strptime(e_d, '%Y-%m-%d').date()
    for day in DTBS['D']['day']:
        cdt =  datetime.datetime.strptime(day, '%Y-%m-%d').date()
        if cdt >= sdt:
            flag = 1
        
        if cdt == edt:
            days.append(day)
            break
        
        if cdt > edt:
            break 
            
        if flag == 1:
            days.append(day)
            
    s_days = []
    count = 0
    for day in days:
        if day in DTBS['D'][wkd]:
            if count % gap == 0:
                s_days.append(day)
                
            count += 1
    
    
    return s_days

f20wm = select_days('2020-01-01', '2020-06-30', 'mon', 1)
f20fm = select_days('2020-01-01', '2020-06-30', 'mon', 2)
f20mm = select_days('2020-01-01', '2020-06-30', 'mon', 4)
s20wm = select_days('2020-07-01', '2020-12-31', 'mon', 1)
s20fm = select_days('2020-07-01', '2020-12-31', 'mon', 2)
s20mm = select_days('2020-07-01', '2020-12-31', 'mon', 4)
f21wm = select_days('2021-01-01', '2021-06-30', 'mon', 1)
f21fm = select_days('2021-01-01', '2021-06-30', 'mon', 2)
f21mm = select_days('2021-01-01', '2021-06-30', 'mon', 4)
s21wm = select_days('2021-07-01', '2021-12-31', 'mon', 1)
s21fm = select_days('2021-07-01', '2021-12-31', 'mon', 2)
s21mm = select_days('2021-07-01', '2021-12-31', 'mon', 4)
f22wm = select_days('2022-01-01', '2022-06-30', 'mon', 1)
f22fm = select_days('2022-01-01', '2022-06-30', 'mon', 2)
f22mm = select_days('2022-01-01', '2022-06-30', 'mon', 4)
s22wm = select_days('2022-07-01', '2022-12-31', 'mon', 1)
s22ww = select_days('2022-07-01', '2022-12-31', 'wed', 1)
s22fm = select_days('2022-07-01', '2022-12-31', 'mon', 2)
s22mm = select_days('2022-07-01', '2022-12-31', 'mon', 4)
f23wm = select_days('2023-01-01', '2023-04-17', 'mon', 1)
f23fm = select_days('2023-01-01', '2023-04-17', 'mon', 2)
f23mm = select_days('2023-01-01', '2023-04-17', 'mon', 4)
f23ww = select_days('2023-01-01', '2023-04-19', 'wed', 1)
f23mm.append('2023-04-10')
a20wm = select_days('2020-01-01', '2020-12-31', 'mon', 1)
a20fm = select_days('2020-01-01', '2020-12-31', 'mon', 2)
a20mm = select_days('2020-01-01', '2020-12-31', 'mon', 4)
a21wm = select_days('2021-01-01', '2021-12-31', 'mon', 1)
a21fm = select_days('2021-01-01', '2021-12-31', 'mon', 2)
a21mm = select_days('2021-01-01', '2021-12-31', 'mon', 4)
a22wm = select_days('2022-01-01', '2022-12-31', 'mon', 1)
a22fm = select_days('2022-01-01', '2022-12-31', 'mon', 2)
a22mm = select_days('2022-01-01', '2022-12-31', 'mon', 4)

a22wm = select_days('2022-01-01', '2022-12-31', 'mon', 1)
a22wt = select_days('2022-01-01', '2022-12-31', 'tue', 1)
a22ww = select_days('2022-01-01', '2022-12-31', 'wed', 1)
a22wh = select_days('2022-01-01', '2022-12-31', 'thu', 1)
a22wf = select_days('2022-01-01', '2022-12-31', 'fri', 1)



hywm = [f20wm, s20wm, f21wm, s21wm, f22wm, s22ww, f23ww]
hyfm = [f20fm, s20fm, f21fm, s21fm, f22fm, s22fm, f23fm]
hymm = [f20mm, s20mm, f21mm, s21mm, f22mm, s22mm, f23mm]
test = ['2023-04-12','2023-04-19']

# helper -- others

def sharpe(profit):
    avg_rate = np.mean(profit)
    std_rate = np.std(profit)
    Sharpe_Ratio = (avg_rate * 52 -0.028397) / (std_rate * sqrt(52))
    return(Sharpe_Ratio)


def down(profit):
    return_list = [i+1 for i in profit]
    i = np.argmax((np.maximum.accumulate(return_list) - return_list))
    if i == 0:
        return 0
    j = np.argmax(return_list[:i])  # 开始位置
    drawdown_rate = (return_list[j] - return_list[i]) / return_list[j]
    return drawdown_rate


def vola(profit):
    log_return_list = [log(i+1) for i in profit]
    Volatility = std(log_return_list) / sqrt(5)
    annualVolatility = Volatility * sqrt(252) 
    return annualVolatility


def select_group(nm, dt, codes, grp):
    select = []
    if nm == 'id':
        for code in codes:
            if DTBS['B'][code]['cat1'] == grp:
                select.append(code)
    elif nm == 'pr':
        for code in codes:
            if DTBS['A'][code][dt]['dp'] >= grp[0] and DTBS['A'][code][dt]['dp'] <= grp[1]:
                select.append(code)
                
    else:
        for code in codes:
            if DTBS['B'][code]['cat1']  == grp[0]:
                if DTBS['A'][code][dt]['dp'] >= grp[1][0] and DTBS['A'][code][dt]['dp'] <= grp[1][1]:
                    select.append(code)
    return select


def transform_group(grps):
    if len(grps) == 1:
        return grps[0]
    else:
        grp = ['idpr', []]
        for cd1 in grps[0][1]:
            for cd2 in grps[1][1]:
                grp[1].append((cd1, cd2))
        
        return grp
    
def ipo(codes, dt):
    exist = []
    for code in codes:
        if datetime.datetime.strptime(DTBS['B'][code]['ipo'], '%Y-%m-%d') >= (datetime.datetime.strptime(dt, '%Y-%m-%d') + datetime.timedelta(days=-180)):
            exist.append(code)
             
    return exist
    
def select_existing(dt):
    exist = []
    for code in DTBS['A'].keys():
        if DTBS['A'][code][dt]['ia'] == 1:
            exist.append(code)
            
    return exist

def get_prcs(code, dts):
    prc = []
    for dt in dts:
        prc.append(DTBS['A'][code][dt]['dp'])
    prc.sort()
    return prc
    
def relative_low(lst, pos):
    return np.quantile(a=lst, q = pos)
    
def absolute_low(lst, pos):
    return min(lst) + pos * (max(lst) - min(lst))

def low_prc(code, dt, lm, pos):
    prc = get_prcs(code, lm)
#     lp = min([relative_low(prc, pos), absolute_low(prc, pos)])
    lp = absolute_low(prc, pos)
    tp = DTBS['A'][code][dt]['dp']
#     if (tp <= lp):
#         print(code, tp, lp)
#     if tp <= lp:
#         print(tp, lp)
    return tp <= lp

def calculate_time(dt, d, l):
    time = []
    days = DTBS['D']['day']
    if d == 'p':
        for i in range(len(days)):
            if days[i] == dt:
                break
                
    return days[i-l+1:i+1]
            
def select_condition(codes, dt, fcd):
    satisfy = []
    if fcd[0] == 'lp':
        lm = calculate_time(dt, 'p', 20)
        
        for code in codes:
            if low_prc(code, dt, lm, fcd[1]):
                satisfy.append(code)
    elif len(fcd) == 1:
        return ipo(codes, dt)
        
    else:
        for code in codes:
            if DTBS['A'][code][dt][fcd[0]] <= fcd[2] and DTBS['A'][code][dt][fcd[0]] >= fcd[1]:
                satisfy.append(code)
                    
    return satisfy

def takeSecond(elem):
    return elem[1]


def retrieve_low_nodes(codes,dt,num):
    dl_rank = []
    for code in codes:
        if DTBS['A'][code][dt]['dl'] != 999:
            dl_rank.append((code, DTBS['A'][code][dt]['dl']))
    
    dl_rank.sort(key=takeSecond)
    low = dl_rank[0:num]
    return [i[0] for i in low]

def rank(codes, dt, idx, num, d):
    rk = []
    if num == -1:
        num = len(codes)
    for code in codes:
        if idx == 'lp':
            if not np.isnan(DTBS['A'][code][dt]['dp']):
                lm = calculate_time(dt, 'p', 20)
                prc = get_prcs(code, lm)
                lp = absolute_low(prc, 0)
                rk.append((code, DTBS['A'][code][dt]['dp']/lp))
            
            
        elif idx != 'dl':
            if not np.isnan(DTBS['A'][code][dt][idx]):
                rk.append((code, DTBS['A'][code][dt][idx]))
        else:
            if not np.isnan(DTBS['A'][code][dt][idx]):
                if DTBS['A'][code][dt][idx] != 999:
                    rk.append((code, DTBS['A'][code][dt][idx]))
    if num >= len(rk):
        num = len(rk)
        
     
#     reverse = True 降序
    if d == 'd':
        rk.sort(key=takeSecond, reverse = True)
    else:
        rk.sort(key=takeSecond, reverse = False)

    if idx == 'lp':
        lp = [i for i in rk if i[1] == 1.0]
        ot = []
        if num - len(lp) > 0:
            ot = rk[len(lp):num]
        
        low = lp + ot
        
    else:    
        low = rk[0:num]
#     print("In",dt , len(low), "of", len(codes),  "is selected")   

#     print(low)
    
    
    return [i[0] for i in low]
        
    
idts = [['农林牧渔(2021)', '基础化工(2021)', '美容护理(2021)', '通信(2021)', '非银金融(2021)', '电力设备(2021)', '汽车(2021)', '电子(2021)'], ['家用电器(2021)', '基础化工(2021)', '建筑材料(2021)', '建筑装饰(2021)', '机械设备(2021)', '商贸零售(2021)', '计算机(2021)', '国防军工(2021)', '钢铁(2021)', '传媒(2021)'], ['汽车(2021)', '交通运输(2021)', '农林牧渔(2021)', '煤炭(2021)', '有色金属(2021)', '商贸零售(2021)', '机械设备(2021)', '钢铁(2021)', '电力设备(2021)', '基础化工(2021)'], ['电力设备(2021)', '有色金属(2021)', '交通运输(2021)', '钢铁(2021)', '通信(2021)', '汽车(2021)', '基础化工(2021)', '轻工制造(2021)', '国防军工(2021)', '医药生物(2021)'], ['有色金属(2021)', '机械社保(2021)', '基础化工(2021)', '农林牧渔(2021)', '汽车(2021)', '交通运输(2021)', '国防军工(2021)', '医药生物(2021)', '通信(2021)', '电力设备(2021)'], ['有色金属(2021)', '农林牧渔(2021)', '汽车(2021)', '电力设备(2021)', '公用事业(2021)', '社会服务(2021)', '食品饮料(2021)', '医药生物(2021)', '轻工制造(2021)', '建筑材料(2021)'], ['建筑材料(2021)', '建筑装饰(2021)', '国防军工(2021)', '计算机(2021)', '通信(2021)', '食品饮料(2021)', '社会服务(2021)', '纺织服饰(2021)', '交通运输(2021)', '轻工制造(2021)']]

# plot

def plot_profit(days, profit, mk_one, market = DTBS['C'], tt = '收益率'):
    plt.figure(figsize=(80,60))
    

        
    fig, ax = plt.subplots(1,1)
#     plt.plot(days[1:], one_profit, linestyle='dashdot',label='价格110-130+50%低价+市值<3+转股溢价率<50:低价前5')
    plt.plot(days[1:], profit, linestyle='dashdot',label='策略收益率')
    
    i_x = [days[1], days[-1]]

#     market_gain = (market['zi'][days[-1]]-market['zi'][days[0]])/(market['zi'][days[0]])
#     i_y = [0, market_gain]
#     plt.plot(i_x, i_y, linestyle='solid',label='中正转债指数')
    plt.plot(days[1:], mk_one, linestyle='solid',label='中证转债指数')
    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
    plt.ylabel('Increase per year/%')

    # 'dashed'
    #‘dotted'
    # 'dashdot'
    # 'solid'

    
    plt.legend(fontsize = 'x-small')

    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
#     plt.ylabel('收益率/%')
    plt.ylabel("increase per year/%")
#     tt = '收益率'
    plt.title(tt)
    plt.savefig(tt, dpi=300)
#     plt.show()
#     print("Final gain", profit[-1], ',',"Market gain", market_gain)

# statistics

def win_stat(res, mk):
    print("Max profit", max(res), ", Max loss", min(res))
    wins = []
    win = 0
    count = 0
    winm = 0
    winsm  = []
    summ = 0
    mksum = 0    
    for i in range(len(res)):
        if res[i] >= mk[i]:
            win += 1
            wins.append(True)
        else:
            wins.append(False)
        
        summ += res[i]
        mksum += mk[i]
        if (count + 1) % 4 == 0:
            if summ >= mksum:
                winm += 1
                winsm.append(True)
            else:
                winsm.append(False)
                
            summ = 0
            mksum = 0
            
        count += 1
    win_rate = win/len(res)
    winm_rate = winm/len(winsm)
    print("Weekly win rate & details", win_rate, ", ", wins)
    print("Monthly win rate & details", winm_rate,", ", winsm)

# calculate
def cumulative_profit(days, grp_cd, flt_cd, rk_cd):
    cm_profit = []
    one_profit = []
    all_select = []
    sum_profit = 0
    lock = False
    for i in range(len(days)): 
        if i+1 == len(days):
            exist = select_existing(days[i])
            
            
        else: 
            exist_tr = select_existing(days[i])
            exist_nr = select_existing(days[i+1])
            exist =list(set(exist_tr).intersection(set(exist_nr)))

        select = exist.copy()
        candidate = []
        if grp_cd != []:
            grp = transform_group(grp_cd)
            for cd in grp[1]:
                select = exist.copy()
                select = select_group(grp[0], days[i], select, cd)
                for fcd in flt_cd:
                    select = select_condition(select, days[i], fcd)
                for rk in rk_cd:
                    select = rank(select, days[i], rk[0], rk[1], rk[2])                  
                for cd in select:
                    candidate.append(cd)
                    
                
                            

        
        else: 
            for fcd in flt_cd:
                select = select_condition(select, days[i], fcd)
            for rk in rk_cd:
                select = rank(select, days[i], rk[0], rk[1], rk[2])    
#             if dl > 0:
#                 select = retrieve_low_nodes(select, days[i], dl)
                
            candidate = select.copy()    
        
        if avoid(days[i]) <-3.68:
            lock = True
            
        if lock == True and avoid(days[i]) >- 2.9:
            lock = False
            
        if lock == True:
            candidate = []
#         print(days[i], len(candidate))
        all_select.append(candidate)
#         print(days[i], candidate)
        
#         dl = []
#         for cd in candidate:
#             dl.append(DTBS['A'][cd][days[i]]['dl'])
#         for cd in candidate:
#             dl.append(DTBS['A'][cd][days[i]]['dp'])
            
#         for cd in candidate:
#             dl.append(DTBS['A'][cd][days[i]]['bl'])
#         print(days[i], candidate, dl)
        dl = []
        if i >= 1:
        
            tr = 0
            lr = 0
#
            for cd in all_select[i-1]:
                tr += DTBS['A'][cd][days[i]]['dp']
                lr += DTBS['A'][cd][days[i-1]]['dp']
            if len(all_select[i-1]) == 0:
                profit = 0
                print("short position in", days[i-1])
            else:
                profit = ((tr - lr)/ lr)
            one_profit.append(profit)

            sum_profit += profit

                
            cm_profit.append(sum_profit)


    return cm_profit, one_profit    


def avoid(dt):
    return False
    c = []
    for code in DTBS['A'].keys():
        if DTBS['A'][code][dt]['ia'] == 1:
#             if DTBS['A'][code][dt]['dp'] >= 120 and DTBS['A'][code][dt]['dp'] <= 130:
            if DTBS['A'][code][dt]['pd'] >= -20 and  DTBS['A'][code][dt]['pd'] <= 20:
                if not np.isnan(DTBS['A'][code][dt]['ytm']):
                    c.append(DTBS['A'][code][dt]['ytm'] )
#                 c.append(DTBS['A'][code][dt]['cpr'] + DTBS['A'][code][dt]['dp'])
                
    m = np.mean(c)
    
#     return m < -4

    return m

# %%
for code in DTBS['A'].keys():
    
    if DTBS['A'][code]['2023-06-26']['ia'] == 1:
        print(DTBS['B'][code]['cat1'],DTBS['B'][code]['cat2'])
# Out:
# 煤炭(2021) 煤炭开采(2021)
# 煤炭(2021) 焦炭Ⅱ(2021)
# 公用事业(2021) 燃气Ⅱ(2021)
# 公用事业(2021) 燃气Ⅱ(2021)
# 石油石化(2021) 炼化及贸易(2021)
# 煤炭(2021) 煤炭开采(2021)
# 煤炭(2021) 焦炭Ⅱ(2021)
# 轻工制造(2021) 造纸(2021)
# 轻工制造(2021) 造纸(2021)
# 钢铁(2021) 普钢(2021)
# 基础化工(2021) 化学原料(2021)
# 基础化工(2021) 农化制品(2021)
# 基础化工(2021) 化学纤维(2021)
# 建筑材料(2021) 玻璃玻纤(2021)
# 轻工制造(2021) 造纸(2021)
# 基础化工(2021) 化学纤维(2021)
# 基础化工(2021) 化学制品(2021)
# 基础化工(2021) 塑料(2021)
# 有色金属(2021) 工业金属(2021)
# 有色金属(2021) 工业金属(2021)
# 有色金属(2021) 工业金属(2021)
# 建筑材料(2021) 玻璃玻纤(2021)
# 钢铁(2021) 普钢(2021)
# 电力设备(2021) 光伏设备(2021)
# 基础化工(2021) 塑料(2021)
# 有色金属(2021) 工业金属(2021)
# 机械设备(2021) 通用设备(2021)
# 轻工制造(2021) 包装印刷(2021)
# 轻工制造(2021) 包装印刷(2021)
# 有色金属(2021) 金属新材料(2021)
# 建筑装饰(2021) 专业工程(2021)
# 基础化工(2021) 橡胶(2021)
# 基础化工(2021) 化学纤维(2021)
# 轻工制造(2021) 造纸(2021)
# 钢铁(2021) 特钢Ⅱ(2021)
# 纺织服饰(2021) 纺织制造(2021)
# 基础化工(2021) 农化制品(2021)
# 有色金属(2021) 能源金属(2021)
# 基础化工(2021) 农化制品(2021)
# 基础化工(2021) 化学制品(2021)
# 基础化工(2021) 化学制品(2021)
# 建筑材料(2021) 玻璃玻纤(2021)
# 基础化工(2021) 化学制品(2021)
# 电力设备(2021) 电池(2021)
# 电力设备(2021) 电池(2021)
# 基础化工(2021) 化学制品(2021)
# 电力设备(2021) 光伏设备(2021)
# 医药生物(2021) 医疗器械(2021)
# 基础化工(2021) 塑料(2021)
# 电力设备(2021) 电池(2021)
# 电力设备(2021) 电池(2021)
# 钢铁(2021) 特钢Ⅱ(2021)
# 基础化工(2021) 塑料(2021)
# 基础化工(2021) 化学制品(2021)
# 有色金属(2021) 工业金属(2021)
# 基础化工(2021) 塑料(2021)
# 电子(2021) 电子化学品Ⅱ(2021)
# 基础化工(2021) 橡胶(2021)
# 基础化工(2021) 化学制品(2021)
# 电子(2021) 电子化学品Ⅱ(2021)
# 电子(2021) 电子化学品Ⅱ(2021)
# 有色金属(2021) 工业金属(2021)
# 建筑材料(2021) 玻璃玻纤(2021)
# 基础化工(2021) 化学制品(2021)
# 环保(2021) 环境治理(2021)
# 电子(2021) 电子化学品Ⅱ(2021)
# 基础化工(2021) 塑料(2021)
# 基础化工(2021) 化学制品(2021)
# 基础化工(2021) 塑料(2021)
# 基础化工(2021) 化学制品(2021)
# 电力设备(2021) 电池(2021)
# 基础化工(2021) 化学制品(2021)
# 基础化工(2021) 化学纤维(2021)
# 基础化工(2021) 化学原料(2021)
# 有色金属(2021) 金属新材料(2021)
# 建筑材料(2021) 水泥(2021)
# 钢铁(2021) 普钢(2021)
# 有色金属(2021) 工业金属(2021)
# 有色金属(2021) 工业金属(2021)
# 石油石化(2021) 炼化及贸易(2021)
# 建筑材料(2021) 水泥(2021)
# 石油石化(2021) 炼化及贸易(2021)
# 基础化工(2021) 农化制品(2021)
# 建筑材料(2021) 装修建材(2021)
# 轻工制造(2021) 包装印刷(2021)
# 基础化工(2021) 农化制品(2021)
# 有色金属(2021) 工业金属(2021)
# 基础化工(2021) 橡胶(2021)
# 钢铁(2021) 特钢Ⅱ(2021)
# 基础化工(2021) 橡胶(2021)
# 建筑材料(2021) 装修建材(2021)
# 石油石化(2021) 炼化及贸易(2021)
# 有色金属(2021) 工业金属(2021)
# 钢铁(2021) 冶钢原料(2021)
# 电力设备(2021) 电池(2021)
# 基础化工(2021) 化学制品(2021)
# 基础化工(2021) 化学纤维(2021)
# 基础化工(2021) 橡胶(2021)
# 轻工制造(2021) 包装印刷(2021)
# 轻工制造(2021) 家居用品(2021)
# 轻工制造(2021) 包装印刷(2021)
# 有色金属(2021) 小金属(2021)
# 轻工制造(2021) 包装印刷(2021)
# 有色金属(2021) 工业金属(2021)
# 基础化工(2021) 化学原料(2021)
# 电力设备(2021) 电池(2021)
# 有色金属(2021) 工业金属(2021)
# 有色金属(2021) 小金属(2021)
# 基础化工(2021) 塑料(2021)
# 基础化工(2021) 农化制品(2021)
# 石油石化(2021) 炼化及贸易(2021)
# 轻工制造(2021) 造纸(2021)
# 基础化工(2021) 农化制品(2021)
# 建筑材料(2021) 水泥(2021)
# 建筑装饰(2021) 房屋建设Ⅱ(2021)
# 环保(2021) 环保设备Ⅱ(2021)
# 电力设备(2021) 电网设备(2021)
# 交通运输(2021) 航空机场(2021)
# 建筑装饰(2021) 基础建设(2021)
# 电力设备(2021) 电网设备(2021)
# 建筑装饰(2021) 专业工程(2021)
# 机械设备(2021) 工程机械(2021)
# 电力设备(2021) 电网设备(2021)
# 建筑装饰(2021) 基础建设(2021)
# 轻工制造(2021) 包装印刷(2021)
# 交通运输(2021) 铁路公路(2021)
# 环保(2021) 环境治理(2021)
# 电力设备(2021) 电网设备(2021)
# 交通运输(2021) 物流(2021)
# 环保(2021) 环境治理(2021)
# 机械设备(2021) 专用设备(2021)
# 电力设备(2021) 电机Ⅱ(2021)
# 电力设备(2021) 电网设备(2021)
# 电子(2021) 光学光电子(2021)
# 建筑装饰(2021) 装修装饰Ⅱ(2021)
# 机械设备(2021) 通用设备(2021)
# 建筑装饰(2021) 基础建设(2021)
# 机械设备(2021) 通用设备(2021)
# 机械设备(2021) 专用设备(2021)
# 机械设备(2021) 专用设备(2021)
# 汽车(2021) 摩托车及其他(2021)
# 家用电器(2021) 家电零部件Ⅱ(2021)
# 机械设备(2021) 工程机械(2021)
# 轻工制造(2021) 包装印刷(2021)
# 轻工制造(2021) 家居用品(2021)
# 环保(2021) 环境治理(2021)
# 机械设备(2021) 专用设备(2021)
# 交通运输(2021) 物流(2021)
# 交通运输(2021) 物流(2021)
# 机械设备(2021) 通用设备(2021)
# 建筑装饰(2021) 基础建设(2021)
# 机械设备(2021) 通用设备(2021)
# 电力设备(2021) 光伏设备(2021)
# 环保(2021) 环境治理(2021)
# 机械设备(2021) 专用设备(2021)
# 电力设备(2021) 电网设备(2021)
# 医药生物(2021) 医疗器械(2021)
# 电力设备(2021) 电池(2021)
# 环保(2021) 环境治理(2021)
# 建筑装饰(2021) 基础建设(2021)
# 环保(2021) 环境治理(2021)
# 电力设备(2021) 电网设备(2021)
# 电力设备(2021) 电网设备(2021)
# 电子(2021) 光学光电子(2021)
# 电力设备(2021) 电网设备(2021)
# 国防军工(2021) 地面兵装Ⅱ(2021)
# 环保(2021) 环境治理(2021)
# 国防军工(2021) 航空装备Ⅱ(2021)
# 农林牧渔(2021) 农业综合Ⅱ(2021)
# 机械设备(2021) 专用设备(2021)
# 电力设备(2021) 风电设备(2021)
# 建筑装饰(2021) 专业工程(2021)
# 电力设备(2021) 电网设备(2021)
# 机械设备(2021) 自动化设备(2021)
# 基础化工(2021) 橡胶(2021)
# 机械设备(2021) 专用设备(2021)
# 机械设备(2021) 通用设备(2021)
# 国防军工(2021) 航空装备Ⅱ(2021)
# 机械设备(2021) 通用设备(2021)
# 机械设备(2021) 通用设备(2021)
# 建筑装饰(2021) 工程咨询服务Ⅱ(2021)
# 建筑装饰(2021) 工程咨询服务Ⅱ(2021)
# 电力设备(2021) 电网设备(2021)
# 电力设备(2021) 电网设备(2021)
# 环保(2021) 环境治理(2021)
# 电力设备(2021) 电网设备(2021)
# 电力设备(2021) 风电设备(2021)
# 电力设备(2021) 风电设备(2021)
# 电力设备(2021) 电网设备(2021)
# 机械设备(2021) 通用设备(2021)
# 电力设备(2021) 风电设备(2021)
# 机械设备(2021) 自动化设备(2021)
# 机械设备(2021) 通用设备(2021)
# 交通运输(2021) 铁路公路(2021)
# 建筑装饰(2021) 专业工程(2021)
# 环保(2021) 环保设备Ⅱ(2021)
# 建筑装饰(2021) 专业工程(2021)
# 建筑装饰(2021) 装修装饰Ⅱ(2021)
# 环保(2021) 环境治理(2021)
# 家用电器(2021) 家电零部件Ⅱ(2021)
# 交通运输(2021) 航运港口(2021)
# 商贸零售(2021) 贸易Ⅱ(2021)
# 机械设备(2021) 专用设备(2021)
# 轻工制造(2021) 家居用品(2021)
# 轻工制造(2021) 家居用品(2021)
# 机械设备(2021) 自动化设备(2021)
# 电力设备(2021) 其他电源设备Ⅱ(2021)
# 建筑装饰(2021) 装修装饰Ⅱ(2021)
# 机械设备(2021) 专用设备(2021)
# 电力设备(2021) 电池(2021)
# 国防军工(2021) 航天装备Ⅱ(2021)
# 机械设备(2021) 自动化设备(2021)
# 电力设备(2021) 其他电源设备Ⅱ(2021)
# 环保(2021) 环保设备Ⅱ(2021)
# 电子(2021) 半导体(2021)
# 建筑装饰(2021) 专业工程(2021)
# 国防军工(2021) 军工电子Ⅱ(2021)
# 电力设备(2021) 电机Ⅱ(2021)
# 建筑装饰(2021) 基础建设(2021)
# 建筑装饰(2021) 装修装饰Ⅱ(2021)
# 机械设备(2021) 通用设备(2021)
# 纺织服饰(2021) 纺织制造(2021)
# 汽车(2021) 汽车零部件(2021)
# 交通运输(2021) 物流(2021)
# 建筑装饰(2021) 工程咨询服务Ⅱ(2021)
# 建筑装饰(2021) 基础建设(2021)
# 建筑装饰(2021) 基础建设(2021)
# 建筑装饰(2021) 专业工程(2021)
# 环保(2021) 环境治理(2021)
# 环保(2021) 环境治理(2021)
# 机械设备(2021) 通用设备(2021)
# 传媒(2021) 电视广播Ⅱ(2021)
# 纺织服饰(2021) 服装家纺(2021)
# 传媒(2021) 电视广播Ⅱ(2021)
# 汽车(2021) 汽车服务(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 纺织服饰(2021) 纺织制造(2021)
# 汽车(2021) 汽车零部件(2021)
# 纺织服饰(2021) 服装家纺(2021)
# 汽车(2021) 汽车零部件(2021)
# 传媒(2021) 电视广播Ⅱ(2021)
# 商贸零售(2021) 一般零售(2021)
# 汽车(2021) 乘用车(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 家用电器(2021) 家电零部件Ⅱ(2021)
# 纺织服饰(2021) 服装家纺(2021)
# 汽车(2021) 汽车零部件(2021)
# 轻工制造(2021) 家居用品(2021)
# 汽车(2021) 汽车零部件(2021)
# 社会服务(2021) 教育(2021)
# 纺织服饰(2021) 服装家纺(2021)
# 纺织服饰(2021) 服装家纺(2021)
# 轻工制造(2021) 家居用品(2021)
# 汽车(2021) 汽车零部件(2021)
# 纺织服饰(2021) 服装家纺(2021)
# 电子(2021) 光学光电子(2021)
# 汽车(2021) 汽车零部件(2021)
# 家用电器(2021) 小家电(2021)
# 传媒(2021) 数字媒体(2021)
# 轻工制造(2021) 家居用品(2021)
# 家用电器(2021) 小家电(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 纺织服饰(2021) 服装家纺(2021)
# 轻工制造(2021) 家居用品(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 社会服务(2021) 体育Ⅱ(2021)
# 家用电器(2021) 厨卫电器(2021)
# 汽车(2021) 汽车零部件(2021)
# 传媒(2021) 电视广播Ⅱ(2021)
# 纺织服饰(2021) 纺织制造(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 家用电器(2021) 小家电(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 汽车(2021) 汽车零部件(2021)
# 有色金属(2021) 工业金属(2021)
# 纺织服饰(2021) 纺织制造(2021)
# 汽车(2021) 汽车零部件(2021)
# 食品饮料(2021) IT服务Ⅱ(2021)
# 农林牧渔(2021) 种植业(2021)
# 商贸零售(2021) 一般零售(2021)
# 医药生物(2021) 医药商业(2021)
# 美容护理(2021) 化妆品(2021)
# 农林牧渔(2021) 饲料(2021)
# 农林牧渔(2021) 养殖业(2021)
# 农林牧渔(2021) 种植业(2021)
# 农林牧渔(2021) 养殖业(2021)
# 农林牧渔(2021) 饲料(2021)
# 医药生物(2021) 医药商业(2021)
# 农林牧渔(2021) 养殖业(2021)
# 农林牧渔(2021) 养殖业(2021)
# 食品饮料(2021) 非白酒(2021)
# 农林牧渔(2021) 养殖业(2021)
# 农林牧渔(2021) 养殖业(2021)
# 农林牧渔(2021) 饲料(2021)
# 基础化工(2021) 化学制品(2021)
# 农林牧渔(2021) 种植业(2021)
# 农林牧渔(2021) 饲料(2021)
# 农林牧渔(2021) 饲料(2021)
# 食品饮料(2021) 食品加工(2021)
# 农林牧渔(2021) 养殖业(2021)
# 食品饮料(2021) 食品加工(2021)
# 食品饮料(2021) 休闲食品(2021)
# 食品饮料(2021) 饮料乳品(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 医药商业(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 医药商业(2021)
# 医药生物(2021) 医药商业(2021)
# 家用电器(2021) 其他家电Ⅱ(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 中药Ⅱ(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 医疗器械(2021)
# 食品饮料(2021) 食品加工(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 生物制品(2021)
# 农林牧渔(2021) 动物保健Ⅱ(2021)
# 机械设备(2021) 专用设备(2021)
# 医药生物(2021) 医疗服务(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 中药Ⅱ(2021)
# 医药生物(2021) 医药商业(2021)
# 医药生物(2021) 化学制药(2021)
# 基础化工(2021) 化学制品(2021)
# 医药生物(2021) 中药Ⅱ(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 化学制药(2021)
# 医药生物(2021) 中药Ⅱ(2021)
# 家用电器(2021) 其他家电Ⅱ(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 医疗器械(2021)
# 医药生物(2021) 中药Ⅱ(2021)
# 银行(2021) 农商行Ⅱ(2021)
# 银行(2021) 城商行Ⅱ(2021)
# 银行(2021) 股份制银行Ⅱ(2021)
# 非银金融(2021) 证券Ⅱ(2021)
# 非银金融(2021) 多元金融(2021)
# 银行(2021) 城商行Ⅱ(2021)
# 非银金融(2021) 多元金融(2021)
# 非银金融(2021) 证券Ⅱ(2021)
# 银行(2021) 股份制银行Ⅱ(2021)
# 银行(2021) 农商行Ⅱ(2021)
# 银行(2021) 城商行Ⅱ(2021)
# 非银金融(2021) 证券Ⅱ(2021)
# 银行(2021) 城商行Ⅱ(2021)
# 银行(2021) 股份制银行Ⅱ(2021)
# 银行(2021) 城商行Ⅱ(2021)
# 银行(2021) 城商行Ⅱ(2021)
# 非银金融(2021) 证券Ⅱ(2021)
# 非银金融(2021) 证券Ⅱ(2021)
# 银行(2021) 农商行Ⅱ(2021)
# 银行(2021) 城商行Ⅱ(2021)
# 银行(2021) 农商行Ⅱ(2021)
# 非银金融(2021) 证券Ⅱ(2021)
# 银行(2021) 城商行Ⅱ(2021)
# 银行(2021) 农商行Ⅱ(2021)
# 银行(2021) 农商行Ⅱ(2021)
# 非银金融(2021) 多元金融(2021)
# 银行(2021) 农商行Ⅱ(2021)
# 通信(2021) 通信设备(2021)
# 通信(2021) 通信设备(2021)
# 电子(2021) 半导体(2021)
# 电力设备(2021) 光伏设备(2021)
# 电子(2021) 半导体(2021)
# 电子(2021) 消费电子(2021)
# 电力设备(2021) 光伏设备(2021)
# 电子(2021) 元件(2021)
# 计算机(2021) 计算机设备(2021)
# 通信(2021) 通信服务(2021)
# 电子(2021) 消费电子(2021)
# 国防军工(2021) 军工电子Ⅱ(2021)
# 计算机(2021) 计算机设备(2021)
# 计算机(2021) 白酒Ⅱ(2021)
# 电子(2021) 元件(2021)
# 计算机(2021) 软件开发(2021)
# 电子(2021) 半导体(2021)
# 电子(2021) 元件(2021)
# 电子(2021) 元件(2021)
# 电力设备(2021) 光伏设备(2021)
# 机械设备(2021) 通用设备(2021)
# 计算机(2021) 软件开发(2021)
# 电子(2021) 半导体(2021)
# 计算机(2021) 计算机设备(2021)
# 电子(2021) 半导体(2021)
# 计算机(2021) 软件开发(2021)
# 电力设备(2021) 电池(2021)
# 计算机(2021) 白酒Ⅱ(2021)
# 国防军工(2021) 军工电子Ⅱ(2021)
# 计算机(2021) 白酒Ⅱ(2021)
# 电子(2021) 光学光电子(2021)
# 机械设备(2021) 通用设备(2021)
# 电子(2021) 光学光电子(2021)
# 电子(2021) 光学光电子(2021)
# 计算机(2021) 软件开发(2021)
# 计算机(2021) 白酒Ⅱ(2021)
# 电子(2021) 元件(2021)
# 计算机(2021) 白酒Ⅱ(2021)
# 电子(2021) 消费电子(2021)
# 计算机(2021) 软件开发(2021)
# 电子(2021) 半导体(2021)
# 电力设备(2021) 光伏设备(2021)
# 电子(2021) 半导体(2021)
# 计算机(2021) 白酒Ⅱ(2021)
# 计算机(2021) 软件开发(2021)
# 计算机(2021) 计算机设备(2021)
# 电子(2021) 消费电子(2021)
# 电子(2021) 消费电子(2021)
# 计算机(2021) 软件开发(2021)
# 计算机(2021) 软件开发(2021)
# 电子(2021) 元件(2021)
# 电子(2021) 电子化学品Ⅱ(2021)
# 计算机(2021) 软件开发(2021)
# 电子(2021) 元件(2021)
# 电子(2021) 半导体(2021)
# 计算机(2021) 计算机设备(2021)
# 环保(2021) 环保设备Ⅱ(2021)
# 机械设备(2021) 自动化设备(2021)
# 传媒(2021) 游戏Ⅱ(2021)
# 计算机(2021) 计算机设备(2021)
# 电子(2021) 光学光电子(2021)
# 电子(2021) 消费电子(2021)
# 电子(2021) 元件(2021)
# 电子(2021) 元件(2021)
# 电子(2021) 消费电子(2021)
# 电子(2021) 其他电子Ⅱ(2021)
# 通信(2021) 通信服务(2021)
# 公用事业(2021) 电力(2021)
# 公用事业(2021) 电力(2021)
# 环保(2021) 环境治理(2021)
# 公用事业(2021) 燃气Ⅱ(2021)
# 公用事业(2021) 电力(2021)
# 公用事业(2021) 电力(2021)
# 公用事业(2021) 电力(2021)
# 环保(2021) 环境治理(2021)
# 公用事业(2021) 燃气Ⅱ(2021)
# 公用事业(2021) 电力(2021)
# 环保(2021) 环境治理(2021)
# 电力设备(2021) 光伏设备(2021)
# 汽车(2021) 摩托车及其他(2021)
# 机械设备(2021) 通用设备(2021)
# 医药生物(2021) 化学制药(2021)
# 建筑装饰(2021) 工程咨询服务Ⅱ(2021)
# 食品饮料(2021) 休闲食品(2021)
# 机械设备(2021) 专用设备(2021)
# 基础化工(2021) 化学制品(2021)
# 煤炭(2021) 煤炭开采(2021)
# 计算机(2021) 白酒Ⅱ(2021)
# 电子(2021) 消费电子(2021)
# 电子(2021) 电子化学品Ⅱ(2021)
# 国防军工(2021) 航空装备Ⅱ(2021)
# 计算机(2021) 白酒Ⅱ(2021)
# 轻工制造(2021) 包装印刷(2021)
# 基础化工(2021) 化学纤维(2021)
# 建筑装饰(2021) 专业工程(2021)
# 机械设备(2021) 工程机械(2021)
# 建筑装饰(2021) 专业工程(2021)
# 汽车(2021) 汽车零部件(2021)
# 农林牧渔(2021) 养殖业(2021)
# 建筑材料(2021) 装修建材(2021)
# 美容护理(2021) 化妆品(2021)
# 电力设备(2021) 电池(2021)
# 建筑装饰(2021) 基础建设(2021)
# 基础化工(2021) 化学制品(2021)
# 有色金属(2021) 工业金属(2021)
# 纺织服饰(2021) 纺织制造(2021)
# 医药生物(2021) 医药商业(2021)
# 公用事业(2021) 电力(2021)
# 基础化工(2021) 塑料(2021)
# 电子(2021) 消费电子(2021)
# 电子(2021) 元件(2021)
# 美容护理(2021) 化妆品(2021)
# 轻工制造(2021) 家居用品(2021)
# 电力设备(2021) 光伏设备(2021)
# 计算机(2021) 计算机设备(2021)
# nan nan
# nan nan

# %%
            
            
print(nm)
count = 0
s1 = 0
s2 = 0
s3 = 0
for cd in cds:
    s1 = DTBS['A'][cd][d2]['dp'] 
    s2 = DTBS['A'][cd][d1]['dp'] 
    s3 += s2/s1 -1
    count += 1
# ic = (s2-s1)/s1 * 100
# print(str(round(ic,2))+ '%')
ic = s3/count*100
print('截至6月20，前一周',str(round(ic,2))+ '%')

count = 0
s1 = 0
s2 = 0
s3 = 0
for cd in cds:
    s1 = DTBS['A'][cd][d3]['dp'] 
    s2 = DTBS['A'][cd][d1]['dp'] 
    s3 += s2/s1 -1
    count += 1
# ic = (s2-s1)/s1 * 100
# print(str(round(ic,2))+ '%')
ic = s3/count*100
print('截至6月20，前二周',str(round(ic,2))+ '%')


count = 0
s1 = 0
s2 = 0
s3 = 0
for cd in cds:
    s1 = DTBS['A'][cd][d4]['dp'] 
    s2 = DTBS['A'][cd][d1]['dp'] 
    s3 += s2/s1 -1
    count += 1
# ic = (s2-s1)/s1 * 100
# print(str(round(ic,2))+ '%')
ic = s3/count*100
print('截至6月20，前四周',str(round(ic,2))+ '%')
# Out:
# 软件开发(2021)
# 截至6月20，前一周 1.52%
# 截至6月20，前二周 4.75%
# 截至6月20，前四周 11.3%

# %%
# 二级
nm = '通信服务(2021)'
cds = []
d1 = '2023-06-20'
d2 = '2023-06-13'
d3 = '2023-06-06'
d4 = '2023-05-30'
d0 = '2023-06-26'
for code in DTBS['A'].keys():
    
    if DTBS['A'][code][d1]['ia'] == 1 and DTBS['A'][code][d4]['ia'] == 1:
        if DTBS['B'][code]['cat2'] == nm:
            cds.append(code)

# %%
# 一级
nm = '家用电器(2021)'
cds = []
d1 = '2023-06-20'
d2 = '2023-06-13'
d3 = '2023-06-06'
d4 = '2023-05-30'
d0 = '2023-06-26'
for code in DTBS['A'].keys():
    
    if DTBS['A'][code][d1]['ia'] == 1 and DTBS['A'][code][d4]['ia'] == 1:
        if DTBS['B'][code]['cat1'] == nm:
            cds.append(code)

# %%
    
    
    
print(nm)


print('今日信息（6月26日）')            
for cd in cds:
    print(cd, DTBS['B'][cd]['cn'],'收盘价',DTBS['A'][cd][d0]['dp'],'转股溢价率',DTBS['A'][cd][d0]['cpr'])
print('截至6月20，前一周')


count = 0
s1 = 0
s2 = 0
s3 = 0
for cd in cds:
    s1 = DTBS['A'][cd][d2]['dp'] 
    s2 = DTBS['A'][cd][d1]['dp'] 
    s3 += s2/s1 -1
    s4 = (s2/s1 -1 )*100
    count += 1
    print(cd, DTBS['B'][cd]['cn'],str(round(s4,2))+ '%')
# ic = (s2-s1)/s1 * 100
# print(str(round(ic,2))+ '%')
ic = s3/count*100
print('全部等权收益',str(round(ic,2))+ '%')


print('截至6月20，前二周')
count = 0
s1 = 0
s2 = 0
s3 = 0
for cd in cds:
    s1 = DTBS['A'][cd][d3]['dp'] 
    s2 = DTBS['A'][cd][d1]['dp'] 
    s3 += s2/s1 -1
    s4 = (s2/s1 -1 )*100
    count += 1
    print(cd, DTBS['B'][cd]['cn'],str(round(s4,2))+ '%')
# ic = (s2-s1)/s1 * 100
# print(str(round(ic,2))+ '%')
ic = s3/count*100
print('全部等权收益',str(round(ic,2))+ '%')

print('截至6月20，前四周')
count = 0
s1 = 0
s2 = 0
s3 = 0
for cd in cds:
    s1 = DTBS['A'][cd][d4]['dp'] 
    s2 = DTBS['A'][cd][d1]['dp'] 
    s3 += s2/s1 -1
    s4 = (s2/s1 -1 )*100
    count += 1
    print(cd, DTBS['B'][cd]['cn'],str(round(s4,2))+ '%')
# ic = (s2-s1)/s1 * 100
# print(str(round(ic,2))+ '%')
ic = s3/count*100
print('全部等权收益',str(round(ic,2))+ '%')
# Out:
# 家用电器(2021)
# 今日信息（6月26日）
# 113637.SH 华翔转债 收盘价 122.88 转股溢价率 39.51
# 127036.SZ 三花转债 收盘价 145.0 转股溢价率 3.43
# 113524.SH 奇精转债 收盘价 119.411 转股溢价率 27.11
# 113633.SH 科沃转债 收盘价 110.244 转股溢价率 157.06
# 113659.SH 莱克转债 收盘价 116.207 转股溢价率 66.8
# 123154.SZ 火星转债 收盘价 118.78 转股溢价率 60.53
# 127069.SZ 小熊转债 收盘价 163.2 转股溢价率 3.45
# 113606.SH 荣泰转债 收盘价 110.573 转股溢价率 82.14
# 128097.SZ 奥佳转债 收盘价 113.28 转股溢价率 51.3
# 截至6月20，前一周
# 113637.SH 华翔转债 1.12%
# 127036.SZ 三花转债 7.9%
# 113524.SH 奇精转债 0.46%
# 113633.SH 科沃转债 -0.08%
# 113659.SH 莱克转债 0.41%
# 123154.SZ 火星转债 -0.12%
# 127069.SZ 小熊转债 0.78%
# 113606.SH 荣泰转债 -0.62%
# 128097.SZ 奥佳转债 0.01%
# 全部等权收益 1.09%
# 截至6月20，前二周
# 113637.SH 华翔转债 2.67%
# 127036.SZ 三花转债 10.73%
# 113524.SH 奇精转债 1.33%
# 113633.SH 科沃转债 -0.09%
# 113659.SH 莱克转债 1.03%
# 123154.SZ 火星转债 0.37%
# 127069.SZ 小熊转债 2.41%
# 113606.SH 荣泰转债 0.37%
# 128097.SZ 奥佳转债 1.15%
# 全部等权收益 2.22%
# 截至6月20，前四周
# 113637.SH 华翔转债 3.55%
# 127036.SZ 三花转债 10.41%
# 113524.SH 奇精转债 1.86%
# 113633.SH 科沃转债 0.91%
# 113659.SH 莱克转债 1.08%
# 123154.SZ 火星转债 3.04%
# 127069.SZ 小熊转债 4.29%
# 113606.SH 荣泰转债 0.64%
# 128097.SZ 奥佳转债 0.94%
# 全部等权收益 2.97%

# %%
# 一级
