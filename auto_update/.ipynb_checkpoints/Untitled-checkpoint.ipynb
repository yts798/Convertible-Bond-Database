# %%
# !python crawler_update.py
# Out:
# 493
# 475

# %%
from datetime import datetime
datetime.strptime('2023-03-20', '%Y-%m-%d')
datetime.strptime('2023-03-21', '%Y-%m-%d')
# Out:
# datetime.datetime(2023, 3, 21, 0, 0)

# %%
datetime.today()
# Out:
# datetime.datetime(2023, 3, 22, 10, 52, 33, 327607)

# %%
# !python to_database.py

# %%
# re-open
import os
import pickle
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
DTBS_path = os.path.join(storage_path, "DTBS.pkl")
with open(DTBS_path, 'rb') as f:  
    DTBS = pickle.load(f)

# %%
DTBS['A']['110088.SH']['2023-03-22']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-2d80e343c5c0> in <module>()
# ----> 1 DTBS['A']['110088.SH']['2023-03-22']
#
# KeyError: '2023-03-22'

# %%
DTBS['B']
# Out:
# {'110088.SH': {'cn': '淮22转债',
#   'ipo': '2022-10-20',
#   'sc': '600985.SH',
#   'sn': '淮北矿业',
#   'cat1': '煤炭(2021)',
#   'cat2': '煤炭开采(2021)'},
#  '113545.SH': {'cn': '金能转债',
#   'ipo': '2019-11-07',
#   'sc': '603113.SH',
#   'sn': '金能科技',
#   'cat1': '煤炭(2021)',
#   'cat2': '焦炭Ⅱ(2021)'},
#  '113631.SH': {'cn': '皖天转债',
#   'ipo': '2021-12-10',
#   'sc': '603689.SH',
#   'sn': '皖天然气',
#   'cat1': '公用事业(2021)',
#   'cat2': '燃气Ⅱ(2021)'},
#  '123128.SZ': {'cn': '首华转债',
#   'ipo': '2021-11-18',
#   'sc': '300483.SZ',
#   'sn': '首华燃气',
#   'cat1': '公用事业(2021)',
#   'cat2': '燃气Ⅱ(2021)'},
#  '123156.SZ': {'cn': '博汇转债',
#   'ipo': '2022-09-02',
#   'sc': '300839.SZ',
#   'sn': '博汇股份',
#   'cat1': '石油石化(2021)',
#   'cat2': '炼化及贸易(2021)'},
#  '127027.SZ': {'cn': '靖远转债',
#   'ipo': '2021-01-22',
#   'sc': '000552.SZ',
#   'sn': '靖远煤电',
#   'cat1': '煤炭(2021)',
#   'cat2': '煤炭开采(2021)'},
#  '127061.SZ': {'cn': '美锦转债',
#   'ipo': '2022-05-30',
#   'sc': '000723.SZ',
#   'sn': '美锦能源',
#   'cat1': '煤炭(2021)',
#   'cat2': '焦炭Ⅱ(2021)'},
#  '110047.SH': {'cn': '山鹰转债',
#   'ipo': '2018-12-10',
#   'sc': '600567.SH',
#   'sn': '山鹰国际',
#   'cat1': '轻工制造(2021)',
#   'cat2': '造纸(2021)'},
#  '110063.SH': {'cn': '鹰19转债',
#   'ipo': '2020-01-03',
#   'sc': '600567.SH',
#   'sn': '山鹰国际',
#   'cat1': '轻工制造(2021)',
#   'cat2': '造纸(2021)'},
#  '110070.SH': {'cn': '凌钢转债',
#   'ipo': '2020-05-13',
#   'sc': '600231.SH',
#   'sn': '凌钢股份',
#   'cat1': '钢铁(2021)',
#   'cat2': '普钢(2021)'},
#  '110087.SH': {'cn': '天业转债',
#   'ipo': '2022-07-19',
#   'sc': '600075.SH',
#   'sn': '新疆天业',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学原料(2021)'},
#  '110089.SH': {'cn': '兴发转债',
#   'ipo': '2022-10-31',
#   'sc': '600141.SH',
#   'sn': '兴发集团',
#   'cat1': '基础化工(2021)',
#   'cat2': '农化制品(2021)'},
#  '110092.SH': {'cn': '三房转债',
#   'ipo': '2023-02-07',
#   'sc': '600370.SH',
#   'sn': '三房巷',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学纤维(2021)'},
#  '111001.SH': {'cn': '山玻转债',
#   'ipo': '2021-12-06',
#   'sc': '605006.SH',
#   'sn': '山东玻纤',
#   'cat1': '建筑材料(2021)',
#   'cat2': '玻璃玻纤(2021)'},
#  '111002.SH': {'cn': '特纸转债',
#   'ipo': '2021-12-30',
#   'sc': '605007.SH',
#   'sn': '五洲特纸',
#   'cat1': '轻工制造(2021)',
#   'cat2': '造纸(2021)'},
#  '111003.SH': {'cn': '聚合转债',
#   'ipo': '2022-04-19',
#   'sc': '605166.SH',
#   'sn': '聚合顺',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学纤维(2021)'},
#  '111007.SH': {'cn': '永和转债',
#   'ipo': '2022-11-01',
#   'sc': '605020.SH',
#   'sn': '永和股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '111012.SH': {'cn': '福新转债',
#   'ipo': '2023-02-07',
#   'sc': '605488.SH',
#   'sn': '福莱新材',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '113025.SH': {'cn': '明泰转债',
#   'ipo': '2019-05-07',
#   'sc': '601677.SH',
#   'sn': '明泰铝业',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '113027.SH': {'cn': '华钰转债',
#   'ipo': '2019-07-10',
#   'sc': '601020.SH',
#   'sn': '华钰矿业',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '113046.SH': {'cn': '金田转债',
#   'ipo': '2021-04-12',
#   'sc': '601609.SH',
#   'sn': '金田股份',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '113047.SH': {'cn': '旗滨转债',
#   'ipo': '2021-05-07',
#   'sc': '601636.SH',
#   'sn': '旗滨集团',
#   'cat1': '建筑材料(2021)',
#   'cat2': '玻璃玻纤(2021)'},
#  '113058.SH': {'cn': '友发转债',
#   'ipo': '2022-04-26',
#   'sc': '601686.SH',
#   'sn': '友发集团',
#   'cat1': '钢铁(2021)',
#   'cat2': '普钢(2021)'},
#  '113059.SH': {'cn': '福莱转债',
#   'ipo': '2022-06-13',
#   'sc': '601865.SH',
#   'sn': '福莱特',
#   'cat1': '电力设备(2021)',
#   'cat2': '光伏设备(2021)'},
#  '113064.SH': {'cn': '东材转债',
#   'ipo': '2022-12-12',
#   'sc': '601208.SH',
#   'sn': '东材科技',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '113534.SH': {'cn': '鼎胜转债',
#   'ipo': '2019-04-30',
#   'sc': '603876.SH',
#   'sn': '鼎胜新材',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '113535.SH': {'cn': '大业转债',
#   'ipo': '2019-06-03',
#   'sc': '603278.SH',
#   'sn': '大业股份',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '113566.SH': {'cn': '翔港转债',
#   'ipo': '2020-03-31',
#   'sc': '603499.SH',
#   'sn': '翔港科技',
#   'cat1': '轻工制造(2021)',
#   'cat2': '包装印刷(2021)'},
#  '113591.SH': {'cn': '胜达转债',
#   'ipo': '2020-07-23',
#   'sc': '603687.SH',
#   'sn': '大胜达',
#   'cat1': '轻工制造(2021)',
#   'cat2': '包装印刷(2021)'},
#  '113600.SH': {'cn': '新星转债',
#   'ipo': '2020-09-11',
#   'sc': '603978.SH',
#   'sn': '深圳新星',
#   'cat1': '有色金属(2021)',
#   'cat2': '金属新材料(2021)'},
#  '113615.SH': {'cn': '金诚转债',
#   'ipo': '2021-01-14',
#   'sc': '603979.SH',
#   'sn': '金诚信',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '专业工程(2021)'},
#  '113621.SH': {'cn': '彤程转债',
#   'ipo': '2021-02-22',
#   'sc': '603650.SH',
#   'sn': '彤程新材',
#   'cat1': '基础化工(2021)',
#   'cat2': '橡胶(2021)'},
#  '113623.SH': {'cn': '凤21转债',
#   'ipo': '2021-05-07',
#   'sc': '603225.SH',
#   'sn': '新凤鸣',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学纤维(2021)'},
#  '113632.SH': {'cn': '鹤21转债',
#   'ipo': '2021-12-09',
#   'sc': '603733.SH',
#   'sn': '仙鹤股份',
#   'cat1': '轻工制造(2021)',
#   'cat2': '造纸(2021)'},
#  '113636.SH': {'cn': '甬金转债',
#   'ipo': '2021-12-31',
#   'sc': '603995.SH',
#   'sn': '甬金股份',
#   'cat1': '钢铁(2021)',
#   'cat2': '特钢Ⅱ(2021)'},
#  '113638.SH': {'cn': '台21转债',
#   'ipo': '2022-01-21',
#   'sc': '603055.SH',
#   'sn': '台华新材',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '纺织制造(2021)'},
#  '113640.SH': {'cn': '苏利转债',
#   'ipo': '2022-03-10',
#   'sc': '603585.SH',
#   'sn': '苏利股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '农化制品(2021)'},
#  '113641.SH': {'cn': '华友转债',
#   'ipo': '2022-03-23',
#   'sc': '603799.SH',
#   'sn': '华友钴业',
#   'cat1': '有色金属(2021)',
#   'cat2': '能源金属(2021)'},
#  '113649.SH': {'cn': '丰山转债',
#   'ipo': '2022-07-21',
#   'sc': '603810.SH',
#   'sn': '丰山集团',
#   'cat1': '基础化工(2021)',
#   'cat2': '农化制品(2021)'},
#  '113650.SH': {'cn': '博22转债',
#   'ipo': '2022-07-28',
#   'sc': '603916.SH',
#   'sn': '苏博特',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '113653.SH': {'cn': '永22转债',
#   'ipo': '2022-08-26',
#   'sc': '603681.SH',
#   'sn': '永冠新材',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '113657.SH': {'cn': '再22转债',
#   'ipo': '2022-10-27',
#   'sc': '603601.SH',
#   'sn': '再升科技',
#   'cat1': '建筑材料(2021)',
#   'cat2': '玻璃玻纤(2021)'},
#  '113663.SH': {'cn': '新化转债',
#   'ipo': '2022-12-16',
#   'sc': '603867.SH',
#   'sn': '新化股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '118000.SH': {'cn': '嘉元转债',
#   'ipo': '2021-03-15',
#   'sc': '688388.SH',
#   'sn': '嘉元科技',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '118005.SH': {'cn': '天奈转债',
#   'ipo': '2022-03-01',
#   'sc': '688116.SH',
#   'sn': '天奈科技',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '118006.SH': {'cn': '阿拉转债',
#   'ipo': '2022-04-12',
#   'sc': '688179.SH',
#   'sn': '阿拉丁',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '118008.SH': {'cn': '海优转债',
#   'ipo': '2022-07-21',
#   'sc': '688680.SH',
#   'sn': '海优新材',
#   'cat1': '电力设备(2021)',
#   'cat2': '光伏设备(2021)'},
#  '118010.SH': {'cn': '洁特转债',
#   'ipo': '2022-08-02',
#   'sc': '688026.SH',
#   'sn': '洁特生物',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '118018.SH': {'cn': '瑞科转债',
#   'ipo': '2022-09-14',
#   'sc': '688323.SH',
#   'sn': '瑞华泰',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '118020.SH': {'cn': '芳源转债',
#   'ipo': '2022-11-07',
#   'sc': '688148.SH',
#   'sn': '芳源股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '118022.SH': {'cn': '锂科转债',
#   'ipo': '2022-11-07',
#   'sc': '688779.SH',
#   'sn': '长远锂科',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '118023.SH': {'cn': '广大转债',
#   'ipo': '2022-11-09',
#   'sc': '688186.SH',
#   'sn': '广大特材',
#   'cat1': '钢铁(2021)',
#   'cat2': '特钢Ⅱ(2021)'},
#  '118028.SH': {'cn': '会通转债',
#   'ipo': '2023-01-04',
#   'sc': '688219.SH',
#   'sn': '会通股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '118029.SH': {'cn': '富淼转债',
#   'ipo': '2023-01-09',
#   'sc': '688350.SH',
#   'sn': '富淼科技',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '123012.SZ': {'cn': '万顺转债',
#   'ipo': '2018-08-29',
#   'sc': '300057.SZ',
#   'sn': '万顺新材',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '123013.SZ': {'cn': '横河转债',
#   'ipo': '2018-08-20',
#   'sc': '300539.SZ',
#   'sn': '横河精密',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '123031.SZ': {'cn': '晶瑞转债',
#   'ipo': '2019-09-26',
#   'sc': '300655.SZ',
#   'sn': '晶瑞电材',
#   'cat1': '电子(2021)',
#   'cat2': '电子化学品Ⅱ(2021)'},
#  '123046.SZ': {'cn': '天铁转债',
#   'ipo': '2020-04-17',
#   'sc': '300587.SZ',
#   'sn': '天铁股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '橡胶(2021)'},
#  '123052.SZ': {'cn': '飞鹿转债',
#   'ipo': '2020-07-03',
#   'sc': '300665.SZ',
#   'sn': '飞鹿股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '123057.SZ': {'cn': '美联转债',
#   'ipo': '2020-07-27',
#   'sc': '300586.SZ',
#   'sn': '美联新材',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '123076.SZ': {'cn': '强力转债',
#   'ipo': '2020-12-04',
#   'sc': '300429.SZ',
#   'sn': '强力新材',
#   'cat1': '电子(2021)',
#   'cat2': '电子化学品Ⅱ(2021)'},
#  '123078.SZ': {'cn': '飞凯转债',
#   'ipo': '2020-12-16',
#   'sc': '300398.SZ',
#   'sn': '飞凯材料',
#   'cat1': '电子(2021)',
#   'cat2': '电子化学品Ⅱ(2021)'},
#  '123085.SZ': {'cn': '万顺转2',
#   'ipo': '2020-12-28',
#   'sc': '300057.SZ',
#   'sn': '万顺新材',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '123091.SZ': {'cn': '长海转债',
#   'ipo': '2021-01-15',
#   'sc': '300196.SZ',
#   'sn': '长海股份',
#   'cat1': '建筑材料(2021)',
#   'cat2': '玻璃玻纤(2021)'},
#  '123106.SZ': {'cn': '正丹转债',
#   'ipo': '2021-04-20',
#   'sc': '300641.SZ',
#   'sn': '正丹股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '123118.SZ': {'cn': '惠城转债',
#   'ipo': '2021-07-26',
#   'sc': '300779.SZ',
#   'sn': '惠城环保',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '123124.SZ': {'cn': '晶瑞转2',
#   'ipo': '2021-09-07',
#   'sc': '300655.SZ',
#   'sn': '晶瑞电材',
#   'cat1': '电子(2021)',
#   'cat2': '电子化学品Ⅱ(2021)'},
#  '123126.SZ': {'cn': '瑞丰转债',
#   'ipo': '2021-10-18',
#   'sc': '300243.SZ',
#   'sn': '瑞丰高材',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '123129.SZ': {'cn': '锦鸡转债',
#   'ipo': '2021-11-24',
#   'sc': '300798.SZ',
#   'sn': '锦鸡股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '123144.SZ': {'cn': '裕兴转债',
#   'ipo': '2022-04-27',
#   'sc': '300305.SZ',
#   'sn': '裕兴股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '123152.SZ': {'cn': '润禾转债',
#   'ipo': '2022-08-11',
#   'sc': '300727.SZ',
#   'sn': '润禾材料',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '123158.SZ': {'cn': '宙邦转债',
#   'ipo': '2022-10-21',
#   'sc': '300037.SZ',
#   'sn': '新宙邦',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '123165.SZ': {'cn': '回天转债',
#   'ipo': '2022-11-15',
#   'sc': '300041.SZ',
#   'sn': '回天新材',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '123166.SZ': {'cn': '蒙泰转债',
#   'ipo': '2022-11-25',
#   'sc': '300876.SZ',
#   'sn': '蒙泰高新',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学纤维(2021)'},
#  '123168.SZ': {'cn': '惠云转债',
#   'ipo': '2022-12-14',
#   'sc': '300891.SZ',
#   'sn': '惠云钛业',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学原料(2021)'},
#  '123169.SZ': {'cn': '正海转债',
#   'ipo': '2022-12-12',
#   'sc': '300224.SZ',
#   'sn': '正海磁材',
#   'cat1': '有色金属(2021)',
#   'cat2': '金属新材料(2021)'},
#  '127017.SZ': {'cn': '万青转债',
#   'ipo': '2020-07-02',
#   'sc': '000789.SZ',
#   'sn': '万年青',
#   'cat1': '建筑材料(2021)',
#   'cat2': '水泥(2021)'},
#  '127018.SZ': {'cn': '本钢转债',
#   'ipo': '2020-08-04',
#   'sc': '000761.SZ',
#   'sn': '本钢板材',
#   'cat1': '钢铁(2021)',
#   'cat2': '普钢(2021)'},
#  '127019.SZ': {'cn': '国城转债',
#   'ipo': '2020-08-10',
#   'sc': '000688.SZ',
#   'sn': '国城矿业',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '127020.SZ': {'cn': '中金转债',
#   'ipo': '2020-08-14',
#   'sc': '000060.SZ',
#   'sn': '中金岭南',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '127022.SZ': {'cn': '恒逸转债',
#   'ipo': '2020-11-16',
#   'sc': '000703.SZ',
#   'sn': '恒逸石化',
#   'cat1': '石油石化(2021)',
#   'cat2': '炼化及贸易(2021)'},
#  '127025.SZ': {'cn': '冀东转债',
#   'ipo': '2020-12-02',
#   'sc': '000401.SZ',
#   'sn': '冀东水泥',
#   'cat1': '建筑材料(2021)',
#   'cat2': '水泥(2021)'},
#  '127030.SZ': {'cn': '盛虹转债',
#   'ipo': '2021-04-21',
#   'sc': '000301.SZ',
#   'sn': '东方盛虹',
#   'cat1': '石油石化(2021)',
#   'cat2': '炼化及贸易(2021)'},
#  '127031.SZ': {'cn': '洋丰转债',
#   'ipo': '2021-04-23',
#   'sc': '000902.SZ',
#   'sn': '新洋丰',
#   'cat1': '基础化工(2021)',
#   'cat2': '农化制品(2021)'},
#  '127035.SZ': {'cn': '濮耐转债',
#   'ipo': '2021-06-18',
#   'sc': '002225.SZ',
#   'sn': '濮耐股份',
#   'cat1': '建筑材料(2021)',
#   'cat2': '装修建材(2021)'},
#  '127042.SZ': {'cn': '嘉美转债',
#   'ipo': '2021-09-08',
#   'sc': '002969.SZ',
#   'sn': '嘉美包装',
#   'cat1': '轻工制造(2021)',
#   'cat2': '包装印刷(2021)'},
#  '127043.SZ': {'cn': '川恒转债',
#   'ipo': '2021-09-23',
#   'sc': '002895.SZ',
#   'sn': '川恒股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '农化制品(2021)'},
#  '127053.SZ': {'cn': '豪美转债',
#   'ipo': '2022-03-04',
#   'sc': '002988.SZ',
#   'sn': '豪美新材',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '127054.SZ': {'cn': '双箭转债',
#   'ipo': '2022-03-15',
#   'sc': '002381.SZ',
#   'sn': '双箭股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '橡胶(2021)'},
#  '127056.SZ': {'cn': '中特转债',
#   'ipo': '2022-04-15',
#   'sc': '000708.SZ',
#   'sn': '中信特钢',
#   'cat1': '钢铁(2021)',
#   'cat2': '特钢Ⅱ(2021)'},
#  '127059.SZ': {'cn': '永东转2',
#   'ipo': '2022-05-16',
#   'sc': '002753.SZ',
#   'sn': '永东股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '橡胶(2021)'},
#  '127062.SZ': {'cn': '垒知转债',
#   'ipo': '2022-05-20',
#   'sc': '002398.SZ',
#   'sn': '垒知集团',
#   'cat1': '建筑材料(2021)',
#   'cat2': '装修建材(2021)'},
#  '127067.SZ': {'cn': '恒逸转2',
#   'ipo': '2022-08-18',
#   'sc': '000703.SZ',
#   'sn': '恒逸石化',
#   'cat1': '石油石化(2021)',
#   'cat2': '炼化及贸易(2021)'},
#  '127068.SZ': {'cn': '顺博转债',
#   'ipo': '2022-09-07',
#   'sc': '002996.SZ',
#   'sn': '顺博合金',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '127070.SZ': {'cn': '大中转债',
#   'ipo': '2022-10-11',
#   'sc': '001203.SZ',
#   'sn': '大中矿业',
#   'cat1': '钢铁(2021)',
#   'cat2': '冶钢原料(2021)'},
#  '127073.SZ': {'cn': '天赐转债',
#   'ipo': '2022-10-27',
#   'sc': '002709.SZ',
#   'sn': '天赐材料',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '127075.SZ': {'cn': '百川转2',
#   'ipo': '2022-11-16',
#   'sc': '002455.SZ',
#   'sn': '百川股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '127078.SZ': {'cn': '优彩转债',
#   'ipo': '2023-01-09',
#   'sc': '002998.SZ',
#   'sn': '优彩资源',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学纤维(2021)'},
#  '128014.SZ': {'cn': '永东转债',
#   'ipo': '2017-05-12',
#   'sc': '002753.SZ',
#   'sn': '永东股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '橡胶(2021)'},
#  '128039.SZ': {'cn': '三力转债',
#   'ipo': '2018-06-29',
#   'sc': '002224.SZ',
#   'sn': '三力士',
#   'cat1': '基础化工(2021)',
#   'cat2': '橡胶(2021)'},
#  '128049.SZ': {'cn': '华源转债',
#   'ipo': '2018-12-20',
#   'sc': '002787.SZ',
#   'sn': '华源控股',
#   'cat1': '轻工制造(2021)',
#   'cat2': '包装印刷(2021)'},
#  '128063.SZ': {'cn': '未来转债',
#   'ipo': '2019-04-24',
#   'sc': '002631.SZ',
#   'sn': '德尔未来',
#   'cat1': '轻工制造(2021)',
#   'cat2': '家居用品(2021)'},
#  '128071.SZ': {'cn': '合兴转债',
#   'ipo': '2019-09-16',
#   'sc': '002228.SZ',
#   'sn': '合兴包装',
#   'cat1': '轻工制造(2021)',
#   'cat2': '包装印刷(2021)'},
#  '128072.SZ': {'cn': '翔鹭转债',
#   'ipo': '2019-09-16',
#   'sc': '002842.SZ',
#   'sn': '翔鹭钨业',
#   'cat1': '有色金属(2021)',
#   'cat2': '小金属(2021)'},
#  '128079.SZ': {'cn': '英联转债',
#   'ipo': '2019-11-21',
#   'sc': '002846.SZ',
#   'sn': '英联股份',
#   'cat1': '轻工制造(2021)',
#   'cat2': '包装印刷(2021)'},
#  '128081.SZ': {'cn': '海亮转债',
#   'ipo': '2019-12-16',
#   'sc': '002203.SZ',
#   'sn': '海亮股份',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '128085.SZ': {'cn': '鸿达转债',
#   'ipo': '2020-01-08',
#   'sc': '002002.SZ',
#   'sn': '鸿达兴业',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学原料(2021)'},
#  '128095.SZ': {'cn': '恩捷转债',
#   'ipo': '2020-02-28',
#   'sc': '002812.SZ',
#   'sn': '恩捷股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '128109.SZ': {'cn': '楚江转债',
#   'ipo': '2020-06-23',
#   'sc': '002171.SZ',
#   'sn': '楚江新材',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '128111.SZ': {'cn': '中矿转债',
#   'ipo': '2020-07-07',
#   'sc': '002738.SZ',
#   'sn': '中矿资源',
#   'cat1': '有色金属(2021)',
#   'cat2': '小金属(2021)'},
#  '128117.SZ': {'cn': '道恩转债',
#   'ipo': '2020-07-20',
#   'sc': '002838.SZ',
#   'sn': '道恩股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '塑料(2021)'},
#  '128123.SZ': {'cn': '国光转债',
#   'ipo': '2020-08-19',
#   'sc': '002749.SZ',
#   'sn': '国光股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '农化制品(2021)'},
#  '128128.SZ': {'cn': '齐翔转2',
#   'ipo': '2020-09-15',
#   'sc': '002408.SZ',
#   'sn': '齐翔腾达',
#   'cat1': '石油石化(2021)',
#   'cat2': '炼化及贸易(2021)'},
#  '128130.SZ': {'cn': '景兴转债',
#   'ipo': '2020-09-18',
#   'sc': '002067.SZ',
#   'sn': '景兴纸业',
#   'cat1': '轻工制造(2021)',
#   'cat2': '造纸(2021)'},
#  '128144.SZ': {'cn': '利民转债',
#   'ipo': '2021-03-24',
#   'sc': '002734.SZ',
#   'sn': '利民股份',
#   'cat1': '基础化工(2021)',
#   'cat2': '农化制品(2021)'},
#  '110060.SH': {'cn': '天路转债',
#   'ipo': '2019-11-28',
#   'sc': '600326.SH',
#   'sn': '西藏天路',
#   'cat1': '建筑材料(2021)',
#   'cat2': '水泥(2021)'},
#  '110064.SH': {'cn': '建工转债',
#   'ipo': '2020-01-16',
#   'sc': '600939.SH',
#   'sn': '重庆建工',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '房屋建设Ⅱ(2021)'},
#  '110068.SH': {'cn': '龙净转债',
#   'ipo': '2020-04-15',
#   'sc': '600388.SH',
#   'sn': 'ST龙净',
#   'cat1': '环保(2021)',
#   'cat2': '环保设备Ⅱ(2021)'},
#  '110074.SH': {'cn': '精达转债',
#   'ipo': '2020-09-21',
#   'sc': '600577.SH',
#   'sn': '精达股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '110075.SH': {'cn': '南航转债',
#   'ipo': '2020-11-03',
#   'sc': '600029.SH',
#   'sn': '南方航空',
#   'cat1': '交通运输(2021)',
#   'cat2': '航空机场(2021)'},
#  '110080.SH': {'cn': '东湖转债',
#   'ipo': '2021-05-12',
#   'sc': '600133.SH',
#   'sn': '东湖高新',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '基础建设(2021)'},
#  '110082.SH': {'cn': '宏发转债',
#   'ipo': '2021-11-23',
#   'sc': '600885.SH',
#   'sn': '宏发股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '110086.SH': {'cn': '精工转债',
#   'ipo': '2022-05-23',
#   'sc': '600496.SH',
#   'sn': '精工钢构',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '专业工程(2021)'},
#  '110091.SH': {'cn': '合力转债',
#   'ipo': '2023-01-06',
#   'sc': '600761.SH',
#   'sn': '安徽合力',
#   'cat1': '机械设备(2021)',
#   'cat2': '工程机械(2021)'},
#  '111000.SH': {'cn': '起帆转债',
#   'ipo': '2021-06-17',
#   'sc': '605222.SH',
#   'sn': '起帆电缆',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '113024.SH': {'cn': '核建转债',
#   'ipo': '2019-04-26',
#   'sc': '601611.SH',
#   'sn': '中国核建',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '基础建设(2021)'},
#  '113030.SH': {'cn': '东风转债',
#   'ipo': '2020-01-20',
#   'sc': '601515.SH',
#   'sn': '东风股份',
#   'cat1': '轻工制造(2021)',
#   'cat2': '包装印刷(2021)'},
#  '113044.SH': {'cn': '大秦转债',
#   'ipo': '2021-01-15',
#   'sc': '601006.SH',
#   'sn': '大秦铁路',
#   'cat1': '交通运输(2021)',
#   'cat2': '铁路公路(2021)'},
#  '113054.SH': {'cn': '绿动转债',
#   'ipo': '2022-03-23',
#   'sc': '601330.SH',
#   'sn': '绿色动力',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '113505.SH': {'cn': '杭电转债',
#   'ipo': '2018-03-27',
#   'sc': '603618.SH',
#   'sn': '杭电股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '113519.SH': {'cn': '长久转债',
#   'ipo': '2018-11-30',
#   'sc': '603569.SH',
#   'sn': '长久物流',
#   'cat1': '交通运输(2021)',
#   'cat2': '物流(2021)'},
#  '113526.SH': {'cn': '联泰转债',
#   'ipo': '2019-02-18',
#   'sc': '603797.SH',
#   'sn': '联泰环保',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '113530.SH': {'cn': '大丰转债',
#   'ipo': '2019-04-18',
#   'sc': '603081.SH',
#   'sn': '大丰实业',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '113546.SH': {'cn': '迪贝转债',
#   'ipo': '2019-11-21',
#   'sc': '603320.SH',
#   'sn': '迪贝电气',
#   'cat1': '电力设备(2021)',
#   'cat2': '电机Ⅱ(2021)'},
#  '113549.SH': {'cn': '白电转债',
#   'ipo': '2019-12-11',
#   'sc': '603861.SH',
#   'sn': '白云电器',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '113570.SH': {'cn': '百达转债',
#   'ipo': '2020-04-08',
#   'sc': '603331.SH',
#   'sn': '百达精工',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '113574.SH': {'cn': '华体转债',
#   'ipo': '2020-04-27',
#   'sc': '603679.SH',
#   'sn': '华体科技',
#   'cat1': '电子(2021)',
#   'cat2': '光学光电子(2021)'},
#  '113578.SH': {'cn': '全筑转债',
#   'ipo': '2020-05-19',
#   'sc': '603030.SH',
#   'sn': '全筑股份',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '装修装饰Ⅱ(2021)'},
#  '113593.SH': {'cn': '沪工转债',
#   'ipo': '2020-08-10',
#   'sc': '603131.SH',
#   'sn': '上海沪工',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '113595.SH': {'cn': '花王转债',
#   'ipo': '2020-08-18',
#   'sc': '603007.SH',
#   'sn': 'ST花王',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '基础建设(2021)'},
#  '113597.SH': {'cn': '佳力转债',
#   'ipo': '2020-08-21',
#   'sc': '603912.SH',
#   'sn': '佳力图',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '113598.SH': {'cn': '法兰转债',
#   'ipo': '2020-08-25',
#   'sc': '603966.SH',
#   'sn': '法兰泰克',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '113608.SH': {'cn': '威派转债',
#   'ipo': '2020-11-27',
#   'sc': '603956.SH',
#   'sn': '威派格',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '113609.SH': {'cn': '永安转债',
#   'ipo': '2020-12-23',
#   'sc': '603776.SH',
#   'sn': '永安行',
#   'cat1': '汽车(2021)',
#   'cat2': '摩托车及其他(2021)'},
#  '113622.SH': {'cn': '杭叉转债',
#   'ipo': '2021-04-14',
#   'sc': '603298.SH',
#   'sn': '杭叉集团',
#   'cat1': '机械设备(2021)',
#   'cat2': '工程机械(2021)'},
#  '113637.SH': {'cn': '华翔转债',
#   'ipo': '2022-01-20',
#   'sc': '603112.SH',
#   'sn': '华翔股份',
#   'cat1': '家用电器(2021)',
#   'cat2': '家电零部件Ⅱ(2021)'},
#  '113644.SH': {'cn': '艾迪转债',
#   'ipo': '2022-05-12',
#   'sc': '603638.SH',
#   'sn': '艾迪精密',
#   'cat1': '机械设备(2021)',
#   'cat2': '工程机械(2021)'},
#  '113646.SH': {'cn': '永吉转债',
#   'ipo': '2022-05-17',
#   'sc': '603058.SH',
#   'sn': '永吉股份',
#   'cat1': '轻工制造(2021)',
#   'cat2': '包装印刷(2021)'},
#  '113651.SH': {'cn': '松霖转债',
#   'ipo': '2022-08-17',
#   'sc': '603992.SH',
#   'sn': '松霖科技',
#   'cat1': '轻工制造(2021)',
#   'cat2': '家居用品(2021)'},
#  '113652.SH': {'cn': '伟22转债',
#   'ipo': '2022-08-12',
#   'sc': '603568.SH',
#   'sn': '伟明环保',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '113654.SH': {'cn': '永02转债',
#   'ipo': '2022-09-01',
#   'sc': '603901.SH',
#   'sn': '永创智能',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '113656.SH': {'cn': '嘉诚转债',
#   'ipo': '2022-10-12',
#   'sc': '603535.SH',
#   'sn': '嘉诚国际',
#   'cat1': '交通运输(2021)',
#   'cat2': '物流(2021)'},
#  '113658.SH': {'cn': '密卫转债',
#   'ipo': '2022-10-25',
#   'sc': '603713.SH',
#   'sn': '密尔克卫',
#   'cat1': '交通运输(2021)',
#   'cat2': '物流(2021)'},
#  '113664.SH': {'cn': '大元转债',
#   'ipo': '2023-01-04',
#   'sc': '603757.SH',
#   'sn': '大元泵业',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '113665.SH': {'cn': '汇通转债',
#   'ipo': '2023-01-11',
#   'sc': '603176.SH',
#   'sn': '汇通集团',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '基础建设(2021)'},
#  '118009.SH': {'cn': '华锐转债',
#   'ipo': '2022-07-21',
#   'sc': '688059.SH',
#   'sn': '华锐精密',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '118014.SH': {'cn': '高测转债',
#   'ipo': '2022-08-12',
#   'sc': '688556.SH',
#   'sn': '高测股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '光伏设备(2021)'},
#  '118016.SH': {'cn': '京源转债',
#   'ipo': '2022-08-25',
#   'sc': '688096.SH',
#   'sn': '京源环保',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '118017.SH': {'cn': '深科转债',
#   'ipo': '2022-08-29',
#   'sc': '688328.SH',
#   'sn': '深科达',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '118019.SH': {'cn': '金盘转债',
#   'ipo': '2022-10-13',
#   'sc': '688676.SH',
#   'sn': '金盘科技',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '118025.SH': {'cn': '奕瑞转债',
#   'ipo': '2022-11-18',
#   'sc': '688301.SH',
#   'sn': '奕瑞科技',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '118026.SH': {'cn': '利元转债',
#   'ipo': '2022-11-18',
#   'sc': '688499.SH',
#   'sn': '利元亨',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '123002.SZ': {'cn': '国祯转债',
#   'ipo': '2017-12-25',
#   'sc': '300388.SZ',
#   'sn': '节能国祯',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '123004.SZ': {'cn': '铁汉转债',
#   'ipo': '2018-01-26',
#   'sc': '300197.SZ',
#   'sn': '节能铁汉',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '基础建设(2021)'},
#  '123010.SZ': {'cn': '博世转债',
#   'ipo': '2018-08-14',
#   'sc': '300422.SZ',
#   'sn': '博世科',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '123014.SZ': {'cn': '凯发转债',
#   'ipo': '2018-08-21',
#   'sc': '300407.SZ',
#   'sn': '凯发电气',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '123034.SZ': {'cn': '通光转债',
#   'ipo': '2019-11-28',
#   'sc': '300265.SZ',
#   'sn': '通光线缆',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '123038.SZ': {'cn': '联得转债',
#   'ipo': '2020-01-22',
#   'sc': '300545.SZ',
#   'sn': '联得装备',
#   'cat1': '电子(2021)',
#   'cat2': '光学光电子(2021)'},
#  '123044.SZ': {'cn': '红相转债',
#   'ipo': '2020-04-13',
#   'sc': '300427.SZ',
#   'sn': '红相股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '123048.SZ': {'cn': '应急转债',
#   'ipo': '2020-05-11',
#   'sc': '300527.SZ',
#   'sn': '中船应急',
#   'cat1': '国防军工(2021)',
#   'cat2': '地面兵装Ⅱ(2021)'},
#  '123049.SZ': {'cn': '维尔转债',
#   'ipo': '2020-05-12',
#   'sc': '300190.SZ',
#   'sn': '维尔利',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '123061.SZ': {'cn': '航新转债',
#   'ipo': '2020-08-18',
#   'sc': '300424.SZ',
#   'sn': '航新科技',
#   'cat1': '国防军工(2021)',
#   'cat2': '航空装备Ⅱ(2021)'},
#  '123063.SZ': {'cn': '大禹转债',
#   'ipo': '2020-08-20',
#   'sc': '300021.SZ',
#   'sn': '大禹节水',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '农业综合Ⅱ(2021)'},
#  '123067.SZ': {'cn': '斯莱转债',
#   'ipo': '2020-10-15',
#   'sc': '300382.SZ',
#   'sn': '斯莱克',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '123071.SZ': {'cn': '天能转债',
#   'ipo': '2020-11-25',
#   'sc': '300569.SZ',
#   'sn': '天能重工',
#   'cat1': '电力设备(2021)',
#   'cat2': '风电设备(2021)'},
#  '123080.SZ': {'cn': '海波转债',
#   'ipo': '2020-12-22',
#   'sc': '300517.SZ',
#   'sn': '海波重科',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '专业工程(2021)'},
#  '123089.SZ': {'cn': '九洲转2',
#   'ipo': '2021-01-08',
#   'sc': '300040.SZ',
#   'sn': '九洲集团',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '123101.SZ': {'cn': '拓斯转债',
#   'ipo': '2021-03-29',
#   'sc': '300607.SZ',
#   'sn': '拓斯达',
#   'cat1': '机械设备(2021)',
#   'cat2': '自动化设备(2021)'},
#  '123103.SZ': {'cn': '震安转债',
#   'ipo': '2021-03-31',
#   'sc': '300767.SZ',
#   'sn': '震安科技',
#   'cat1': '基础化工(2021)',
#   'cat2': '橡胶(2021)'},
#  '123109.SZ': {'cn': '昌红转债',
#   'ipo': '2021-04-19',
#   'sc': '300151.SZ',
#   'sn': '昌红科技',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '123112.SZ': {'cn': '万讯转债',
#   'ipo': '2021-04-23',
#   'sc': '300112.SZ',
#   'sn': '万讯自控',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '123114.SZ': {'cn': '三角转债',
#   'ipo': '2021-06-11',
#   'sc': '300775.SZ',
#   'sn': '三角防务',
#   'cat1': '国防军工(2021)',
#   'cat2': '航空装备Ⅱ(2021)'},
#  '123120.SZ': {'cn': '隆华转债',
#   'ipo': '2021-08-23',
#   'sc': '300263.SZ',
#   'sn': '隆华科技',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '123127.SZ': {'cn': '耐普转债',
#   'ipo': '2021-11-19',
#   'sc': '300818.SZ',
#   'sn': '耐普矿机',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '123130.SZ': {'cn': '设研转债',
#   'ipo': '2021-12-02',
#   'sc': '300732.SZ',
#   'sn': '设研院',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '工程咨询服务Ⅱ(2021)'},
#  '123134.SZ': {'cn': '卡倍转债',
#   'ipo': '2022-01-18',
#   'sc': '300863.SZ',
#   'sn': '卡倍亿',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '123136.SZ': {'cn': '城市转债',
#   'ipo': '2022-02-15',
#   'sc': '300778.SZ',
#   'sn': '新城市',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '工程咨询服务Ⅱ(2021)'},
#  '123141.SZ': {'cn': '宏丰转债',
#   'ipo': '2022-04-08',
#   'sc': '300283.SZ',
#   'sn': '温州宏丰',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '123142.SZ': {'cn': '申昊转债',
#   'ipo': '2022-04-11',
#   'sc': '300853.SZ',
#   'sn': '申昊科技',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '123146.SZ': {'cn': '中环转2',
#   'ipo': '2022-05-26',
#   'sc': '300692.SZ',
#   'sn': '中环环保',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '123147.SZ': {'cn': '中辰转债',
#   'ipo': '2022-06-21',
#   'sc': '300933.SZ',
#   'sn': '中辰股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '123148.SZ': {'cn': '上能转债',
#   'ipo': '2022-07-01',
#   'sc': '300827.SZ',
#   'sn': '上能电气',
#   'cat1': '电力设备(2021)',
#   'cat2': '光伏设备(2021)'},
#  '123149.SZ': {'cn': '通裕转债',
#   'ipo': '2022-07-15',
#   'sc': '300185.SZ',
#   'sn': '通裕重工',
#   'cat1': '电力设备(2021)',
#   'cat2': '风电设备(2021)'},
#  '123155.SZ': {'cn': '中陆转债',
#   'ipo': '2022-08-31',
#   'sc': '301040.SZ',
#   'sn': '中环海陆',
#   'cat1': '电力设备(2021)',
#   'cat2': '风电设备(2021)'},
#  '123159.SZ': {'cn': '崧盛转债',
#   'ipo': '2022-10-24',
#   'sc': '301002.SZ',
#   'sn': '崧盛股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '电网设备(2021)'},
#  '123160.SZ': {'cn': '泰福转债',
#   'ipo': '2022-10-25',
#   'sc': '300992.SZ',
#   'sn': '泰福泵业',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '123161.SZ': {'cn': '强联转债',
#   'ipo': '2022-10-27',
#   'sc': '300850.SZ',
#   'sn': '新强联',
#   'cat1': '电力设备(2021)',
#   'cat2': '风电设备(2021)'},
#  '123162.SZ': {'cn': '东杰转债',
#   'ipo': '2022-11-04',
#   'sc': '300486.SZ',
#   'sn': '东杰智能',
#   'cat1': '机械设备(2021)',
#   'cat2': '自动化设备(2021)'},
#  '123163.SZ': {'cn': '金沃转债',
#   'ipo': '2022-11-07',
#   'sc': '300984.SZ',
#   'sn': '金沃股份',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '127012.SZ': {'cn': '招路转债',
#   'ipo': '2019-04-30',
#   'sc': '001965.SZ',
#   'sn': '招商公路',
#   'cat1': '交通运输(2021)',
#   'cat2': '铁路公路(2021)'},
#  '127014.SZ': {'cn': '北方转债',
#   'ipo': '2019-11-21',
#   'sc': '000065.SZ',
#   'sn': '北方国际',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '专业工程(2021)'},
#  '127024.SZ': {'cn': '盈峰转债',
#   'ipo': '2020-12-02',
#   'sc': '000967.SZ',
#   'sn': '盈峰环境',
#   'cat1': '环保(2021)',
#   'cat2': '环保设备Ⅱ(2021)'},
#  '127029.SZ': {'cn': '中钢转债',
#   'ipo': '2021-04-23',
#   'sc': '000928.SZ',
#   'sn': '中钢国际',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '专业工程(2021)'},
#  '127033.SZ': {'cn': '中装转2',
#   'ipo': '2021-05-24',
#   'sc': '002822.SZ',
#   'sn': '中装建设',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '装修装饰Ⅱ(2021)'},
#  '127034.SZ': {'cn': '绿茵转债',
#   'ipo': '2021-05-28',
#   'sc': '002887.SZ',
#   'sn': '绿茵生态',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '127036.SZ': {'cn': '三花转债',
#   'ipo': '2021-06-30',
#   'sc': '002050.SZ',
#   'sn': '三花智控',
#   'cat1': '家用电器(2021)',
#   'cat2': '家电零部件Ⅱ(2021)'},
#  '127039.SZ': {'cn': '北港转债',
#   'ipo': '2021-07-23',
#   'sc': '000582.SZ',
#   'sn': '北部湾港',
#   'cat1': '交通运输(2021)',
#   'cat2': '航运港口(2021)'},
#  '127040.SZ': {'cn': '国泰转债',
#   'ipo': '2021-08-10',
#   'sc': '002091.SZ',
#   'sn': '江苏国泰',
#   'cat1': '商贸零售(2021)',
#   'cat2': '贸易Ⅱ(2021)'},
#  '127041.SZ': {'cn': '弘亚转债',
#   'ipo': '2021-08-10',
#   'sc': '002833.SZ',
#   'sn': '弘亚数控',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '127044.SZ': {'cn': '蒙娜转债',
#   'ipo': '2021-09-16',
#   'sc': '002918.SZ',
#   'sn': '蒙娜丽莎',
#   'cat1': '轻工制造(2021)',
#   'cat2': '家居用品(2021)'},
#  '127047.SZ': {'cn': '帝欧转债',
#   'ipo': '2021-11-26',
#   'sc': '002798.SZ',
#   'sn': '帝欧家居',
#   'cat1': '轻工制造(2021)',
#   'cat2': '家居用品(2021)'},
#  '127051.SZ': {'cn': '博杰转债',
#   'ipo': '2021-12-17',
#   'sc': '002975.SZ',
#   'sn': '博杰股份',
#   'cat1': '机械设备(2021)',
#   'cat2': '自动化设备(2021)'},
#  '127052.SZ': {'cn': '西子转债',
#   'ipo': '2022-01-24',
#   'sc': '002534.SZ',
#   'sn': '西子洁能',
#   'cat1': '电力设备(2021)',
#   'cat2': '其他电源设备Ⅱ(2021)'},
#  '127055.SZ': {'cn': '精装转债',
#   'ipo': '2022-03-24',
#   'sc': '002989.SZ',
#   'sn': '中天精装',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '装修装饰Ⅱ(2021)'},
#  '127064.SZ': {'cn': '杭氧转债',
#   'ipo': '2022-07-05',
#   'sc': '002430.SZ',
#   'sn': '杭氧股份',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '127066.SZ': {'cn': '科利转债',
#   'ipo': '2022-08-03',
#   'sc': '002850.SZ',
#   'sn': '科达利',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '127071.SZ': {'cn': '天箭转债',
#   'ipo': '2022-09-19',
#   'sc': '003009.SZ',
#   'sn': '中天火箭',
#   'cat1': '国防军工(2021)',
#   'cat2': '航天装备Ⅱ(2021)'},
#  '127072.SZ': {'cn': '博实转债',
#   'ipo': '2022-11-03',
#   'sc': '002698.SZ',
#   'sn': '博实股份',
#   'cat1': '机械设备(2021)',
#   'cat2': '自动化设备(2021)'},
#  '127074.SZ': {'cn': '麦米转2',
#   'ipo': '2022-11-09',
#   'sc': '002851.SZ',
#   'sn': '麦格米特',
#   'cat1': '电力设备(2021)',
#   'cat2': '其他电源设备Ⅱ(2021)'},
#  '127077.SZ': {'cn': '华宏转债',
#   'ipo': '2023-01-10',
#   'sc': '002645.SZ',
#   'sn': '华宏科技',
#   'cat1': '环保(2021)',
#   'cat2': '环保设备Ⅱ(2021)'},
#  '127079.SZ': {'cn': '华亚转债',
#   'ipo': '2023-01-16',
#   'sc': '003043.SZ',
#   'sn': '华亚智能',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '128037.SZ': {'cn': '岩土转债',
#   'ipo': '2018-04-25',
#   'sc': '002542.SZ',
#   'sn': '中化岩土',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '专业工程(2021)'},
#  '128041.SZ': {'cn': '盛路转债',
#   'ipo': '2018-08-14',
#   'sc': '002446.SZ',
#   'sn': '盛路通信',
#   'cat1': '国防军工(2021)',
#   'cat2': '军工电子Ⅱ(2021)'},
#  '128042.SZ': {'cn': '凯中转债',
#   'ipo': '2018-09-03',
#   'sc': '002823.SZ',
#   'sn': '凯中精密',
#   'cat1': '电力设备(2021)',
#   'cat2': '电机Ⅱ(2021)'},
#  '128044.SZ': {'cn': '岭南转债',
#   'ipo': '2018-09-04',
#   'sc': '002717.SZ',
#   'sn': '岭南股份',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '基础建设(2021)'},
#  '128066.SZ': {'cn': '亚泰转债',
#   'ipo': '2019-05-14',
#   'sc': '002811.SZ',
#   'sn': '郑中设计',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '装修装饰Ⅱ(2021)'},
#  '128070.SZ': {'cn': '智能转债',
#   'ipo': '2019-07-23',
#   'sc': '002877.SZ',
#   'sn': '智能自控',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '128076.SZ': {'cn': '金轮转债',
#   'ipo': '2019-11-08',
#   'sc': '002722.SZ',
#   'sn': '物产金轮',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '纺织制造(2021)'},
#  '128120.SZ': {'cn': '联诚转债',
#   'ipo': '2020-08-17',
#   'sc': '002921.SZ',
#   'sn': '联诚精密',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '128121.SZ': {'cn': '宏川转债',
#   'ipo': '2020-08-07',
#   'sc': '002930.SZ',
#   'sn': '宏川智慧',
#   'cat1': '交通运输(2021)',
#   'cat2': '物流(2021)'},
#  '128125.SZ': {'cn': '华阳转债',
#   'ipo': '2020-08-21',
#   'sc': '002949.SZ',
#   'sn': '华阳国际',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '工程咨询服务Ⅱ(2021)'},
#  '128127.SZ': {'cn': '文科转债',
#   'ipo': '2020-09-11',
#   'sc': '002775.SZ',
#   'sn': '文科园林',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '基础建设(2021)'},
#  '128132.SZ': {'cn': '交建转债',
#   'ipo': '2020-10-16',
#   'sc': '002941.SZ',
#   'sn': '新疆交建',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '基础建设(2021)'},
#  '128134.SZ': {'cn': '鸿路转债',
#   'ipo': '2020-11-02',
#   'sc': '002541.SZ',
#   'sn': '鸿路钢构',
#   'cat1': '建筑装饰(2021)',
#   'cat2': '专业工程(2021)'},
#  '128138.SZ': {'cn': '侨银转债',
#   'ipo': '2020-12-24',
#   'sc': '002973.SZ',
#   'sn': '侨银股份',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '128141.SZ': {'cn': '旺能转债',
#   'ipo': '2021-01-18',
#   'sc': '002034.SZ',
#   'sn': '旺能环境',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '128143.SZ': {'cn': '锋龙转债',
#   'ipo': '2021-01-29',
#   'sc': '002931.SZ',
#   'sn': '锋龙股份',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '110044.SH': {'cn': '广电转债',
#   'ipo': '2018-07-24',
#   'sc': '600831.SH',
#   'sn': '广电网络',
#   'cat1': '传媒(2021)',
#   'cat2': '电视广播Ⅱ(2021)'},
#  '110045.SH': {'cn': '海澜转债',
#   'ipo': '2018-07-31',
#   'sc': '600398.SH',
#   'sn': '海澜之家',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '服装家纺(2021)'},
#  '110052.SH': {'cn': '贵广转债',
#   'ipo': '2019-03-29',
#   'sc': '600996.SH',
#   'sn': '贵广网络',
#   'cat1': '传媒(2021)',
#   'cat2': '电视广播Ⅱ(2021)'},
#  '110072.SH': {'cn': '广汇转债',
#   'ipo': '2020-09-15',
#   'sc': '600297.SH',
#   'sn': '广汇汽车',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车服务(2021)'},
#  '110090.SH': {'cn': '爱迪转债',
#   'ipo': '2022-10-28',
#   'sc': '600933.SH',
#   'sn': '爱柯迪',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '111004.SH': {'cn': '明新转债',
#   'ipo': '2022-04-25',
#   'sc': '605068.SH',
#   'sn': '明新旭腾',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '111005.SH': {'cn': '富春转债',
#   'ipo': '2022-07-25',
#   'sc': '605189.SH',
#   'sn': '富春染织',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '纺织制造(2021)'},
#  '111006.SH': {'cn': '嵘泰转债',
#   'ipo': '2022-09-21',
#   'sc': '605133.SH',
#   'sn': '嵘泰股份',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '111008.SH': {'cn': '沿浦转债',
#   'ipo': '2022-11-28',
#   'sc': '605128.SH',
#   'sn': '上海沿浦',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '111009.SH': {'cn': '盛泰转债',
#   'ipo': '2022-12-01',
#   'sc': '605138.SH',
#   'sn': '盛泰集团',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '服装家纺(2021)'},
#  '111011.SH': {'cn': '冠盛转债',
#   'ipo': '2023-02-06',
#   'sc': '605088.SH',
#   'sn': '冠盛股份',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '113016.SH': {'cn': '小康转债',
#   'ipo': '2017-11-21',
#   'sc': '601127.SH',
#   'sn': '赛力斯',
#   'cat1': '汽车(2021)',
#   'cat2': '乘用车(2021)'},
#  '113017.SH': {'cn': '吉视转债',
#   'ipo': '2018-01-15',
#   'sc': '601929.SH',
#   'sn': '吉视传媒',
#   'cat1': '传媒(2021)',
#   'cat2': '电视广播Ⅱ(2021)'},
#  '113033.SH': {'cn': '利群转债',
#   'ipo': '2020-04-21',
#   'sc': '601366.SH',
#   'sn': '利群股份',
#   'cat1': '商贸零售(2021)',
#   'cat2': '一般零售(2021)'},
#  '113049.SH': {'cn': '长汽转债',
#   'ipo': '2021-07-08',
#   'sc': '601633.SH',
#   'sn': '长城汽车',
#   'cat1': '汽车(2021)',
#   'cat2': '乘用车(2021)'},
#  '113061.SH': {'cn': '拓普转债',
#   'ipo': '2022-08-12',
#   'sc': '601689.SH',
#   'sn': '拓普集团',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '113063.SH': {'cn': '赛轮转债',
#   'ipo': '2022-11-24',
#   'sc': '601058.SH',
#   'sn': '赛轮轮胎',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '113524.SH': {'cn': '奇精转债',
#   'ipo': '2019-01-07',
#   'sc': '603677.SH',
#   'sn': '奇精机械',
#   'cat1': '家用电器(2021)',
#   'cat2': '家电零部件Ⅱ(2021)'},
#  '113527.SH': {'cn': '维格转债',
#   'ipo': '2019-02-19',
#   'sc': '603518.SH',
#   'sn': '锦泓集团',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '服装家纺(2021)'},
#  '113537.SH': {'cn': '文灿转债',
#   'ipo': '2019-07-05',
#   'sc': '603348.SH',
#   'sn': '文灿股份',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '113542.SH': {'cn': '好客转债',
#   'ipo': '2019-08-23',
#   'sc': '603898.SH',
#   'sn': '好莱客',
#   'cat1': '轻工制造(2021)',
#   'cat2': '家居用品(2021)'},
#  '113561.SH': {'cn': '正裕转债',
#   'ipo': '2020-02-10',
#   'sc': '603089.SH',
#   'sn': '正裕工业',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '113575.SH': {'cn': '东时转债',
#   'ipo': '2020-04-30',
#   'sc': '603377.SH',
#   'sn': '东方时尚',
#   'cat1': '社会服务(2021)',
#   'cat2': '教育(2021)'},
#  '113576.SH': {'cn': '起步转债',
#   'ipo': '2020-05-07',
#   'sc': '603557.SH',
#   'sn': 'ST起步',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '服装家纺(2021)'},
#  '113589.SH': {'cn': '天创转债',
#   'ipo': '2020-07-16',
#   'sc': '603608.SH',
#   'sn': '天创时尚',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '服装家纺(2021)'},
#  '113625.SH': {'cn': '江山转债',
#   'ipo': '2021-07-01',
#   'sc': '603208.SH',
#   'sn': '江山欧派',
#   'cat1': '轻工制造(2021)',
#   'cat2': '家居用品(2021)'},
#  '113626.SH': {'cn': '伯特转债',
#   'ipo': '2021-07-21',
#   'sc': '603596.SH',
#   'sn': '伯特利',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '113627.SH': {'cn': '太平转债',
#   'ipo': '2021-08-06',
#   'sc': '603877.SH',
#   'sn': '太平鸟',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '服装家纺(2021)'},
#  '113628.SH': {'cn': '晨丰转债',
#   'ipo': '2021-09-17',
#   'sc': '603685.SH',
#   'sn': '晨丰科技',
#   'cat1': '电子(2021)',
#   'cat2': '光学光电子(2021)'},
#  '113629.SH': {'cn': '泉峰转债',
#   'ipo': '2021-10-21',
#   'sc': '603982.SH',
#   'sn': '泉峰汽车',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '113633.SH': {'cn': '科沃转债',
#   'ipo': '2021-12-29',
#   'sc': '603486.SH',
#   'sn': '科沃斯',
#   'cat1': '家用电器(2021)',
#   'cat2': '小家电(2021)'},
#  '113643.SH': {'cn': '风语转债',
#   'ipo': '2022-04-22',
#   'sc': '603466.SH',
#   'sn': '风语筑',
#   'cat1': '传媒(2021)',
#   'cat2': '数字媒体(2021)'},
#  '113655.SH': {'cn': '欧22转债',
#   'ipo': '2022-09-01',
#   'sc': '603833.SH',
#   'sn': '欧派家居',
#   'cat1': '轻工制造(2021)',
#   'cat2': '家居用品(2021)'},
#  '113659.SH': {'cn': '莱克转债',
#   'ipo': '2022-11-15',
#   'sc': '603355.SH',
#   'sn': '莱克电气',
#   'cat1': '家用电器(2021)',
#   'cat2': '小家电(2021)'},
#  '113662.SH': {'cn': '豪能转债',
#   'ipo': '2022-12-23',
#   'sc': '603809.SH',
#   'sn': '豪能股份',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '123011.SZ': {'cn': '德尔转债',
#   'ipo': '2018-08-14',
#   'sc': '300473.SZ',
#   'sn': '德尔股份',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '123039.SZ': {'cn': '开润转债',
#   'ipo': '2020-01-23',
#   'sc': '300577.SZ',
#   'sn': '开润股份',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '服装家纺(2021)'},
#  '123072.SZ': {'cn': '乐歌转债',
#   'ipo': '2020-11-10',
#   'sc': '300729.SZ',
#   'sn': '乐歌股份',
#   'cat1': '轻工制造(2021)',
#   'cat2': '家居用品(2021)'},
#  '123075.SZ': {'cn': '贝斯转债',
#   'ipo': '2020-11-23',
#   'sc': '300580.SZ',
#   'sn': '贝斯特',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '123088.SZ': {'cn': '威唐转债',
#   'ipo': '2021-01-06',
#   'sc': '300707.SZ',
#   'sn': '威唐工业',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '123093.SZ': {'cn': '金陵转债',
#   'ipo': '2021-02-18',
#   'sc': '300651.SZ',
#   'sn': '金陵体育',
#   'cat1': '社会服务(2021)',
#   'cat2': '体育Ⅱ(2021)'},
#  '123154.SZ': {'cn': '火星转债',
#   'ipo': '2022-08-23',
#   'sc': '300894.SZ',
#   'sn': '火星人',
#   'cat1': '家用电器(2021)',
#   'cat2': '厨卫电器(2021)'},
#  '123174.SZ': {'cn': '精锻转债',
#   'ipo': '2023-03-07',
#   'sc': '300258.SZ',
#   'sn': '精锻科技',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '127004.SZ': {'cn': '模塑转债',
#   'ipo': '2017-06-26',
#   'sc': '000700.SZ',
#   'sn': '模塑科技',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '127007.SZ': {'cn': '湖广转债',
#   'ipo': '2018-08-01',
#   'sc': '000665.SZ',
#   'sn': '湖北广电',
#   'cat1': '传媒(2021)',
#   'cat2': '电视广播Ⅱ(2021)'},
#  '127016.SZ': {'cn': '鲁泰转债',
#   'ipo': '2020-05-13',
#   'sc': '000726.SZ',
#   'sn': '鲁泰A',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '纺织制造(2021)'},
#  '127037.SZ': {'cn': '银轮转债',
#   'ipo': '2021-07-09',
#   'sc': '002126.SZ',
#   'sn': '银轮股份',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '127050.SZ': {'cn': '麒麟转债',
#   'ipo': '2021-12-06',
#   'sc': '002984.SZ',
#   'sn': '森麒麟',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '127063.SZ': {'cn': '贵轮转债',
#   'ipo': '2022-05-30',
#   'sc': '000589.SZ',
#   'sn': '贵州轮胎',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '127065.SZ': {'cn': '瑞鹄转债',
#   'ipo': '2022-07-27',
#   'sc': '002997.SZ',
#   'sn': '瑞鹄模具',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '127069.SZ': {'cn': '小熊转债',
#   'ipo': '2022-09-07',
#   'sc': '002959.SZ',
#   'sn': '小熊电器',
#   'cat1': '家用电器(2021)',
#   'cat2': '小家电(2021)'},
#  '128023.SZ': {'cn': '亚太转债',
#   'ipo': '2017-12-26',
#   'sc': '002284.SZ',
#   'sn': '亚太股份',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '128056.SZ': {'cn': '今飞转债',
#   'ipo': '2019-03-22',
#   'sc': '002863.SZ',
#   'sn': '今飞凯达',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '128075.SZ': {'cn': '远东转债',
#   'ipo': '2019-10-31',
#   'sc': '002406.SZ',
#   'sn': '远东传动',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '128082.SZ': {'cn': '华锋转债',
#   'ipo': '2020-01-06',
#   'sc': '002806.SZ',
#   'sn': '华锋股份',
#   'cat1': '有色金属(2021)',
#   'cat2': '工业金属(2021)'},
#  '128087.SZ': {'cn': '孚日转债',
#   'ipo': '2020-01-16',
#   'sc': '002083.SZ',
#   'sn': '孚日股份',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '纺织制造(2021)'},
#  '128090.SZ': {'cn': '汽模转2',
#   'ipo': '2020-01-23',
#   'sc': '002510.SZ',
#   'sn': '天汽模',
#   'cat1': '汽车(2021)',
#   'cat2': '汽车零部件(2021)'},
#  '128100.SZ': {'cn': '搜特转债',
#   'ipo': '2020-04-09',
#   'sc': '002503.SZ',
#   'sn': '搜于特',
#   'cat1': '纺织服饰(2021)',
#   'cat2': '服装家纺(2021)'},
#  '110055.SH': {'cn': '伊力转债',
#   'ipo': '2019-04-04',
#   'sc': '600197.SH',
#   'sn': '伊力特',
#   'cat1': '食品饮料(2021)',
#   'cat2': 'IT服务Ⅱ(2021)'},
#  '113565.SH': {'cn': '宏辉转债',
#   'ipo': '2020-03-16',
#   'sc': '603336.SH',
#   'sn': '宏辉果蔬',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '种植业(2021)'},
#  '113584.SH': {'cn': '家悦转债',
#   'ipo': '2020-06-24',
#   'sc': '603708.SH',
#   'sn': '家家悦',
#   'cat1': '商贸零售(2021)',
#   'cat2': '一般零售(2021)'},
#  '113605.SH': {'cn': '大参转债',
#   'ipo': '2020-11-13',
#   'sc': '603233.SH',
#   'sn': '大参林',
#   'cat1': '医药生物(2021)',
#   'cat2': '医药商业(2021)'},
#  '113634.SH': {'cn': '珀莱转债',
#   'ipo': '2022-01-04',
#   'sc': '603605.SH',
#   'sn': '珀莱雅',
#   'cat1': '美容护理(2021)',
#   'cat2': '化妆品(2021)'},
#  '113647.SH': {'cn': '禾丰转债',
#   'ipo': '2022-05-18',
#   'sc': '603609.SH',
#   'sn': '禾丰股份',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '饲料(2021)'},
#  '113648.SH': {'cn': '巨星转债',
#   'ipo': '2022-05-17',
#   'sc': '603477.SH',
#   'sn': '巨星农牧',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '养殖业(2021)'},
#  '123056.SZ': {'cn': '雪榕转债',
#   'ipo': '2020-07-24',
#   'sc': '300511.SZ',
#   'sn': '雪榕生物',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '种植业(2021)'},
#  '123107.SZ': {'cn': '温氏转债',
#   'ipo': '2021-04-21',
#   'sc': '300498.SZ',
#   'sn': '温氏股份',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '养殖业(2021)'},
#  '123133.SZ': {'cn': '佩蒂转债',
#   'ipo': '2022-01-21',
#   'sc': '300673.SZ',
#   'sn': '佩蒂股份',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '饲料(2021)'},
#  '123172.SZ': {'cn': '漱玉转债',
#   'ipo': '2023-01-06',
#   'sc': '301017.SZ',
#   'sn': '漱玉平民',
#   'cat1': '医药生物(2021)',
#   'cat2': '医药商业(2021)'},
#  '127015.SZ': {'cn': '希望转债',
#   'ipo': '2020-02-04',
#   'sc': '000876.SZ',
#   'sn': '新希望',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '养殖业(2021)'},
#  '127045.SZ': {'cn': '牧原转债',
#   'ipo': '2021-09-10',
#   'sc': '002714.SZ',
#   'sn': '牧原股份',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '养殖业(2021)'},
#  '127046.SZ': {'cn': '百润转债',
#   'ipo': '2021-11-03',
#   'sc': '002568.SZ',
#   'sn': '百润股份',
#   'cat1': '食品饮料(2021)',
#   'cat2': '非白酒(2021)'},
#  '127049.SZ': {'cn': '希望转2',
#   'ipo': '2021-11-29',
#   'sc': '000876.SZ',
#   'sn': '新希望',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '养殖业(2021)'},
#  '127060.SZ': {'cn': '湘佳转债',
#   'ipo': '2022-06-10',
#   'sc': '002982.SZ',
#   'sn': '湘佳股份',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '养殖业(2021)'},
#  '127076.SZ': {'cn': '中宠转2',
#   'ipo': '2022-11-21',
#   'sc': '002891.SZ',
#   'sn': '中宠股份',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '饲料(2021)'},
#  '128017.SZ': {'cn': '金禾转债',
#   'ipo': '2017-11-27',
#   'sc': '002597.SZ',
#   'sn': '金禾实业',
#   'cat1': '基础化工(2021)',
#   'cat2': '化学制品(2021)'},
#  '128026.SZ': {'cn': '众兴转债',
#   'ipo': '2018-01-03',
#   'sc': '002772.SZ',
#   'sn': '众兴菌业',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '种植业(2021)'},
#  '128030.SZ': {'cn': '天康转债',
#   'ipo': '2018-01-29',
#   'sc': '002100.SZ',
#   'sn': '天康生物',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '饲料(2021)'},
#  '128036.SZ': {'cn': '金农转债',
#   'ipo': '2018-04-02',
#   'sc': '002548.SZ',
#   'sn': '金新农',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '饲料(2021)'},
#  '128106.SZ': {'cn': '华统转债',
#   'ipo': '2020-05-08',
#   'sc': '002840.SZ',
#   'sn': '华统股份',
#   'cat1': '食品饮料(2021)',
#   'cat2': '食品加工(2021)'},
#  '128114.SZ': {'cn': '正邦转债',
#   'ipo': '2020-07-15',
#   'sc': '002157.SZ',
#   'sn': '正邦科技',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '养殖业(2021)'},
#  '128119.SZ': {'cn': '龙大转债',
#   'ipo': '2020-08-07',
#   'sc': '002726.SZ',
#   'sn': '龙大美食',
#   'cat1': '食品饮料(2021)',
#   'cat2': '食品加工(2021)'},
#  '128135.SZ': {'cn': '洽洽转债',
#   'ipo': '2020-11-18',
#   'sc': '002557.SZ',
#   'sn': '洽洽食品',
#   'cat1': '食品饮料(2021)',
#   'cat2': '休闲食品(2021)'},
#  '128142.SZ': {'cn': '新乳转债',
#   'ipo': '2021-01-19',
#   'sc': '002946.SZ',
#   'sn': '新乳业',
#   'cat1': '食品饮料(2021)',
#   'cat2': '饮料乳品(2021)'},
#  '110057.SH': {'cn': '现代转债',
#   'ipo': '2019-04-30',
#   'sc': '600420.SH',
#   'sn': '国药现代',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '110076.SH': {'cn': '华海转债',
#   'ipo': '2020-11-25',
#   'sc': '600521.SH',
#   'sn': '华海药业',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '113563.SH': {'cn': '柳药转债',
#   'ipo': '2020-02-24',
#   'sc': '603368.SH',
#   'sn': '柳药集团',
#   'cat1': '医药生物(2021)',
#   'cat2': '医药商业(2021)'},
#  '113579.SH': {'cn': '健友转债',
#   'ipo': '2020-05-22',
#   'sc': '603707.SH',
#   'sn': '健友股份',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '113585.SH': {'cn': '寿仙转债',
#   'ipo': '2020-07-07',
#   'sc': '603896.SH',
#   'sn': '寿仙谷',
#   'cat1': '医药生物(2021)',
#   'cat2': '中药Ⅱ(2021)'},
#  '113588.SH': {'cn': '润达转债',
#   'ipo': '2020-07-13',
#   'sc': '603108.SH',
#   'sn': '润达医疗',
#   'cat1': '医药生物(2021)',
#   'cat2': '医药商业(2021)'},
#  '113601.SH': {'cn': '塞力转债',
#   'ipo': '2020-09-15',
#   'sc': '603716.SH',
#   'sn': '塞力医疗',
#   'cat1': '医药生物(2021)',
#   'cat2': '医药商业(2021)'},
#  '113606.SH': {'cn': '荣泰转债',
#   'ipo': '2020-11-20',
#   'sc': '603579.SH',
#   'sn': '荣泰健康',
#   'cat1': '家用电器(2021)',
#   'cat2': '其他家电Ⅱ(2021)'},
#  '113610.SH': {'cn': '灵康转债',
#   'ipo': '2020-12-22',
#   'sc': '603669.SH',
#   'sn': '灵康药业',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '113618.SH': {'cn': '美诺转债',
#   'ipo': '2021-02-04',
#   'sc': '603538.SH',
#   'sn': '美诺华',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '113624.SH': {'cn': '正川转债',
#   'ipo': '2021-06-01',
#   'sc': '603976.SH',
#   'sn': '正川股份',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '113660.SH': {'cn': '寿22转债',
#   'ipo': '2022-12-12',
#   'sc': '603896.SH',
#   'sn': '寿仙谷',
#   'cat1': '医药生物(2021)',
#   'cat2': '中药Ⅱ(2021)'},
#  '118004.SH': {'cn': '博瑞转债',
#   'ipo': '2022-01-27',
#   'sc': '688166.SH',
#   'sn': '博瑞医药',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '118012.SH': {'cn': '微芯转债',
#   'ipo': '2022-07-28',
#   'sc': '688321.SH',
#   'sn': '微芯生物',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '123018.SZ': {'cn': '溢利转债',
#   'ipo': '2019-01-23',
#   'sc': '300381.SZ',
#   'sn': '溢多利',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '123029.SZ': {'cn': '英科转债',
#   'ipo': '2019-09-10',
#   'sc': '300677.SZ',
#   'sn': '英科医疗',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '123064.SZ': {'cn': '万孚转债',
#   'ipo': '2020-09-23',
#   'sc': '300482.SZ',
#   'sn': '万孚生物',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '123065.SZ': {'cn': '宝莱转债',
#   'ipo': '2020-09-24',
#   'sc': '300246.SZ',
#   'sn': '宝莱特',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '123082.SZ': {'cn': '北陆转债',
#   'ipo': '2020-12-28',
#   'sc': '300016.SZ',
#   'sn': '北陆药业',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '123090.SZ': {'cn': '三诺转债',
#   'ipo': '2021-01-12',
#   'sc': '300298.SZ',
#   'sn': '三诺生物',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '123098.SZ': {'cn': '一品转债',
#   'ipo': '2021-02-23',
#   'sc': '300723.SZ',
#   'sn': '一品红',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '123099.SZ': {'cn': '普利转债',
#   'ipo': '2021-03-08',
#   'sc': '300630.SZ',
#   'sn': '普利制药',
#   'cat1': '医药生物(2021)',
#   'cat2': '化学制药(2021)'},
#  '123108.SZ': {'cn': '乐普转2',
#   'ipo': '2021-04-19',
#   'sc': '300003.SZ',
#   'sn': '乐普医疗',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '123113.SZ': {'cn': '仙乐转债',
#   'ipo': '2021-05-14',
#   'sc': '300791.SZ',
#   'sn': '仙乐健康',
#   'cat1': '食品饮料(2021)',
#   'cat2': '食品加工(2021)'},
#  '123117.SZ': {'cn': '健帆转债',
#   'ipo': '2021-07-12',
#   'sc': '300529.SZ',
#   'sn': '健帆生物',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '123119.SZ': {'cn': '康泰转2',
#   'ipo': '2021-08-05',
#   'sc': '300601.SZ',
#   'sn': '康泰生物',
#   'cat1': '医药生物(2021)',
#   'cat2': '生物制品(2021)'},
#  '123132.SZ': {'cn': '回盛转债',
#   'ipo': '2022-01-07',
#   'sc': '300871.SZ',
#   'sn': '回盛生物',
#   'cat1': '农林牧渔(2021)',
#   'cat2': '动物保健Ⅱ(2021)'},
#  '123135.SZ': {'cn': '泰林转债',
#   'ipo': '2022-01-19',
#   'sc': '300813.SZ',
#   'sn': '泰林生物',
#   'cat1': '机械设备(2021)',
#   'cat2': '专用设备(2021)'},
#  '123145.SZ': {'cn': '药石转债',
#   'ipo': '2022-05-18',
# ...
#   'sn': '奥佳华',
#   'cat1': '家用电器(2021)',
#   'cat2': '其他家电Ⅱ(2021)'},
#  '128108.SZ': {'cn': '蓝帆转债',
#   'ipo': '2020-06-19',
#   'sc': '002382.SZ',
#   'sn': '蓝帆医疗',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '128124.SZ': {'cn': '科华转债',
#   'ipo': '2020-08-20',
#   'sc': '002022.SZ',
#   'sn': '*ST科华',
#   'cat1': '医药生物(2021)',
#   'cat2': '医疗器械(2021)'},
#  '128133.SZ': {'cn': '奇正转债',
#   'ipo': '2020-10-27',
#   'sc': '002287.SZ',
#   'sn': '奇正藏药',
#   'cat1': '医药生物(2021)',
#   'cat2': '中药Ⅱ(2021)'},
#  '110043.SH': {'cn': '无锡转债',
#   'ipo': '2018-03-14',
#   'sc': '600908.SH',
#   'sn': '无锡银行',
#   'cat1': '银行(2021)',
#   'cat2': '农商行Ⅱ(2021)'},
#  '110053.SH': {'cn': '苏银转债',
#   'ipo': '2019-04-03',
#   'sc': '600919.SH',
#   'sn': '江苏银行',
#   'cat1': '银行(2021)',
#   'cat2': '城商行Ⅱ(2021)'},
#  '110059.SH': {'cn': '浦发转债',
#   'ipo': '2019-11-15',
#   'sc': '600000.SH',
#   'sn': '浦发银行',
#   'cat1': '银行(2021)',
#   'cat2': '股份制银行Ⅱ(2021)'},
#  '110067.SH': {'cn': '华安转债',
#   'ipo': '2020-04-09',
#   'sc': '600909.SH',
#   'sn': '华安证券',
#   'cat1': '非银金融(2021)',
#   'cat2': '证券Ⅱ(2021)'},
#  '110073.SH': {'cn': '国投转债',
#   'ipo': '2020-08-20',
#   'sc': '600061.SH',
#   'sn': '国投资本',
#   'cat1': '非银金融(2021)',
#   'cat2': '多元金融(2021)'},
#  '110079.SH': {'cn': '杭银转债',
#   'ipo': '2021-04-23',
#   'sc': '600926.SH',
#   'sn': '杭州银行',
#   'cat1': '银行(2021)',
#   'cat2': '城商行Ⅱ(2021)'},
#  '110083.SH': {'cn': '苏租转债',
#   'ipo': '2021-12-10',
#   'sc': '600901.SH',
#   'sn': '江苏金租',
#   'cat1': '非银金融(2021)',
#   'cat2': '多元金融(2021)'},
#  '113011.SH': {'cn': '光大转债(退市)',
#   'ipo': '2017-04-05',
#   'sc': '601818.SH',
#   'sn': '光大银行',
#   'cat1': '银行(2021)',
#   'cat2': '股份制银行Ⅱ(2021)'},
#  '113013.SH': {'cn': '国君转债',
#   'ipo': '2017-07-24',
#   'sc': '601211.SH',
#   'sn': '国泰君安',
#   'cat1': '非银金融(2021)',
#   'cat2': '证券Ⅱ(2021)'},
#  '113021.SH': {'cn': '中信转债',
#   'ipo': '2019-03-19',
#   'sc': '601998.SH',
#   'sn': '中信银行',
#   'cat1': '银行(2021)',
#   'cat2': '股份制银行Ⅱ(2021)'},
#  '113037.SH': {'cn': '紫银转债',
#   'ipo': '2020-08-17',
#   'sc': '601860.SH',
#   'sn': '紫金银行',
#   'cat1': '银行(2021)',
#   'cat2': '农商行Ⅱ(2021)'},
#  '113042.SH': {'cn': '上银转债',
#   'ipo': '2021-02-10',
#   'sc': '601229.SH',
#   'sn': '上海银行',
#   'cat1': '银行(2021)',
#   'cat2': '城商行Ⅱ(2021)'},
#  '113043.SH': {'cn': '财通转债',
#   'ipo': '2020-12-28',
#   'sc': '601108.SH',
#   'sn': '财通证券',
#   'cat1': '非银金融(2021)',
#   'cat2': '证券Ⅱ(2021)'},
#  '113050.SH': {'cn': '南银转债',
#   'ipo': '2021-07-01',
#   'sc': '601009.SH',
#   'sn': '南京银行',
#   'cat1': '银行(2021)',
#   'cat2': '城商行Ⅱ(2021)'},
#  '113052.SH': {'cn': '兴业转债',
#   'ipo': '2022-01-14',
#   'sc': '601166.SH',
#   'sn': '兴业银行',
#   'cat1': '银行(2021)',
#   'cat2': '股份制银行Ⅱ(2021)'},
#  '113055.SH': {'cn': '成银转债',
#   'ipo': '2022-04-06',
#   'sc': '601838.SH',
#   'sn': '成都银行',
#   'cat1': '银行(2021)',
#   'cat2': '城商行Ⅱ(2021)'},
#  '113056.SH': {'cn': '重银转债',
#   'ipo': '2022-04-14',
#   'sc': '601963.SH',
#   'sn': '重庆银行',
#   'cat1': '银行(2021)',
#   'cat2': '城商行Ⅱ(2021)'},
#  '113057.SH': {'cn': '中银转债',
#   'ipo': '2022-05-10',
#   'sc': '601881.SH',
#   'sn': '中国银河',
#   'cat1': '非银金融(2021)',
#   'cat2': '证券Ⅱ(2021)'},
#  '113060.SH': {'cn': '浙22转债',
#   'ipo': '2022-07-08',
#   'sc': '601878.SH',
#   'sn': '浙商证券',
#   'cat1': '非银金融(2021)',
#   'cat2': '证券Ⅱ(2021)'},
#  '113062.SH': {'cn': '常银转债',
#   'ipo': '2022-10-17',
#   'sc': '601128.SH',
#   'sn': '常熟银行',
#   'cat1': '银行(2021)',
#   'cat2': '农商行Ⅱ(2021)'},
#  '113065.SH': {'cn': '齐鲁转债',
#   'ipo': '2022-12-19',
#   'sc': '601665.SH',
#   'sn': '齐鲁银行',
#   'cat1': '银行(2021)',
#   'cat2': '城商行Ⅱ(2021)'},
#  '113516.SH': {'cn': '苏农转债',
#   'ipo': '2018-08-20',
#   'sc': '603323.SH',
#   'sn': '苏农银行',
#   'cat1': '银行(2021)',
#   'cat2': '农商行Ⅱ(2021)'},
#  '127005.SZ': {'cn': '长证转债',
#   'ipo': '2018-04-11',
#   'sc': '000783.SZ',
#   'sn': '长江证券',
#   'cat1': '非银金融(2021)',
#   'cat2': '证券Ⅱ(2021)'},
#  '127032.SZ': {'cn': '苏行转债',
#   'ipo': '2021-05-12',
#   'sc': '002966.SZ',
#   'sn': '苏州银行',
#   'cat1': '银行(2021)',
#   'cat2': '城商行Ⅱ(2021)'},
#  '128034.SZ': {'cn': '江银转债',
#   'ipo': '2018-02-14',
#   'sc': '002807.SZ',
#   'sn': '江阴银行',
#   'cat1': '银行(2021)',
#   'cat2': '农商行Ⅱ(2021)'},
#  '128048.SZ': {'cn': '张行转债',
#   'ipo': '2018-11-29',
#   'sc': '002839.SZ',
#   'sn': '张家港行',
#   'cat1': '银行(2021)',
#   'cat2': '农商行Ⅱ(2021)'},
#  '128116.SZ': {'cn': '瑞达转债',
#   'ipo': '2020-07-24',
#   'sc': '002961.SZ',
#   'sn': '瑞达期货',
#   'cat1': '非银金融(2021)',
#   'cat2': '多元金融(2021)'},
#  '128129.SZ': {'cn': '青农转债',
#   'ipo': '2020-09-18',
#   'sc': '002958.SZ',
#   'sn': '青农商行',
#   'cat1': '银行(2021)',
#   'cat2': '农商行Ⅱ(2021)'},
#  '110058.SH': {'cn': '永鼎转债',
#   'ipo': '2019-05-08',
#   'sc': '600105.SH',
#   'sn': '永鼎股份',
#   'cat1': '通信(2021)',
#   'cat2': '通信设备(2021)'},
#  '110062.SH': {'cn': '烽火转债',
#   'ipo': '2019-12-25',
#   'sc': '600498.SH',
#   'sn': '烽火通信',
#   'cat1': '通信(2021)',
#   'cat2': '通信设备(2021)'},
#  '110081.SH': {'cn': '闻泰转债',
#   'ipo': '2021-08-20',
#   'sc': '600745.SH',
#   'sn': '闻泰科技',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '110085.SH': {'cn': '通22转债',
#   'ipo': '2022-03-18',
#   'sc': '600438.SH',
#   'sn': '通威股份',
#   'cat1': '电力设备(2021)',
#   'cat2': '光伏设备(2021)'},
#  '111010.SH': {'cn': '立昂转债',
#   'ipo': '2022-12-07',
#   'sc': '605358.SH',
#   'sn': '立昂微',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '113045.SH': {'cn': '环旭转债',
#   'ipo': '2021-04-02',
#   'sc': '601231.SH',
#   'sn': '环旭电子',
#   'cat1': '电子(2021)',
#   'cat2': '消费电子(2021)'},
#  '113053.SH': {'cn': '隆22转债',
#   'ipo': '2022-02-17',
#   'sc': '601012.SH',
#   'sn': '隆基绿能',
#   'cat1': '电力设备(2021)',
#   'cat2': '光伏设备(2021)'},
#  '113504.SH': {'cn': '艾华转债',
#   'ipo': '2018-03-23',
#   'sc': '603989.SH',
#   'sn': '艾华集团',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '113569.SH': {'cn': '科达转债',
#   'ipo': '2020-04-08',
#   'sc': '603660.SH',
#   'sn': '苏州科达',
#   'cat1': '计算机(2021)',
#   'cat2': '计算机设备(2021)'},
#  '113573.SH': {'cn': '纵横转债',
#   'ipo': '2020-05-22',
#   'sc': '603602.SH',
#   'sn': '纵横通信',
#   'cat1': '通信(2021)',
#   'cat2': '通信服务(2021)'},
#  '113577.SH': {'cn': '春秋转债',
#   'ipo': '2020-05-13',
#   'sc': '603890.SH',
#   'sn': '春秋电子',
#   'cat1': '电子(2021)',
#   'cat2': '消费电子(2021)'},
#  '113582.SH': {'cn': '火炬转债',
#   'ipo': '2020-06-23',
#   'sc': '603678.SH',
#   'sn': '火炬电子',
#   'cat1': '国防军工(2021)',
#   'cat2': '军工电子Ⅱ(2021)'},
#  '113594.SH': {'cn': '淳中转债',
#   'ipo': '2020-08-28',
#   'sc': '603516.SH',
#   'sn': '淳中科技',
#   'cat1': '计算机(2021)',
#   'cat2': '计算机设备(2021)'},
#  '113596.SH': {'cn': '城地转债',
#   'ipo': '2020-08-20',
#   'sc': '603887.SH',
#   'sn': '城地香江',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '113602.SH': {'cn': '景20转债',
#   'ipo': '2020-09-22',
#   'sc': '603228.SH',
#   'sn': '景旺电子',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '113604.SH': {'cn': '多伦转债',
#   'ipo': '2020-11-17',
#   'sc': '603528.SH',
#   'sn': '多伦科技',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '113616.SH': {'cn': '韦尔转债',
#   'ipo': '2021-01-22',
#   'sc': '603501.SH',
#   'sn': '韦尔股份',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '113619.SH': {'cn': '世运转债',
#   'ipo': '2021-02-19',
#   'sc': '603920.SH',
#   'sn': '世运电路',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '113639.SH': {'cn': '华正转债',
#   'ipo': '2022-02-22',
#   'sc': '603186.SH',
#   'sn': '华正新材',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '113661.SH': {'cn': '福22转债',
#   'ipo': '2022-12-22',
#   'sc': '603806.SH',
#   'sn': '福斯特',
#   'cat1': '电力设备(2021)',
#   'cat2': '光伏设备(2021)'},
#  '118003.SH': {'cn': '华兴转债',
#   'ipo': '2021-12-20',
#   'sc': '688001.SH',
#   'sn': '华兴源创',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '118007.SH': {'cn': '山石转债',
#   'ipo': '2022-04-21',
#   'sc': '688030.SH',
#   'sn': '山石网科',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '118011.SH': {'cn': '银微转债',
#   'ipo': '2022-08-02',
#   'sc': '688689.SH',
#   'sn': '银河微电',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '118013.SH': {'cn': '道通转债',
#   'ipo': '2022-07-28',
#   'sc': '688208.SH',
#   'sn': '道通科技',
#   'cat1': '计算机(2021)',
#   'cat2': '计算机设备(2021)'},
#  '118015.SH': {'cn': '芯海转债',
#   'ipo': '2022-08-18',
#   'sc': '688595.SH',
#   'sn': '芯海科技',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '118021.SH': {'cn': '新致转债',
#   'ipo': '2022-11-02',
#   'sc': '688590.SH',
#   'sn': '新致软件',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '118024.SH': {'cn': '冠宇转债',
#   'ipo': '2022-11-17',
#   'sc': '688772.SH',
#   'sn': '珠海冠宇',
#   'cat1': '电力设备(2021)',
#   'cat2': '电池(2021)'},
#  '118027.SH': {'cn': '宏图转债',
#   'ipo': '2022-12-22',
#   'sc': '688066.SH',
#   'sn': '航天宏图',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '118030.SH': {'cn': '睿创转债',
#   'ipo': '2023-02-10',
#   'sc': '688002.SH',
#   'sn': '睿创微纳',
#   'cat1': '国防军工(2021)',
#   'cat2': '军工电子Ⅱ(2021)'},
#  '123015.SZ': {'cn': '蓝盾转债',
#   'ipo': '2018-09-13',
#   'sc': '300297.SZ',
#   'sn': '*ST蓝盾',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '123022.SZ': {'cn': '长信转债',
#   'ipo': '2019-04-10',
#   'sc': '300088.SZ',
#   'sn': '长信科技',
#   'cat1': '电子(2021)',
#   'cat2': '光学光电子(2021)'},
#  '123025.SZ': {'cn': '精测转债',
#   'ipo': '2019-04-19',
#   'sc': '300567.SZ',
#   'sn': '精测电子',
#   'cat1': '机械设备(2021)',
#   'cat2': '通用设备(2021)'},
#  '123035.SZ': {'cn': '利德转债',
#   'ipo': '2019-12-09',
#   'sc': '300296.SZ',
#   'sn': '利亚德',
#   'cat1': '电子(2021)',
#   'cat2': '光学光电子(2021)'},
#  '123050.SZ': {'cn': '聚飞转债',
#   'ipo': '2020-05-15',
#   'sc': '300303.SZ',
#   'sn': '聚飞光电',
#   'cat1': '电子(2021)',
#   'cat2': '光学光电子(2021)'},
#  '123054.SZ': {'cn': '思特转债',
#   'ipo': '2020-07-06',
#   'sc': '300608.SZ',
#   'sn': '思特奇',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '123059.SZ': {'cn': '银信转债',
#   'ipo': '2020-08-12',
#   'sc': '300231.SZ',
#   'sn': '银信科技',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '123077.SZ': {'cn': '汉得转债',
#   'ipo': '2020-12-15',
#   'sc': '300170.SZ',
#   'sn': '汉得信息',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '123083.SZ': {'cn': '朗新转债',
#   'ipo': '2021-01-06',
#   'sc': '300682.SZ',
#   'sn': '朗新科技',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '123087.SZ': {'cn': '明电转债',
#   'ipo': '2021-01-05',
#   'sc': '300739.SZ',
#   'sn': '明阳电路',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '123096.SZ': {'cn': '思创转债',
#   'ipo': '2021-03-01',
#   'sc': '300078.SZ',
#   'sn': '思创医惠',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '123100.SZ': {'cn': '朗科转债',
#   'ipo': '2021-03-16',
#   'sc': '300543.SZ',
#   'sn': '朗科智能',
#   'cat1': '电子(2021)',
#   'cat2': '消费电子(2021)'},
#  '123104.SZ': {'cn': '卫宁转债',
#   'ipo': '2021-03-31',
#   'sc': '300253.SZ',
#   'sn': '卫宁健康',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '123115.SZ': {'cn': '捷捷转债',
#   'ipo': '2021-06-29',
#   'sc': '300623.SZ',
#   'sn': '捷捷微电',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '123116.SZ': {'cn': '万兴转债',
#   'ipo': '2021-07-01',
#   'sc': '300624.SZ',
#   'sn': '万兴科技',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '123121.SZ': {'cn': '帝尔转债',
#   'ipo': '2021-08-27',
#   'sc': '300776.SZ',
#   'sn': '帝尔激光',
#   'cat1': '电力设备(2021)',
#   'cat2': '光伏设备(2021)'},
#  '123122.SZ': {'cn': '富瀚转债',
#   'ipo': '2021-08-24',
#   'sc': '300613.SZ',
#   'sn': '富瀚微',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '123131.SZ': {'cn': '奥飞转债',
#   'ipo': '2021-12-22',
#   'sc': '300738.SZ',
#   'sn': '奥飞数据',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '123138.SZ': {'cn': '丝路转债',
#   'ipo': '2022-03-22',
#   'sc': '300556.SZ',
#   'sn': '丝路视觉',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '123140.SZ': {'cn': '天地转债',
#   'ipo': '2022-03-30',
#   'sc': '300743.SZ',
#   'sn': '天地数码',
#   'cat1': '计算机(2021)',
#   'cat2': '计算机设备(2021)'},
#  '123143.SZ': {'cn': '胜蓝转债',
#   'ipo': '2022-04-22',
#   'sc': '300843.SZ',
#   'sn': '胜蓝股份',
#   'cat1': '电子(2021)',
#   'cat2': '消费电子(2021)'},
#  '123153.SZ': {'cn': '英力转债',
#   'ipo': '2022-08-11',
#   'sc': '300956.SZ',
#   'sn': '英力股份',
#   'cat1': '电子(2021)',
#   'cat2': '消费电子(2021)'},
#  '123157.SZ': {'cn': '科蓝转债',
#   'ipo': '2022-09-20',
#   'sc': '300663.SZ',
#   'sn': '科蓝软件',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '123164.SZ': {'cn': '法本转债',
#   'ipo': '2022-11-14',
#   'sc': '300925.SZ',
#   'sn': '法本信息',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '123167.SZ': {'cn': '商络转债',
#   'ipo': '2022-12-09',
#   'sc': '300975.SZ',
#   'sn': '商络电子',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '123170.SZ': {'cn': '南电转债',
#   'ipo': '2022-12-15',
#   'sc': '300346.SZ',
#   'sn': '南大光电',
#   'cat1': '电子(2021)',
#   'cat2': '电子化学品Ⅱ(2021)'},
#  '123173.SZ': {'cn': '恒锋转债',
#   'ipo': '2023-02-08',
#   'sc': '300605.SZ',
#   'sn': '恒锋信息',
#   'cat1': '计算机(2021)',
#   'cat2': '软件开发(2021)'},
#  '127021.SZ': {'cn': '特发转2',
#   'ipo': '2020-09-04',
#   'sc': '000070.SZ',
#   'sn': '特发信息',
#   'cat1': '通信(2021)',
#   'cat2': '通信设备(2021)'},
#  '127026.SZ': {'cn': '超声转债',
#   'ipo': '2021-01-14',
#   'sc': '000823.SZ',
#   'sn': '超声电子',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '127038.SZ': {'cn': '国微转债',
#   'ipo': '2021-07-14',
#   'sc': '002049.SZ',
#   'sn': '紫光国微',
#   'cat1': '电子(2021)',
#   'cat2': '半导体(2021)'},
#  '127080.SZ': {'cn': '声迅转债',
#   'ipo': '2023-02-10',
#   'sc': '003004.SZ',
#   'sn': '声迅股份',
#   'cat1': '计算机(2021)',
#   'cat2': '计算机设备(2021)'},
#  '128033.SZ': {'cn': '迪龙转债',
#   'ipo': '2018-01-29',
#   'sc': '002658.SZ',
#   'sn': '雪迪龙',
#   'cat1': '环保(2021)',
#   'cat2': '环保设备Ⅱ(2021)'},
#  '128035.SZ': {'cn': '大族转债',
#   'ipo': '2018-03-05',
#   'sc': '002008.SZ',
#   'sn': '大族激光',
#   'cat1': '机械设备(2021)',
#   'cat2': '自动化设备(2021)'},
#  '128074.SZ': {'cn': '游族转债',
#   'ipo': '2019-10-21',
#   'sc': '002174.SZ',
#   'sn': '游族网络',
#   'cat1': '传媒(2021)',
#   'cat2': '游戏Ⅱ(2021)'},
#  '128078.SZ': {'cn': '太极转债',
#   'ipo': '2019-11-08',
#   'sc': '002368.SZ',
#   'sn': '太极股份',
#   'cat1': '计算机(2021)',
#   'cat2': '白酒Ⅱ(2021)'},
#  '128083.SZ': {'cn': '新北转债',
#   'ipo': '2019-12-31',
#   'sc': '002376.SZ',
#   'sn': '新北洋',
#   'cat1': '计算机(2021)',
#   'cat2': '计算机设备(2021)'},
#  '128101.SZ': {'cn': '联创转债',
#   'ipo': '2020-04-13',
#   'sc': '002036.SZ',
#   'sn': '联创电子',
#   'cat1': '电子(2021)',
#   'cat2': '光学光电子(2021)'},
#  '128118.SZ': {'cn': '瀛通转债',
#   'ipo': '2020-08-05',
#   'sc': '002861.SZ',
#   'sn': '瀛通通讯',
#   'cat1': '电子(2021)',
#   'cat2': '消费电子(2021)'},
#  '128122.SZ': {'cn': '兴森转债',
#   'ipo': '2020-08-17',
#   'sc': '002436.SZ',
#   'sn': '兴森科技',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '128131.SZ': {'cn': '崇达转2',
#   'ipo': '2020-09-28',
#   'sc': '002815.SZ',
#   'sn': '崇达技术',
#   'cat1': '电子(2021)',
#   'cat2': '元件(2021)'},
#  '128136.SZ': {'cn': '立讯转债',
#   'ipo': '2020-12-02',
#   'sc': '002475.SZ',
#   'sn': '立讯精密',
#   'cat1': '电子(2021)',
#   'cat2': '消费电子(2021)'},
#  '128137.SZ': {'cn': '洁美转债',
#   'ipo': '2020-12-01',
#   'sc': '002859.SZ',
#   'sn': '洁美科技',
#   'cat1': '电子(2021)',
#   'cat2': '其他电子Ⅱ(2021)'},
#  '128140.SZ': {'cn': '润建转债',
#   'ipo': '2020-12-29',
#   'sc': '002929.SZ',
#   'sn': '润建股份',
#   'cat1': '通信(2021)',
#   'cat2': '通信服务(2021)'},
#  '110048.SH': {'cn': '福能转债',
#   'ipo': '2018-12-28',
#   'sc': '600483.SH',
#   'sn': '福能股份',
#   'cat1': '公用事业(2021)',
#   'cat2': '电力(2021)'},
#  '110061.SH': {'cn': '川投转债',
#   'ipo': '2019-12-02',
#   'sc': '600674.SH',
#   'sn': '川投能源',
#   'cat1': '公用事业(2021)',
#   'cat2': '电力(2021)'},
#  '110077.SH': {'cn': '洪城转债',
#   'ipo': '2020-12-17',
#   'sc': '600461.SH',
#   'sn': '洪城环境',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '110084.SH': {'cn': '贵燃转债',
#   'ipo': '2022-01-18',
#   'sc': '600903.SH',
#   'sn': '贵州燃气',
#   'cat1': '公用事业(2021)',
#   'cat2': '燃气Ⅱ(2021)'},
#  '113039.SH': {'cn': '嘉泽转债',
#   'ipo': '2020-09-17',
#   'sc': '601619.SH',
#   'sn': '嘉泽新能',
#   'cat1': '公用事业(2021)',
#   'cat2': '电力(2021)'},
#  '113048.SH': {'cn': '晶科转债',
#   'ipo': '2021-05-31',
#   'sc': '601778.SH',
#   'sn': '晶科科技',
#   'cat1': '公用事业(2021)',
#   'cat2': '电力(2021)'},
#  '113051.SH': {'cn': '节能转债',
#   'ipo': '2021-07-22',
#   'sc': '601016.SH',
#   'sn': '节能风电',
#   'cat1': '公用事业(2021)',
#   'cat2': '电力(2021)'},
#  '113532.SH': {'cn': '海环转债',
#   'ipo': '2019-04-24',
#   'sc': '603817.SH',
#   'sn': '海峡环保',
#   'cat1': '环保(2021)',
#   'cat2': '环境治理(2021)'},
#  '123092.SZ': {'cn': '天壕转债',
#   'ipo': '2021-01-15',
#   'sc': '300332.SZ',
#   'sn': '天壕环境',
#   'cat1': '公用事业(2021)',
#   'cat2': '燃气Ⅱ(2021)'},
#  '128105.SZ': {'cn': '长集转债',
#   'ipo': '2020-05-13',
#   'sc': '002616.SZ',
#   'sn': '长青集团',
#   'cat1': '公用事业(2021)',
#   'cat2': '电力(2021)'},
#  '118031.SH': {'ipo_dt': '2023-03-15',
#   'cn': '天23转债',
#   'sc': '688599.SH',
#   'sn': '天合光能',
#   'cat1': nan,
#   'cat2': nan},
#  '123175.SZ': {'ipo_dt': '2023-03-17',
#   'cn': '百畅转债',
#   'sc': '300614.SZ',
#   'sn': '百川畅银',
#   'cat1': nan,
#   'cat2': nan},
#  '113666.SH': {'ipo_dt': '2023-03-20',
#   'cn': '爱玛转债',
#   'sc': '603529.SH',
#   'sn': '爱玛科技',
#   'cat1': nan,
#   'cat2': nan},
#  '123176.SZ': {'ipo_dt': '2023-03-22',
#   'cn': '精测转2',
#   'sc': '300567.SZ',
#   'sn': '精测电子',
#   'cat1': nan,
#   'cat2': nan}}
