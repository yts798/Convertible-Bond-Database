# %%
import numpy as np
import pickle
import time 
import os
import requests
import json
import pandas as pd
import datetime
from datetime import datetime
from operator import itemgetter


data_folder_path = 'C:\\Users\\goodluck\\Desktop\\DB'
raw_data_path =  "C:\\Users\\goodluck\\Desktop\\DB\\raw_data"
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
update_path =   "C:\\Users\\goodluck\\Desktop\\DB\\auto_update"
DTBS_path = os.path.join(storage_path, "DTBS.pkl")


index = requests.get('https://www.jisilu.cn/data/etf/#index')
index.content
# Out:
# b'<!DOCTYPE html>\n<html><head>\n<meta name="renderer" content="webkit" />\n<meta name="force-rendering" content="webkit" />\n<meta content="text/html;charset=utf-8" http-equiv="Content-Type" />\n<meta http-equiv="X-UA-Compatible" content="Chrome=1,IE=edge" />\n<title>ETF\xe5\x9f\xba\xe9\x87\x91 - \xe9\x9b\x86\xe6\x80\x9d\xe5\xbd\x95</title>\n<meta name="keywords" content="\xe9\x9b\x86\xe6\x80\x9d\xe5\xbd\x95,\xe7\x90\x86\xe8\xb4\xa2,\xe5\x8f\xaf\xe8\xbd\xac\xe5\x80\xba,\xe5\x80\xba\xe5\x88\xb8,\xe5\x85\xac\xe5\x8f\xb8\xe5\x80\xba,\xe5\x9b\xbd\xe5\x80\xba,\xe6\x96\xb0\xe8\x82\xa1,\xe5\xb0\x81\xe9\x97\xad\xe5\x9f\xba\xe9\x87\x91,\xe5\xb0\x81\xe5\x9f\xba,ETF,LOF" />\n<meta name="description" content="\xe9\x9b\x86\xe6\x80\x9d\xe5\xbd\x95\xef\xbc\x8c\xe4\xb8\x80\xe4\xb8\xaa\xe4\xbb\xa5\xe6\x95\xb0\xe6\x8d\xae\xe4\xb8\xba\xe6\x9c\xac\xe7\x9a\x84\xe6\x8a\x95\xe8\xb5\x84\xe7\xa4\xbe\xe5\x8c\xba"  />\n<base href="https://www.jisilu.cn/" />\n\n<link href="https://www.jisilu.cn/static/js/table
# ...
