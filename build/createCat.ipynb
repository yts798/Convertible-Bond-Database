# %%
# set up
import pandas as pd
import numpy as np
import pickle
import time 
import os
from datetime import datetime
from operator import itemgetter
data_folder_path = 'C:\\Users\\goodluck\\Desktop\\DB'
raw_data_path =  "C:\\Users\\goodluck\\Desktop\\DB\\raw_data"
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
DTBS_path = os.path.join(storage_path, "DTBS.pkl")
with open(DTBS_path, 'rb') as f:  
    DTBS = pickle.load(f)

# %%
for cd in DTBS['A'].keys():
    if DTBS['B'][cd]['cat1'] == '房地产(2021)':
        DTBS['B'][cd]['sw'] = '房地产'
        DTBS['B'][cd]['zs'] = '房地产'        
    elif DTBS['B'][cd]['cat1'] == '传媒(2021)':
        DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '科技'         
    elif DTBS['B'][cd]['cat1'] == '电力设备(2021)':
        DTBS['B'][cd]['sw'] = '制造'
        DTBS['B'][cd]['zs'] = '新能源'            
    elif DTBS['B'][cd]['cat1'] == '电子(2021)':
        DTBS['B'][cd]['sw'] = '制造'
        DTBS['B'][cd]['zs'] = '科技'            
    elif DTBS['B'][cd]['cat1'] == '纺织服饰(2021)':
        DTBS['B'][cd]['sw'] = '制造'
        DTBS['B'][cd]['zs'] = '消费'                    
    elif DTBS['B'][cd]['cat1'] == '银行(2021)':
        DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '金融'               
    elif DTBS['B'][cd]['cat1'] == '非银金融(2021)':
        DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '金融'         
    elif DTBS['B'][cd]['cat1'] == '钢铁(2021)':
        DTBS['B'][cd]['sw'] = '投资'
        DTBS['B'][cd]['zs'] = '周期'         
    elif DTBS['B'][cd]['cat1'] == '公用事业(2021)':
        DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '能源'         
    elif DTBS['B'][cd]['cat1'] == '国防军工(2021)':
        DTBS['B'][cd]['sw'] = '制造'
        DTBS['B'][cd]['zs'] = '科技'         
    elif DTBS['B'][cd]['cat1'] == '环保(2021)':
        if DTBS['B'][cd]['cat2'] == '环保设备Ⅱ(2021)':
            DTBS['B'][cd]['sw'] = '制造'
        else:
            DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '环保'  
    elif DTBS['B'][cd]['cat1'] == '机械设备(2021)':
        DTBS['B'][cd]['sw'] = '制造'
        DTBS['B'][cd]['zs'] = '周期'  
    elif DTBS['B'][cd]['cat1'] == '基础化工(2021)':
        DTBS['B'][cd]['sw'] = '投资'
        DTBS['B'][cd]['zs'] = '周期'  
    elif DTBS['B'][cd]['cat1'] == '计算机(2021)':
        if DTBS['B'][cd]['cat2'] == '计算机设备(2021)':
            DTBS['B'][cd]['sw'] = '制造'
        else:
            DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '科技'  
    elif DTBS['B'][cd]['cat1'] == '家用电器(2021)':
        DTBS['B'][cd]['sw'] = '消费'
        DTBS['B'][cd]['zs'] = '消费'  
    elif DTBS['B'][cd]['cat1'] == '建筑材料(2021)':
        DTBS['B'][cd]['sw'] = '投资'
        DTBS['B'][cd]['zs'] = '周期'  
    elif DTBS['B'][cd]['cat1'] == '建筑装饰(2021)':
        DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '周期'  
    elif DTBS['B'][cd]['cat1'] == '交通运输(2021)':
        DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '周期'  
    elif DTBS['B'][cd]['cat1'] == '煤炭(2021)':
        DTBS['B'][cd]['sw'] = '投资'
        DTBS['B'][cd]['zs'] = '周期'  
    elif DTBS['B'][cd]['cat1'] == '美容护理(2021)':
        DTBS['B'][cd]['sw'] = '消费'
        DTBS['B'][cd]['zs'] = '消费'
    elif DTBS['B'][cd]['cat1'] == '农林牧渔(2021)':
        DTBS['B'][cd]['sw'] = '消费'
        DTBS['B'][cd]['zs'] = '消费'  
    elif DTBS['B'][cd]['cat1'] == '汽车(2021)':
        if DTBS['B'][cd]['cat2'] == '汽车零部件(2021)':   
            DTBS['B'][cd]['sw'] = '制造'
        else:
            DTBS['B'][cd]['sw'] = '消费'
        DTBS['B'][cd]['zs'] = '消费'  
    elif DTBS['B'][cd]['cat1'] == '轻工制造(2021)':
        if DTBS['B'][cd]['cat2'] == '造纸(2021)':  
            DTBS['B'][cd]['sw'] = '制造'
        else:
            DTBS['B'][cd]['sw'] = '消费'
        DTBS['B'][cd]['zs'] = '消费'  
    elif DTBS['B'][cd]['cat1'] == '商贸零售(2021)':
        DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '消费'  
    elif DTBS['B'][cd]['cat1'] == '社会服务(2021)':
        DTBS['B'][cd]['sw'] = '服务'
        DTBS['B'][cd]['zs'] = '消费'  
    elif DTBS['B'][cd]['cat1'] == '石油石化(2021)':
        DTBS['B'][cd]['sw'] = '投资'
        DTBS['B'][cd]['zs'] = '消费' 
    elif DTBS['B'][cd]['cat1'] == '食品饮料(2021)':
        DTBS['B'][cd]['sw'] = '消费'
        DTBS['B'][cd]['zs'] = '消费'  
    elif DTBS['B'][cd]['cat1'] == '通信(2021)':
        if DTBS['B'][cd]['cat2'] == '通信服务(2021)': 
            DTBS['B'][cd]['sw'] = '服务'
        else:
            DTBS['B'][cd]['sw'] = '制造'
        DTBS['B'][cd]['zs'] = '科技'  
    elif DTBS['B'][cd]['cat1'] == '医药生物(2021)':
        DTBS['B'][cd]['sw'] = '消费'
        DTBS['B'][cd]['zs'] = '医药'  
    elif DTBS['B'][cd]['cat1'] == '有色金属(2021)':
        DTBS['B'][cd]['sw'] = '投资'
        DTBS['B'][cd]['zs'] = '周期'

# %%
for cd in DTBS['A'].keys():
    print(cd, DTBS['B'][cd]['cat1'], DTBS['B'][cd]['sw'], DTBS['B'][cd]['zs'])
# Out:
# 110088.SH 煤炭(2021) 投资 周期
# 113545.SH 煤炭(2021) 投资 周期
# 113631.SH 公用事业(2021) 服务 能源
# 123128.SZ 公用事业(2021) 服务 能源
# 123156.SZ 石油石化(2021) 投资 消费
# 127027.SZ 煤炭(2021) 投资 周期
# 127061.SZ 煤炭(2021) 投资 周期
# 110047.SH 轻工制造(2021) 制造 消费
# 110063.SH 轻工制造(2021) 制造 消费
# 110070.SH 钢铁(2021) 投资 周期
# 110087.SH 基础化工(2021) 投资 周期
# 110089.SH 基础化工(2021) 投资 周期
# 110092.SH 基础化工(2021) 投资 周期
# 111001.SH 建筑材料(2021) 投资 周期
# 111002.SH 轻工制造(2021) 制造 消费
# 111003.SH 基础化工(2021) 投资 周期
# 111007.SH 基础化工(2021) 投资 周期
# 111012.SH 基础化工(2021) 投资 周期
# 113025.SH 有色金属(2021) 投资 周期
# 113027.SH 有色金属(2021) 投资 周期
# 113046.SH 有色金属(2021) 投资 周期
# 113047.SH 建筑材料(2021) 投资 周期
# 113058.SH 钢铁(2021) 投资 周期
# 113059.SH 电力设备(2021) 制造 新能源
# 113064.SH 基础化工(2021) 投资 周期
# 113534.SH 有色金属(2021) 投资 周期
# 113535.SH 机械设备(2021) 制造 周期
# 113566.SH 轻工制造(2021) 消费 消费
# 113591.SH 轻工制造(2021) 消费 消费
# 113600.SH 有色金属(2021) 投资 周期
# 113615.SH 建筑装饰(2021) 服务 周期
# 113621.SH 基础化工(2021) 投资 周期
# 113623.SH 基础化工(2021) 投资 周期
# 113632.SH 轻工制造(2021) 制造 消费
# ...

# %%
DTBS['B']['118034.SH']['cat1'] = '电力设备(2021)'
DTBS['B']['118034.SH']['cat2'] = '光伏设备(2021)'
DTBS['B']['123196.SZ']['cat1'] = '计算机(2021)'
DTBS['B']['123196.SZ']['cat2'] = '计算机设备(2021)'

# %%
DTBS['B']['110068.SH']['cat2']
# Out:
# '环保设备Ⅱ(2021)'

# %%
# # save
f_save = open(DTBS_path, 'wb')
pickle.dump(DTBS, f_save)
f_save.close()

# %%
for cd in DTBS['A'].keys():
    if DTBS['B'][cd]['cat1'] == '房地产(2021)':
        DTBS['B'][cd]['yqq'] = '房地产'
    elif DTBS['B'][cd]['cat1'] == '传媒(2021)':      
        DTBS['B'][cd]['yqq'] = '科技'
    elif DTBS['B'][cd]['cat1'] == '电力设备(2021)':
        DTBS['B'][cd]['yqq'] = '新能源'            
    elif DTBS['B'][cd]['cat1'] == '电子(2021)':
        DTBS['B'][cd]['yqq'] = '电子'
    elif DTBS['B'][cd]['cat1'] == '纺织服饰(2021)':
        DTBS['B'][cd]['yqq'] = '制造'                  
    elif DTBS['B'][cd]['cat1'] == '银行(2021)':
        DTBS['B'][cd]['yqq'] = '金融'               
    elif DTBS['B'][cd]['cat1'] == '非银金融(2021)':
        DTBS['B'][cd]['yqq'] = '金融'         
    elif DTBS['B'][cd]['cat1'] == '钢铁(2021)':
        DTBS['B'][cd]['yqq'] = '投资'       
    elif DTBS['B'][cd]['cat1'] == '公用事业(2021)':
        DTBS['B'][cd]['yqq'] = '能源'         
    elif DTBS['B'][cd]['cat1'] == '国防军工(2021)':
        DTBS['B'][cd]['yqq'] = '电子'  
    elif DTBS['B'][cd]['cat1'] == '环保(2021)':
        DTBS['B'][cd]['yqq'] = '环保'   
    elif DTBS['B'][cd]['cat1'] == '机械设备(2021)':
        DTBS['B'][cd]['yqq'] = '制造'    
    elif DTBS['B'][cd]['cat1'] == '基础化工(2021)':
        DTBS['B'][cd]['yqq'] = '投资'      
    elif DTBS['B'][cd]['cat1'] == '计算机(2021)':
        DTBS['B'][cd]['yqq'] = '科技' 
    elif DTBS['B'][cd]['cat1'] == '家用电器(2021)':
        DTBS['B'][cd]['yqq'] = '消费'
    elif DTBS['B'][cd]['cat1'] == '建筑材料(2021)':
        DTBS['B'][cd]['yqq'] = '投资'     
    elif DTBS['B'][cd]['cat1'] == '建筑装饰(2021)':
        DTBS['B'][cd]['yqq'] = '基建'     
    elif DTBS['B'][cd]['cat1'] == '交通运输(2021)':
        DTBS['B'][cd]['yqq'] = '基建'     
    elif DTBS['B'][cd]['cat1'] == '煤炭(2021)':
        DTBS['B'][cd]['yqq'] = '能源'  
    elif DTBS['B'][cd]['cat1'] == '美容护理(2021)':
        DTBS['B'][cd]['yqq'] = '消费'
    elif DTBS['B'][cd]['cat1'] == '农林牧渔(2021)':
        DTBS['B'][cd]['yqq'] = '农业'
    elif DTBS['B'][cd]['cat1'] == '汽车(2021)':
        if DTBS['B'][cd]['cat2'] == '汽车零部件(2021)':   
            DTBS['B'][cd]['yqq'] = '制造'
        else:
            DTBS['B'][cd]['yqq'] = '消费'
    elif DTBS['B'][cd]['cat1'] == '轻工制造(2021)':
        DTBS['B'][cd]['yqq'] = '制造'    
    elif DTBS['B'][cd]['cat1'] == '商贸零售(2021)':
        DTBS['B'][cd]['yqq'] = '消费'
    elif DTBS['B'][cd]['cat1'] == '社会服务(2021)':
        DTBS['B'][cd]['yqq'] = '消费'
    elif DTBS['B'][cd]['cat1'] == '石油石化(2021)':
        DTBS['B'][cd]['yqq'] = '能源'  
    elif DTBS['B'][cd]['cat1'] == '食品饮料(2021)':
        DTBS['B'][cd]['yqq'] = '消费' 
    elif DTBS['B'][cd]['cat1'] == '通信(2021)':
        DTBS['B'][cd]['yqq'] = '科技' 
    elif DTBS['B'][cd]['cat1'] == '医药生物(2021)':
        DTBS['B'][cd]['yqq'] = '医药'
    elif DTBS['B'][cd]['cat1'] == '有色金属(2021)':
        DTBS['B'][cd]['yqq'] = '投资'    
    else:
        print("NO!!!!!!!!!", cd, DTBS['B'][cd]['cat1'])
