# %%
# set up
import pandas as pd
import numpy as np
import pickle
import time 
import os
from datetime import datetime
from operator import itemgetter
data_folder_path = 'C:\\Users\\goodluck\\Desktop\\DB'
raw_data_path =  "C:\\Users\\goodluck\\Desktop\\DB\\raw_data"
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
DTBS_path = os.path.join(storage_path, "DTBS.pkl")

with open(DTBS_path, 'rb') as f:  
    DTBS = pickle.load(f)

# %%
stc_path =  os.path.join(raw_data_path, "stclose.CSV")
stc_df = pd.read_csv(stc_path)
stc_df.set_index('Date',inplace=True)

# %%
stc_df
# Out:
#             002360.SZ  600061.SH  600372.SH  300624.SZ  601677.SH  002352.SZ  \
# Date
# 2017-01-03      12.30      15.74      19.22        NaN      15.08      42.25
# 2017-01-04      12.41      15.77      19.26        NaN      15.11      43.04
# 2017-01-05      12.44      15.63      19.43        NaN      15.35      43.32
# 2017-01-06      12.24      15.39      19.44        NaN      15.24      42.31
# 2017-01-09      12.54      15.43      20.18        NaN      15.25      42.35
# ...               ...        ...        ...        ...        ...        ...
# 2023-03-20       7.75       6.77      17.58      72.40      15.91      51.73
# 2023-03-21       7.84       6.89      17.95      69.06      16.23      53.09
# 2023-03-22       7.90       6.89      18.32      73.40      16.12      53.23
# 2023-03-23       7.87       6.98      18.29      71.79      16.21      54.00
# 2023-03-24       7.85       6.92      18.10      77.02      16.21      53.73
#
# ...

# %%
# # build E structure
# DTBS['E'] = dict()
for code in stc_df.columns:
#     DTBS['E'][code] = dict()
    for date in stc_df.index:
#         DTBS['E'][code][date] = dict()
        DTBS['E'][code][date]['cl'] = stc_df.loc[date][code]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-6dc819923897> in <module>()
# ----> 1 DTBS['E']['002360.SZ']['2023-03-27']
#
# KeyError: '2023-03-27'

# %%
# update qsxxhs

for code in DTBS['A'].keys():
    for dt in stc_df.index:
        DTBS['A'][code][dt]['qs'] = 0
        DTBS['A'][code][dt]['xx'] = 0
        DTBS['A'][code][dt]['hs'] = 0

# %%
DTBS['A']['110088.SH']
# Out:
# {'2017-01-03': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0,
#   'qs': 0,
#   'xx': 0,
#   'hs': 0},
#  '2017-01-04': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0,
#   'qs': 0,
#   'xx': 0,
#   'hs': 0},
#  '2017-01-05': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0,
#   'qs': 0,
#   'xx': 0,
#   'hs': 0},
#  '2017-01-06': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0,
#   'qs': 0,
#   'xx': 0,
#   'hs': 0},
#  '2017-01-09': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
#   'ia': 0,
#   'qs': 0,
#   'xx': 0,
#   'hs': 0},
#  '2017-01-10': {'cpr': nan,
#   'dp': nan,
#   'bl': nan,
#   'trt': nan,
#   'ytm': nan,
#   'yl': nan,
#   'dl': 999,
# ...

# %%
f_save = open(DTBS_path, 'wb')
pickle.dump(DTBS, f_save)
f_save.close()

# %%
pb_path =  os.path.join(raw_data_path, "pb.CSV")
pb_df = pd.read_csv(pb_path)
pb_df.set_index('Date',inplace=True)
pb_df
# Out:
#            002360.SZ  600061.SH  600372.SH  300624.SZ  601677.SH  002352.SZ  \
# Date
# 2017/1/3      4.8859     2.1538     5.7703        NaN     2.0432    13.9636
# 2017/1/4      4.9296     2.1579     5.7823        NaN     2.0473    14.2247
# 2017/1/5      4.9415     2.1388     5.8333        NaN     2.0798    14.3172
# 2017/1/6      4.8620     2.1059     5.8363        NaN     2.0649    13.9834
# 2017/1/9      4.9812     2.1114     6.0585        NaN     2.0662    13.9966
# ...              ...        ...        ...        ...        ...        ...
# 2023/3/30     1.9095     0.9319     2.7621    11.2597     1.2987     3.1324
# 2023/3/31     1.9396     0.9279     2.7574    11.7518     1.3169     3.1426
# 2023/4/3      1.9547     0.9492     2.7826    12.5723     1.3227     3.0717
# 2023/4/4      1.8919     0.9506     2.8062    11.8773     1.2962     3.0382
# 2023/4/6      1.8567     0.9680     2.7951    10.5862     1.2730     3.1029
#
# ...

# %%
for dt in DTBS['D']['day']:
    print(dt)
# Out:
# 2017-01-03
# 2017-01-04
# 2017-01-05
# 2017-01-06
# 2017-01-09
# 2017-01-10
# 2017-01-11
# 2017-01-12
# 2017-01-13
# 2017-01-16
# 2017-01-17
# 2017-01-18
# 2017-01-19
# 2017-01-20
# 2017-01-23
# 2017-01-24
# 2017-01-25
# 2017-01-26
# 2017-02-03
# 2017-02-06
# 2017-02-07
# 2017-02-08
# 2017-02-09
# 2017-02-10
# 2017-02-13
# 2017-02-14
# 2017-02-15
# 2017-02-16
# 2017-02-17
# 2017-02-20
# 2017-02-21
# 2017-02-22
# 2017-02-23
# 2017-02-24
# 2017-02-27
# 2017-02-28
# 2017-03-01
# 2017-03-02
# 2017-03-03
# 2017-03-06
# 2017-03-07
# 2017-03-08
# 2017-03-09
# 2017-03-10
# 2017-03-13
# 2017-03-14
# 2017-03-15
# 2017-03-16
# 2017-03-17
# 2017-03-20
# 2017-03-21
# 2017-03-22
# 2017-03-23
# 2017-03-24
# 2017-03-27
# 2017-03-28
# 2017-03-29
# 2017-03-30
# 2017-03-31
# 2017-04-05
# 2017-04-06
# 2017-04-07
# 2017-04-10
# 2017-04-11
# 2017-04-12
# 2017-04-13
# 2017-04-14
# 2017-04-17
# 2017-04-18
# 2017-04-19
# 2017-04-20
# 2017-04-21
# 2017-04-24
# 2017-04-25
# 2017-04-26
# 2017-04-27
# ...

# %%
DTBS['D']['day'][0]
# Out:
# '2017-01-03'

# %%
# build E structure

for code in pb_df.columns:
    count = 0
    for date in pb_df.index:
        dt = DTBS['D']['day'][count]
        count += 1
        DTBS['E'][code][dt]['pb'] = pb_df.loc[date][code]

# %%
print(DTBS['E']['002360.SZ'])
# Out:
# {'2017-01-03': {'cl': 12.3, 'pb': 4.8859}, '2017-01-04': {'cl': 12.41, 'pb': 4.9296}, '2017-01-05': {'cl': 12.44, 'pb': 4.9415}, '2017-01-06': {'cl': 12.24, 'pb': 4.862}, '2017-01-09': {'cl': 12.54, 'pb': 4.9812}, '2017-01-10': {'cl': 12.48, 'pb': 4.9574}, '2017-01-11': {'cl': 12.49, 'pb': 4.9613}, '2017-01-12': {'cl': 12.45, 'pb': 4.9455}, '2017-01-13': {'cl': 12.35, 'pb': 4.9057}, '2017-01-16': {'cl': 11.23, 'pb': 4.4608}, '2017-01-17': {'cl': 10.96, 'pb': 4.3536}, '2017-01-18': {'cl': 10.72, 'pb': 4.2583}, '2017-01-19': {'cl': 10.81, 'pb': 4.294}, '2017-01-20': {'cl': 11.19, 'pb': 4.445}, '2017-01-23': {'cl': 11.29, 'pb': 4.4847}, '2017-01-24': {'cl': 11.17, 'pb': 4.437}, '2017-01-25': {'cl': 11.19, 'pb': 4.445}, '2017-01-26': {'cl': 11.26, 'pb': 4.4728}, '2017-02-03': {'cl': 11.2, 'pb': 4.4489}, '2017-02-06': {'cl': 11.36, 'pb': 4.5125}, '2017-02-07': {'cl': 11.4, 'pb': 4.5284}, '2017-02-08': {'cl': 11.72, 'pb': 4.6555}, '2017-02-09': {'cl': 11.95, 'pb': 4.7468}, '2017-02-10': {'
# ...

# %%
# save
f_save = open(DTBS_path, 'wb')
pickle.dump(DTBS, f_save)
f_save.close()
