# %%
# set up
import pandas as pd
import numpy as np
import pickle
import time 
import os
from datetime import datetime
from operator import itemgetter
data_folder_path = 'C:\\Users\\goodluck\\Desktop\\DB'
raw_data_path =  "C:\\Users\\goodluck\\Desktop\\DB\\raw_data"
storage_path =  "C:\\Users\\goodluck\\Desktop\\DB\\database_storage"
DTBS_path = os.path.join(storage_path, "DTBS.pkl")
with open(DTBS_path, 'rb') as f:  
    DTBS = pickle.load(f)

# %%
def slash_dash_convert(t):
    if t[4] == '/':
        t = datetime.strptime(t, '%Y/%m/%d')
        t = t.strftime('%Y-%m-%d')
    elif t[4] == '-':
        t = datetime.strptime(t,'%Y-%m-%d')
        t = t.strftime('%Y/%m/%d').replace('/0','/')

    else:
        print("Wrong Input!")
        
    return t

slash_dash_convert('2023/6/8')
# Out:
# '2023-06-08'

# %%
196.1247/194.9037
# Out:
# 1.0062646322260687

# %%
sw_path =  os.path.join(raw_data_path, "sw_zs.CSV")
sw_df = pd.read_csv(sw_path)
sw_df.set_index('Date',inplace=True)
sw_df
# Out:
#               nlmy      jchg        gt      ysjs        dz      jydq  \
# Date
# 2017/1/3  3,388.74  3,350.08  2,610.63  3,623.94  3,085.68  5,143.15
# 2017/1/4  3,423.82  3,405.95  2,642.13  3,670.89  3,125.47  5,202.55
# 2017/1/5  3,421.90  3,411.20  2,645.93  3,688.33  3,119.82  5,195.79
# 2017/1/6  3,410.66  3,394.32  2,656.73  3,665.62  3,081.86  5,150.36
# 2017/1/9  3,399.36  3,410.87  2,680.69  3,677.00  3,092.85  5,152.42
# ...            ...       ...       ...       ...       ...       ...
# 2023/6/5  2,901.58  3,731.51  2,231.41  4,542.49  3,850.06  6,861.65
# 2023/6/6  2,867.49  3,678.44  2,195.28  4,485.38  3,721.74  6,816.08
# 2023/6/7  2,872.16  3,645.84  2,190.46  4,451.38  3,755.05  6,860.33
# 2023/6/8  2,940.20  3,653.58  2,202.84  4,472.23  3,699.64  6,983.55
# 2023/6/9  2,938.90  3,636.35  2,201.76  4,518.69  3,751.47  6,923.16
#
#                spyl      fzfs      qgzz      yysw  ...        cm        tx  \
# ...

# %%
DTBS['C']['zi'] 
for nm in sw_df.columns:
    DTBS['C'][nm] = dict()
    
for nm in sw_df.columns:
    for dt in sw_df.index:
        ddt = slash_dash_convert(dt)
        DTBS['C'][nm][ddt] = sw_df[nm][dt]

# %%
sw_df.index
# Out:
# Index(['2017/1/3', '2017/1/4', '2017/1/5', '2017/1/6', '2017/1/9', '2017/1/10',
#        '2017/1/11', '2017/1/12', '2017/1/13', '2017/1/16',
#        ...
#        '2023/5/29', '2023/5/30', '2023/5/31', '2023/6/1', '2023/6/2',
#        '2023/6/5', '2023/6/6', '2023/6/7', '2023/6/8', '2023/6/9'],
#       dtype='object', name='Date', length=1564)

# %%
for dt in sw_df.index:
    ddt = slash_dash_convert(dt)
    print(dt,ddt)
# Out:
# 2017/1/3 2017-01-03
# 2017/1/4 2017-01-04
# 2017/1/5 2017-01-05
# 2017/1/6 2017-01-06
# 2017/1/9 2017-01-09
# 2017/1/10 2017-01-10
# 2017/1/11 2017-01-11
# 2017/1/12 2017-01-12
# 2017/1/13 2017-01-13
# 2017/1/16 2017-01-16
# 2017/1/17 2017-01-17
# 2017/1/18 2017-01-18
# 2017/1/19 2017-01-19
# 2017/1/20 2017-01-20
# 2017/1/23 2017-01-23
# 2017/1/24 2017-01-24
# 2017/1/25 2017-01-25
# 2017/1/26 2017-01-26
# 2017/2/3 2017-02-03
# 2017/2/6 2017-02-06
# 2017/2/7 2017-02-07
# 2017/2/8 2017-02-08
# 2017/2/9 2017-02-09
# 2017/2/10 2017-02-10
# 2017/2/13 2017-02-13
# 2017/2/14 2017-02-14
# 2017/2/15 2017-02-15
# 2017/2/16 2017-02-16
# 2017/2/17 2017-02-17
# 2017/2/20 2017-02-20
# 2017/2/21 2017-02-21
# 2017/2/22 2017-02-22
# 2017/2/23 2017-02-23
# 2017/2/24 2017-02-24
# 2017/2/27 2017-02-27
# 2017/2/28 2017-02-28
# 2017/3/1 2017-03-01
# 2017/3/2 2017-03-02
# 2017/3/3 2017-03-03
# 2017/3/6 2017-03-06
# 2017/3/7 2017-03-07
# 2017/3/8 2017-03-08
# 2017/3/9 2017-03-09
# 2017/3/10 2017-03-10
# ...

# %%
DTBS['C']['nlmy']
# Out:
# {'2017-01-03': '3,388.74',
#  '2017-01-04': '3,423.82',
#  '2017-01-05': '3,421.90',
#  '2017-01-06': '3,410.66',
#  '2017-01-09': '3,399.36',
#  '2017-01-10': '3,377.76',
#  '2017-01-11': '3,344.89',
#  '2017-01-12': '3,326.66',
#  '2017-01-13': '3,263.00',
#  '2017-01-16': '3,187.55',
#  '2017-01-17': '3,209.00',
#  '2017-01-18': '3,196.61',
#  '2017-01-19': '3,181.35',
#  '2017-01-20': '3,222.73',
#  '2017-01-23': '3,244.39',
#  '2017-01-24': '3,234.90',
#  '2017-01-25': '3,244.94',
#  '2017-01-26': '3,261.28',
#  '2017-02-03': '3,248.20',
#  '2017-02-06': '3,285.69',
#  '2017-02-07': '3,275.28',
#  '2017-02-08': '3,289.62',
#  '2017-02-09': '3,307.01',
#  '2017-02-10': '3,307.57',
#  '2017-02-13': '3,317.87',
#  '2017-02-14': '3,307.00',
#  '2017-02-15': '3,276.96',
#  '2017-02-16': '3,293.99',
#  '2017-02-17': '3,261.96',
#  '2017-02-20': '3,290.41',
#  '2017-02-21': '3,318.28',
#  '2017-02-22': '3,334.92',
#  '2017-02-23': '3,318.15',
#  '2017-02-24': '3,339.30',
# ...

# %%
# save
f_save = open(DTBS_path, 'wb')
pickle.dump(DTBS, f_save)
f_save.close()
